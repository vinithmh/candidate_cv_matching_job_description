# %% [markdown]
# # Objective: Build a PDF extractor to pull relevant details from CVs in PDF format, and match them against the job descriptions from the Hugging Face dataset.

# %% [markdown]
# ## Approach
#
# #### Step 1: Data Extraction from PDFs
#
# ##### Use the PyMuPDF (fitz) library to parse PDF documents efficiently and extract text data.
# ##### Implement robust error handling to gracefully handle exceptions during the PDF extraction process.
#
# #### Step 2: Text Data Preprocessing
#
# ##### Tokenize both job descriptions and candidate resumes using the Hugging Face Transformers library to prepare them for analysis.
# ##### Convert all text data to lowercase to ensure case sensitivity does not affect similarity calculations.
# ##### Remove stopwords from the text using the NLTK library to eliminate common words that do not contribute significantly.
# ##### Lemmatize words using NLTK to reduce inflected words to their base form, improving analysis accuracy.
#
# #### Step 3: Embeddings and Similarity Calculation
#
# ##### Utilize pretrained models like DistilBERT from Hugging Face to convert text data into dense vector representations (embeddings).
# ##### Calculate cosine similarities between job descriptions and candidate resumes using the scikit-learn library, a fundamental metric for comparing text data.
#
# #### Step 4: Data Organization and Management
#
# ##### Organize and manage data efficiently for both job descriptions and candidate resumes using Pandas dataframes, simplifying data manipulation.
# ##### Use dictionaries to store and access data, facilitating structured storage for easy retrieval.
#
# #### Step 5: Top Candidate Ranking
#
# ##### Dynamically map job titles to corresponding candidate resume datasets to allow for flexibility and scalability.
# ##### Implement ranking logic, which involves sorting and ranking algorithms, to determine the top candidates for each job description based on similarity scores.

# %% [markdown]
# ### Importing of Job Description dataset

# %%
import pandas as pd
job_desp_df = pd.read_csv('job_description.csv')
job_desp_df
# Out:
#              company_name                                    job_description  \
# 0                  Google  minimum qualifications\nbachelors degree or eq...
# 1                   Apple  description\nas an asc you will be highly infl...
# 2                 Netflix  its an amazing time to be joining netflix as w...
# 3             Robert Half  description\n\nweb designers looking to expand...
# 4               TrackFive  at trackfive weve got big goals were on a miss...
# ..                    ...                                                ...
# 848               Menards  job description\n\nparttime\n\nmake big money ...
# 849                Parker  responsibilities\nparkers internship program w...
# 850        Borgen Project   the borgen project is an innovative national ...
# 851  Wyndham Destinations  put the world on vacation\n\nat wyndham destin...
# 852               Aerotek  this job handles customer inquiries by telepho...
#
#                                         position_title  description_length
# 0                                     Sales Specialist                2727
# 1                           Apple Solutions Consultant                 828
# 2            Licensing Coordinator - Consumer Products                3205
# 3                                         Web Designer                2489
# 4                                        Web Developer                3167
# ..                                                 ...                 ...
# 848                              Management Internship                1122
# 849  Human Resources Internship - Corporate  (Year-...                3840
# 850                     Writer / Journalist Internship                 897
# 851          Inbound Customer Service / Sales (Remote)                4604
# 852     Remote Inbound Customer Service Representative                1592
#
# [853 rows x 4 columns]

# %% [markdown]
# ### Cleaning the dataframe.

# %%
# List of column names to be dropped
columns_to_drop = ['description_length', 'company_name']
job_desp_df = job_desp_df.drop(columns_to_drop, axis=1)

# %%
job_desp_df
# Out:
#                                        job_description  \
# 0    minimum qualifications\nbachelors degree or eq...
# 1    description\nas an asc you will be highly infl...
# 2    its an amazing time to be joining netflix as w...
# 3    description\n\nweb designers looking to expand...
# 4    at trackfive weve got big goals were on a miss...
# ..                                                 ...
# 848  job description\n\nparttime\n\nmake big money ...
# 849  responsibilities\nparkers internship program w...
# 850   the borgen project is an innovative national ...
# 851  put the world on vacation\n\nat wyndham destin...
# 852  this job handles customer inquiries by telepho...
#
#                                         position_title
# 0                                     Sales Specialist
# 1                           Apple Solutions Consultant
# 2            Licensing Coordinator - Consumer Products
# 3                                         Web Designer
# 4                                        Web Developer
# ..                                                 ...
# 848                              Management Internship
# 849  Human Resources Internship - Corporate  (Year-...
# 850                     Writer / Journalist Internship
# 851          Inbound Customer Service / Sales (Remote)
# 852     Remote Inbound Customer Service Representative
#
# [853 rows x 2 columns]

# %% [markdown]
# ### Extracting 10-15 job descriptions for this task.

# %%
import pandas as pd

# Filter rows containing the keyword corresponding to the subdirectory of the Cvs in 'text_column'

accountant_df = job_desp_df[job_desp_df['position_title'].str.contains('accountant', case=False)]
advocate_df = job_desp_df[job_desp_df['position_title'].str.contains('ADVOCATE', case=False)]
agriculture_df = job_desp_df[job_desp_df['position_title'].str.contains('AGRICULTURE', case=False)]
apparel_df = job_desp_df[job_desp_df['position_title'].str.contains('APPAREL', case=False)]
arts_df = job_desp_df[job_desp_df['position_title'].str.contains('ARTS', case=False)]
automobile_df = job_desp_df[job_desp_df['position_title'].str.contains('AUTOMOBILE', case=False)]
avaition_df = job_desp_df[job_desp_df['position_title'].str.contains('AVIATION', case=False)]
banking_df = job_desp_df[job_desp_df['position_title'].str.contains('BANKING', case=False)]
bpo_df = job_desp_df[job_desp_df['position_title'].str.contains('BPO', case=False)]
buisdevp_df = job_desp_df[job_desp_df['position_title'].str.contains('BUSINESS-DEVELOPMENT', case=False)]
chef_df = job_desp_df[job_desp_df['position_title'].str.contains('CHEF', case=False)]
const_df = job_desp_df[job_desp_df['position_title'].str.contains('CONSTRUCTION', case=False)]
consultant_df = job_desp_df[job_desp_df['position_title'].str.contains('CONSULTANT', case=False)]
designer_df = job_desp_df[job_desp_df['position_title'].str.contains('DESIGNER', case=False)]
digimedia_df = job_desp_df[job_desp_df['position_title'].str.contains('DIGITAL-MEDIA', case=False)]
engg_df = job_desp_df[job_desp_df['position_title'].str.contains('ENGINEERING', case=False)]
finance_df = job_desp_df[job_desp_df['position_title'].str.contains('FINANCE', case=False)]
fitness_df = job_desp_df[job_desp_df['position_title'].str.contains('FITNESS', case=False)]
healthcare_df = job_desp_df[job_desp_df['position_title'].str.contains('HEALTHCARE', case=False)]
hr_df = job_desp_df[job_desp_df['position_title'].str.contains('HR', case=False)]
infotech_df = job_desp_df[job_desp_df['position_title'].str.contains('INFORMATION-TECHNOLOGY', case=False)]
pubrel_df = job_desp_df[job_desp_df['position_title'].str.contains('PUBLIC-RELATIONS', case=False)]
sales_df = job_desp_df[job_desp_df['position_title'].str.contains('SALES', case=False)]
teacher_df = job_desp_df[job_desp_df['position_title'].str.contains('TEACHER', case=False)]

# %% [markdown]
# ### Manually selecting 10 - 15 position_title for the model.

# %%
accountant_df
# Out:
#                                        job_description  \
# 418  brdisplaynonecss ul  limarginleftcss lipadding...
# 420  requirements for senior accountant\n minimum o...
# 421  our client a cpa firm located in central new j...
# 423  vita healthcare group is a leading name in the...
# 424   description robert half is seeking a staff ac...
# 567  about the job\nsenior accountant\nour client i...
# 569  salary range lower than you desire  but still ...
# 573  we are looking for a senior accountant job req...
# 777  in the minute it takes you to read this job de...
# 778  job description\n\nabout the role\n\nas part o...
# 779  greenlight is a fintech company that makes a d...
# 796  at mjh life sciences our success is measured b...
#
#                                         position_title
# 418  Holman Frenia Allison, PC Hiring for Audit Sta...
# 420              Senior Accountant, Banking (Lakewood)
# 421                             Audit Staff Accountant
# 423                                         Accountant
# 424                                         Accountant
# 567                                  Senior Accountant
# 569                                      Sr Accountant
# 573               Senior Accountant - Florham Park, NJ
# 777                         Senior Accountant (Remote)
# 778                Senior Accountant (Remote) (Remote)
# 779                                   Staff Accountant
# 796                                  Senior Accountant

# %%
advocate_df
# Out:
#                                        job_description  \
# 340  social media advocate\n\ngrassroots education ...
# 664  just an idea\n\njob details\njob type\nparttim...
# 679  fulltime entry level  great way to get hands o...
# 680  job description\n\nthe patient advocate will p...
# 681  lets do great things together\n\nfounded in or...
# 682  this job description states that it is remote ...
# 724  this is a fulltime position i know this is not...
#
#                                         position_title
# 340                          Remote Education Advocate
# 664                       Part-time   Patient Advocate
# 679                 Remote Patient Advocate Specialist
# 680  $17.50hr - Patient Advocate - Part Time Positi...
# 681                    Member Health Advocate ~ remote
# 682                   Bilingual Care Advocate (Hebrew)
# 724              Advocate, Patient Empowerment- REMOTE

# %%
agriculture_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
apparel_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
arts_df
# Out:
#                                        job_description  \
# 721  this position will cover womens health and cli...
#
#                                         position_title
# 721  Account Executive, Urology - Ohio and parts of...

# %%
automobile_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
avaition_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
banking_df
# Out:
#                                        job_description  \
# 420  requirements for senior accountant\n minimum o...
# 449  job profile\n\nposition overview\n\nat pnc our...
# 529  how would you like to join a successful and gr...
# 758  about working at commerce\n\nwouldnt it be gre...
#
#                                       position_title
# 420            Senior Accountant, Banking (Lakewood)
# 449  Sales Leader I - Business Banking Sales Manager
# 529                        Banking Center Supervisor
# 758            Business Banking Relationship Manager

# %%
bpo_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
buisdevp_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
chef_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
const_df
# Out:
#                                        job_description  \
# 235  construction project manager\n\ncleveland oh o...
# 404  here at shake shack we take care of each other...
# 405  we have an immediate need for  local or remote...
# 406  job description\n\nwe are currently seeking a ...
# 407  circustrix\n\nconstruction project manager\n\n...
# 408  position summary\n\nthe construction project m...
# 409  job title\n\nproject manager construction mana...
# 410  construction project managerremote flexibility...
# 411  akron  ohio  united states of america clevelan...
# 532  full job description \n\ncommercial constructi...
# 568  about the job\nour client a stable service org...
# 574  overview\nlocation of construction pm currentl...
# 575  job details\ndescription\nthe purpose of your ...
#
#                                         position_title
# 235                       Construction Project Manager
# 404              Construction Project Manager - Remote
# 405  (3) Construction Project Managers (Remote) (in...
# 406              Construction Project Manager (Remote)
# 407              Construction Project Manager (Remote)
# 408              Construction Project Manager - Remote
# 409  Project Manager, Construction Manager (Remote)...
# 410         REMOTE FLEX - Construction Project Manager
# 411  Construction Project Manager- (Remote in Detro...
# 532                    Commercial Construction Manager
# 568        Assistant Controller- Construction Industry
# 574                       Construction Project Manager
# 575                       Construction Project Manager

# %%
consultant_df
# Out:
#                                        job_description  \
# 1    description\nas an asc you will be highly infl...
# 21   company overview\n\nexechq is a consulting fir...
# 249  we go beyond the obvious using intelligence pa...
# 649  job details\nsalary\n   a year\njob type\nfull...
# 733  job details\n\ndescription\n\nthe sales associ...
# 745  our bassett design consultants are responsible...
# 746  job description\nrequisition id \nour busy new...
# 772  one of our clients a global market research co...
#
#                                         position_title
# 1                           Apple Solutions Consultant
# 21            Chief Executive Officer - CEO Consultant
# 249                               Ecommerce Consultant
# 649                  Retail Furniture Sales Consultant
# 733    Sales Associate / Design Consultant - Full Time
# 745                                  Design Consultant
# 746  Design Consultant- Interior Design/Sales Consu...
# 772               Programmer Analyst with R Consultant

# %%
designer_df
# Out:
#                                        job_description  \
# 3    description\n\nweb designers looking to expand...
# 6    about the position\n\nthe web designer is resp...
# 7    job description\n\nzander insurance group is o...
# 8    tuff is a growth marketing team working with c...
# 9    type of requisition regular\n\nclearance level...
# 12    we are seeking a senior ui designer who relis...
# 14   if youre passionate about building a better fu...
# 15   the apply with seek option will be utilized fo...
# 378  sonneman a way of light is seeking an experien...
#
#                    position_title
# 3                    Web Designer
# 6         Remote Website Designer
# 7                    Web Designer
# 8                    Web Designer
# 9                SR. Web Designer
# 12             Senior UI Designer
# 14                UI Web Designer
# 15   Senior Web Designer (REMOTE)
# 378       Senior graphic designer

# %%
digimedia_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
engg_df
# Out:
#                                        job_description  \
# 32   gaming\n\nwelcome to the world of landbased ga...
# 417  passionate about precision medicine and advanc...
# 528  job summary\n\nrandstad federal\n\nwe have ove...
#
#                             position_title
# 32          Associate Software Engineering
# 417  Engineering Lead - Analytics Platform
# 528                   Software Engineering

# %%
finance_df
# Out:
#                                        job_description  \
# 453  createme is a research and development company...
# 454  company description\nproject finds mission is ...
# 456  vp of finance about flywheel flywheel software...
# 457  a tech services company in new york city is cu...
#
#                           position_title
# 453              Senior Director Finance
# 454                  Director of Finance
# 456          VP of Finance (East Meadow)
# 457  Director - FP&A / Corporate Finance

# %%
fitness_df
# Out:
#                                        job_description  \
# 284  orangetheory fitness seven corners\n\nhonors h...
# 285  strength and conditioning jobs in virginia usa...
#
#                                         position_title
# 284                                      Fitness Coach
# 285  Strength & Conditioning Coach Jobs at Onelife ...

# %%
healthcare_df
# Out:
#                                        job_description  \
# 23   chief executive officer  healthcare\n\ncolumbu...
# 267  work for one of the worlds best health care sy...
# 519  job description\n\njob summary\n\nmolina healt...
# 786  healthcare administrative assistant  urgent hi...
#
#                                         position_title
# 23     Chief Executive Officer - Healthcare - Columbus
# 267   Talent Acquisition Advisor (Healthcare)   REMOTE
# 519                            VP, Healthcare Services
# 786  Healthcare Administrative Assistant – Urgent H...

# %%
hr_df
# Out:
#                                        job_description  \
# 82   about\nmacys is proudly americas department st...
# 87   marriott international portfolio of brands inc...
# 401  company background\n\n  \n\ncrane co is headqu...
# 481  job overview\nprovide support to members of an...
# 482  about the teamat doordash people are our most ...
# 483  scale is growing and so is our people team wer...
# 484  engaging our growth mindset the nielsen media ...
# 600  position description\n\nlocation new york ny\n...
# 680  job description\n\nthe patient advocate will p...
# 737  customer service representative\nrequirements\...
# 842  be unstoppable with us\n\ntmobile is synonymou...
#
#                                         position_title
# 82   Retail Commission Sales Associate - Fine Jewel...
# 87               Utility Cleaner - Kitchen ($19.77/hr)
# 401                              HR Director, Americas
# 481       Sr. HR Business Partner (Hybrid/Remote Role)
# 482                         Senior HR Business Partner
# 483                                      HR Generalist
# 484               HR Initiatives Program Lead (Remote)
# 600                Development Associate, Philanthropy
# 680  $17.50hr - Patient Advocate - Part Time Positi...
# 737    Remote Customer Service Representative ($16/hr)
# 842  T Mobile Work From Home – Customer Service Ass...

# %%
infotech_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
pubrel_df
# Out:
# Empty DataFrame
# Columns: [job_description, position_title]
# Index: []

# %%
sales_df
# Out:
#                                        job_description  \
# 0    minimum qualifications\nbachelors degree or eq...
# 54   job summary\n\nunder general supervision this ...
# 55   position type  full time\n\ntype of hire  expe...
# 56   we are hiring a sales manager\n\nsummary\n\nbe...
# 58   account executive  columbus oh  amo sales and ...
# ..                                                 ...
# 826  we inspire purposefilled living that brings jo...
# 827  as one of our passionate fun and dedicated sal...
# 828   what this position is all aboutthe style advi...
# 829  job category retail\n\nrequisition number \n\n...
# 851  put the world on vacation\n\nat wyndham destin...
#
#                                         position_title
# 0                                     Sales Specialist
# 54                                     Sales Executive
# 55               Sales Executive III Client Management
# 56                                       Sales Manager
# 58   Account Executive - Columbus, OH - AMO Sales a...
# ..                                                 ...
# 826                          Furniture Sales Associate
# 827  Vans Retail Sales Associate (Beachwood Place M...
# 828  Luxury Sales Stylist - Mens Combo - Saks Fifth...
# 829                             Retail Sales Associate
# 851          Inbound Customer Service / Sales (Remote)
#
# [120 rows x 2 columns]

# %%
teacher_df
# Out:
#                                        job_description  \
# 337  job description\n\nwe are currently seeking a ...
# 338  description\n\nour teachers bring warmth patie...
# 377   jobid \n\nposition type\n\ndistrictart\n\ndat...
#
#                                       position_title
# 337  Special Education Teacher 2022/2023 School Year
# 338                Teachers at Alpha Park KinderCare
# 377                                      Art Teacher

# %% [markdown]
# ### Selecting the 10 - 15 job roles with job description based on the above analysis and converting it into a dataframe.
# ### Index list - [423, 664, 721, 758, 574,  249, 9, 528, 454, 284, 519, 483, 818, 338]

# %%
# Select specific rows by their indices
selected_indices = [423, 664, 721, 758, 574, 249, 9, 528, 454, 284, 519, 483, 818, 338]  # Replace with the indices you want to select
sel_job_desp_df = job_desp_df.iloc[selected_indices]

# Print the new DataFrame
print(sel_job_desp_df)
# Out:
#                                        job_description  \
# 423  vita healthcare group is a leading name in the...
# 664  just an idea\n\njob details\njob type\nparttim...
# 721  this position will cover womens health and cli...
# 758  about working at commerce\n\nwouldnt it be gre...
# 574  overview\nlocation of construction pm currentl...
# 249  we go beyond the obvious using intelligence pa...
# 9    type of requisition regular\n\nclearance level...
# 528  job summary\n\nrandstad federal\n\nwe have ove...
# 454  company description\nproject finds mission is ...
# 284  orangetheory fitness seven corners\n\nhonors h...
# 519  job description\n\njob summary\n\nmolina healt...
# 483  scale is growing and so is our people team wer...
# 818  overview\n\nthe sales associate is a key emplo...
# 338  description\n\nour teachers bring warmth patie...
#
#                                         position_title
# 423                                         Accountant
# 664                       Part-time   Patient Advocate
# 721  Account Executive, Urology - Ohio and parts of...
# 758              Business Banking Relationship Manager
# 574                       Construction Project Manager
# 249                               Ecommerce Consultant
# 9                                     SR. Web Designer
# 528                               Software Engineering
# 454                                Director of Finance
# 284                                      Fitness Coach
# 519                            VP, Healthcare Services
# 483                                      HR Generalist
# 818                                    Sales Associate
# 338                  Teachers at Alpha Park KinderCare

# %%
# Reset the index
sel_job_desp_df = sel_job_desp_df.reset_index(drop=True)

# %%
sel_job_desp_df
# Out:
#                                       job_description  \
# 0   vita healthcare group is a leading name in the...
# 1   just an idea\n\njob details\njob type\nparttim...
# 2   this position will cover womens health and cli...
# 3   about working at commerce\n\nwouldnt it be gre...
# 4   overview\nlocation of construction pm currentl...
# 5   we go beyond the obvious using intelligence pa...
# 6   type of requisition regular\n\nclearance level...
# 7   job summary\n\nrandstad federal\n\nwe have ove...
# 8   company description\nproject finds mission is ...
# 9   orangetheory fitness seven corners\n\nhonors h...
# 10  job description\n\njob summary\n\nmolina healt...
# 11  scale is growing and so is our people team wer...
# 12  overview\n\nthe sales associate is a key emplo...
# 13  description\n\nour teachers bring warmth patie...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Removing punctuation.

# %%
import pandas as pd
import string  # Import the 'string' module


# Function to remove punctuation
def remove_punctuation(text):
    # Define a string of punctuation characters
    punctuations = string.punctuation
    
    # Use a regular expression to replace all punctuation characters with an empty string
    text = ''.join([char for char in text if char not in punctuations])
    
    return text

# Apply the remove_punctuation function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(remove_punctuation)

# Display the DataFrame with punctuation removed
print(sel_job_desp_df)
# Out:
#                                       job_description  \
# 0   vita healthcare group is a leading name in the...
# 1   just an idea\n\njob details\njob type\nparttim...
# 2   this position will cover womens health and cli...
# 3   about working at commerce\n\nwouldnt it be gre...
# 4   overview\nlocation of construction pm currentl...
# 5   we go beyond the obvious using intelligence pa...
# 6   type of requisition regular\n\nclearance level...
# 7   job summary\n\nrandstad federal\n\nwe have ove...
# 8   company description\nproject finds mission is ...
# 9   orangetheory fitness seven corners\n\nhonors h...
# 10  job description\n\njob summary\n\nmolina healt...
# 11  scale is growing and so is our people team wer...
# 12  overview\n\nthe sales associate is a key emplo...
# 13  description\n\nour teachers bring warmth patie...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %% [markdown]
# ### Removing irrelevant information.

# %%
# Function to remove newline characters
def remove_newlines(text):
    # Use str.replace() to replace '\n' with an empty string
    text = text.replace('\n', '')
    
    return text

# Apply the remove_newlines function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(remove_newlines)

# Display the DataFrame with newline characters removed
print(sel_job_desp_df)
# Out:
#                                       job_description  \
# 0   vita healthcare group is a leading name in the...
# 1   just an ideajob detailsjob typeparttimequalifi...
# 2   this position will cover womens health and cli...
# 3   about working at commercewouldnt it be great t...
# 4   overviewlocation of construction pm currently ...
# 5   we go beyond the obvious using intelligence pa...
# 6   type of requisition regularclearance level mus...
# 7   job summaryrandstad federalwe have over a deca...
# 8   company descriptionproject finds mission is to...
# 9   orangetheory fitness seven cornershonors holdi...
# 10  job descriptionjob summarymolina healthcare se...
# 11  scale is growing and so is our people team wer...
# 12  overviewthe sales associate is a key employee ...
# 13  descriptionour teachers bring warmth patience ...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %% [markdown]
# ### Lowercasing: Converting all text to lowercase for consistency.

# %%
# Function to remove newline characters and convert to lowercase
def preprocess_text(text):
    # Remove newline characters and convert to lowercase
    text = text.replace('\n', '').lower()
    
    return text

# Apply the preprocess_text function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(preprocess_text)

# Display the DataFrame with newline characters removed and text converted to lowercase
print(sel_job_desp_df)
# Out:
#                                       job_description  \
# 0   vita healthcare group is a leading name in the...
# 1   just an ideajob detailsjob typeparttimequalifi...
# 2   this position will cover womens health and cli...
# 3   about working at commercewouldnt it be great t...
# 4   overviewlocation of construction pm currently ...
# 5   we go beyond the obvious using intelligence pa...
# 6   type of requisition regularclearance level mus...
# 7   job summaryrandstad federalwe have over a deca...
# 8   company descriptionproject finds mission is to...
# 9   orangetheory fitness seven cornershonors holdi...
# 10  job descriptionjob summarymolina healthcare se...
# 11  scale is growing and so is our people team wer...
# 12  overviewthe sales associate is a key employee ...
# 13  descriptionour teachers bring warmth patience ...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from collections import Counter

# Function to tokenize and count words
def word_frequency(text):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove punctuation and convert to lowercase
    words = [word.lower() for word in words if word.isalnum()]
    
    # Filter out stopwords
    words = [word for word in words if word not in stopwords.words('english')]
    
    # Calculate word frequencies
    word_freq = dict(Counter(words))
    
    return word_freq

# Create a dictionary to store word frequencies for each job description
word_freq_dict = {}

# Apply the word_frequency function to the "job_description" column and store in the dictionary
for index, row in sel_job_desp_df.iterrows():
    word_freq_dict[index] = word_frequency(row['job_description'])

# Print the dictionary of word frequencies
print(word_freq_dict)
# Out:
# {0: {'vita': 1, 'healthcare': 1, 'group': 1, 'leading': 1, 'name': 1, 'skilled': 1, 'nursing': 2, 'world': 2, 'providing': 2, 'class': 1, 'care': 1, 'community': 4, 'decadewe': 1, 'seeking': 1, 'dedicated': 1, 'accountant': 2, 'assist': 2, 'operating': 1, 'facilitiesif': 1, 'looking': 1, 'incredible': 2, 'office': 2, 'environment': 1, 'paid': 2, 'training': 2, 'room': 1, 'growth': 1, 'may': 1, 'position': 1, 'youthe': 1, 'key': 1, 'team': 2, 'member': 1, 'responsible': 1, 'accounting': 5, 'guidance': 1, 'management': 1, 'relates': 1, 'overall': 1, 'activities': 1, 'programs': 1, 'communityaccountant': 1, 'responsibilities': 1, 'provide': 1, 'support': 2, 'communities': 2, 'executive': 1, 'directors': 1, 'managers': 1, 'prepare': 1, 'journal': 1, 'entries': 1, 'maintain': 2, 'accounts': 2, 'facilitate': 1, 'monthly': 1, 'financial': 1, 'calls': 1, 'payable': 1, 'receivable': 1, 'account': 1, 'reconciliation': 1, 'filing': 1, 'process': 1, 'payrolls': 1, 'compliance': 1, 'company': 1, 'policies': 1, 'state': 1, 'regulationsaccountant': 1, 'qualifications': 1, 'prior': 1, 'bookkeeping': 1, 'experience': 2, 'associate': 1, 'bachelors': 1, 'degree': 1, 'preferred': 1, 'least': 1, 'years': 1, 'ability': 1, 'communicate': 1, 'effectively': 1, 'concisely': 1, 'written': 1, 'oral': 1, 'means': 1, 'associates': 1, 'vendors': 1, 'proficiency': 1, 'software': 1, 'tools': 1, 'yardi': 1, 'quickbooks': 1, 'microsoft': 1, 'excel': 1, 'organized': 1, 'able': 1, 'prioritize': 1, 'work': 1, 'part': 1, 'informal': 1, 'environmentaccountant': 1, 'benefits': 2, 'competitive': 1, 'wages': 1, 'health': 1, 'insurance': 1, 'eligible': 1, 'voluntary': 1, 'disability': 1, 'accident': 1, 'life': 1, 'generous': 1, 'time': 1}, 1: {'ideajob': 1, 'detailsjob': 1, 'typeparttimequalificationscase': 1, 'management': 2, 'year': 4, 'preferredspanish': 1, 'preferredindeeds': 1, 'salary': 2, 'guidenot': 1, 'provided': 1, 'employer': 1, 'indeeds': 1, 'estimated': 1, 'role': 1, 'brooklyn': 1, 'nyreport': 1, 'inaccurate': 1, 'salaryfull': 1, 'job': 1, 'descriptionposition': 1, 'summary': 1, 'supervision': 1, 'director': 1, 'assistant': 1, 'patient': 1, 'advocate': 1, 'shall': 2, 'ensure': 1, 'patients': 5, 'aware': 1, 'empowered': 1, 'exercise': 1, 'rights': 3, 'nysdoh': 2, 'heshe': 1, 'address': 1, 'patientsurrogate': 7, 'questions': 1, 'concerns': 2, 'complaints': 2, 'work': 3, 'toward': 1, 'mutually': 2, 'acceptable': 1, 'solutions': 1, 'bill': 1, 'jcaho': 1, 'standarddutiesresponsibilities': 1, 'serves': 1, 'liaison': 1, 'families': 1, 'medical': 3, 'center': 3, 'staff': 2, 'striving': 1, 'make': 1, 'user': 1, 'friendly': 1, 'assists': 3, 'interpreting': 1, 'hospitals': 1, 'policies': 1, 'procedures': 2, 'requested': 3, 'understanding': 1, 'responsibilities': 1, 'investigates': 1, 'articulated': 1, 'surrogates': 1, 'involves': 1, 'appropriate': 2, 'departments': 1, 'necessary': 1, 'works': 1, 'achieve': 1, 'satisfactory': 1, 'resolution': 1, 'provide': 2, 'assistance': 1, 'desiring': 1, 'complete': 1, 'advance': 1, 'directive': 1, 'provides': 1, 'written': 1, 'response': 3, 'findings': 1, 'investigation': 1, 'satisfied': 1, 'refers': 2, 'new': 1, 'york': 1, 'state': 1, 'department': 1, 'healths': 1, 'office': 1, 'referring': 1, 'services': 1, 'resources': 1, 'responds': 1, 'himherself': 1, 'alternatives': 1, 'available': 1, 'documents': 1, 'interactions': 2, 'using': 1, 'departmentally': 1, 'established': 1, 'timelines': 1, 'interpreters': 2, 'list': 1, 'language': 1, 'barriers': 1, 'present': 1, 'communication': 1, 'problems': 1, 'evaluates': 1, 'interprets': 1, 'information': 1, 'gathered': 1, 'order': 1, 'spot': 1, 'patterns': 1, 'trends': 1, 'performs': 1, 'duties': 1, 'requiredformal': 1, 'education': 2, 'jobrelated': 2, 'experience': 1, 'position': 1, 'requires': 1, 'minimum': 2, 'formal': 1, 'associate': 1, 'degree': 2, 'certification': 1, 'equivalent': 1, 'years': 1, 'experiencedesired': 1, 'required': 1, 'criteria': 1, 'includebachelors': 1, 'preferredbili ...

# %% [markdown]
# ### Removing stop words: Common words like "and," "the," "is" are often removed using custom stop words list and also inbuilt stop word list

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords

# Function to remove stopwords from text
def remove_stopwords(text):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove stopwords
    words = [word for word in words if word.lower() not in stopwords.words('english')]
    
    # Rejoin the words to form cleaned text
    cleaned_text = ' '.join(words)
    
    return cleaned_text

# Apply the remove_stopwords function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(remove_stopwords)

# Display the DataFrame with stopwords removed
print(sel_job_desp_df)
# Out:
#                                       job_description  \
# 0   vita healthcare group leading name skilled nur...
# 1   ideajob detailsjob typeparttimequalificationsc...
# 2   position cover womens health clinical accounts...
# 3   working commercewouldnt great build career ban...
# 4   overviewlocation construction pm currently see...
# 5   go beyond obvious using intelligence passion c...
# 6   type requisition regularclearance level must a...
# 7   job summaryrandstad federalwe decade experienc...
# 8   company descriptionproject finds mission provi...
# 9   orangetheory fitness seven cornershonors holdi...
# 10  job descriptionjob summarymolina healthcare se...
# 11  scale growing people team looking people opera...
# 12  overviewthe sales associate key employee whose...
# 13  descriptionour teachers bring warmth patience ...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from collections import Counter

# Function to tokenize and count words
def word_frequency(text):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove punctuation and convert to lowercase
    words = [word.lower() for word in words if word.isalnum()]
    
    # Filter out stopwords
    words = [word for word in words if word not in stopwords.words('english')]
    
    # Calculate word frequencies
    word_freq = dict(Counter(words))
    
    return word_freq

# Create a dictionary to store word frequencies for each job description
word_freq_dict = {}

# Apply the word_frequency function to the "job_description" column and store in the dictionary
for index, row in sel_job_desp_df.iterrows():
    word_freq_dict[index] = word_frequency(row['job_description'])

# Print the dictionary of word frequencies
print(word_freq_dict)
# Out:
# {0: {'vita': 1, 'healthcare': 1, 'group': 1, 'leading': 1, 'name': 1, 'skilled': 1, 'nursing': 2, 'world': 2, 'providing': 2, 'class': 1, 'care': 1, 'community': 4, 'decadewe': 1, 'seeking': 1, 'dedicated': 1, 'accountant': 2, 'assist': 2, 'operating': 1, 'facilitiesif': 1, 'looking': 1, 'incredible': 2, 'office': 2, 'environment': 1, 'paid': 2, 'training': 2, 'room': 1, 'growth': 1, 'may': 1, 'position': 1, 'youthe': 1, 'key': 1, 'team': 2, 'member': 1, 'responsible': 1, 'accounting': 5, 'guidance': 1, 'management': 1, 'relates': 1, 'overall': 1, 'activities': 1, 'programs': 1, 'communityaccountant': 1, 'responsibilities': 1, 'provide': 1, 'support': 2, 'communities': 2, 'executive': 1, 'directors': 1, 'managers': 1, 'prepare': 1, 'journal': 1, 'entries': 1, 'maintain': 2, 'accounts': 2, 'facilitate': 1, 'monthly': 1, 'financial': 1, 'calls': 1, 'payable': 1, 'receivable': 1, 'account': 1, 'reconciliation': 1, 'filing': 1, 'process': 1, 'payrolls': 1, 'compliance': 1, 'company': 1, 'policies': 1, 'state': 1, 'regulationsaccountant': 1, 'qualifications': 1, 'prior': 1, 'bookkeeping': 1, 'experience': 2, 'associate': 1, 'bachelors': 1, 'degree': 1, 'preferred': 1, 'least': 1, 'years': 1, 'ability': 1, 'communicate': 1, 'effectively': 1, 'concisely': 1, 'written': 1, 'oral': 1, 'means': 1, 'associates': 1, 'vendors': 1, 'proficiency': 1, 'software': 1, 'tools': 1, 'yardi': 1, 'quickbooks': 1, 'microsoft': 1, 'excel': 1, 'organized': 1, 'able': 1, 'prioritize': 1, 'work': 1, 'part': 1, 'informal': 1, 'environmentaccountant': 1, 'benefits': 2, 'competitive': 1, 'wages': 1, 'health': 1, 'insurance': 1, 'eligible': 1, 'voluntary': 1, 'disability': 1, 'accident': 1, 'life': 1, 'generous': 1, 'time': 1}, 1: {'ideajob': 1, 'detailsjob': 1, 'typeparttimequalificationscase': 1, 'management': 2, 'year': 4, 'preferredspanish': 1, 'preferredindeeds': 1, 'salary': 2, 'guidenot': 1, 'provided': 1, 'employer': 1, 'indeeds': 1, 'estimated': 1, 'role': 1, 'brooklyn': 1, 'nyreport': 1, 'inaccurate': 1, 'salaryfull': 1, 'job': 1, 'descriptionposition': 1, 'summary': 1, 'supervision': 1, 'director': 1, 'assistant': 1, 'patient': 1, 'advocate': 1, 'shall': 2, 'ensure': 1, 'patients': 5, 'aware': 1, 'empowered': 1, 'exercise': 1, 'rights': 3, 'nysdoh': 2, 'heshe': 1, 'address': 1, 'patientsurrogate': 7, 'questions': 1, 'concerns': 2, 'complaints': 2, 'work': 3, 'toward': 1, 'mutually': 2, 'acceptable': 1, 'solutions': 1, 'bill': 1, 'jcaho': 1, 'standarddutiesresponsibilities': 1, 'serves': 1, 'liaison': 1, 'families': 1, 'medical': 3, 'center': 3, 'staff': 2, 'striving': 1, 'make': 1, 'user': 1, 'friendly': 1, 'assists': 3, 'interpreting': 1, 'hospitals': 1, 'policies': 1, 'procedures': 2, 'requested': 3, 'understanding': 1, 'responsibilities': 1, 'investigates': 1, 'articulated': 1, 'surrogates': 1, 'involves': 1, 'appropriate': 2, 'departments': 1, 'necessary': 1, 'works': 1, 'achieve': 1, 'satisfactory': 1, 'resolution': 1, 'provide': 2, 'assistance': 1, 'desiring': 1, 'complete': 1, 'advance': 1, 'directive': 1, 'provides': 1, 'written': 1, 'response': 3, 'findings': 1, 'investigation': 1, 'satisfied': 1, 'refers': 2, 'new': 1, 'york': 1, 'state': 1, 'department': 1, 'healths': 1, 'office': 1, 'referring': 1, 'services': 1, 'resources': 1, 'responds': 1, 'himherself': 1, 'alternatives': 1, 'available': 1, 'documents': 1, 'interactions': 2, 'using': 1, 'departmentally': 1, 'established': 1, 'timelines': 1, 'interpreters': 2, 'list': 1, 'language': 1, 'barriers': 1, 'present': 1, 'communication': 1, 'problems': 1, 'evaluates': 1, 'interprets': 1, 'information': 1, 'gathered': 1, 'order': 1, 'spot': 1, 'patterns': 1, 'trends': 1, 'performs': 1, 'duties': 1, 'requiredformal': 1, 'education': 2, 'jobrelated': 2, 'experience': 1, 'position': 1, 'requires': 1, 'minimum': 2, 'formal': 1, 'associate': 1, 'degree': 2, 'certification': 1, 'equivalent': 1, 'years': 1, 'experiencedesired': 1, 'required': 1, 'criteria': 1, 'includebachelors': 1, 'preferredbili ...

# %% [markdown]
# ### Lemmatization: Reducing words to their base form.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Initialize the WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to remove stopwords and perform lemmatization
def preprocess_text(text):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove stopwords and apply lemmatization
    words = [lemmatizer.lemmatize(word.lower()) for word in words if word.lower() not in stopwords.words('english')]
    
    # Rejoin the words to form cleaned text
    cleaned_text = ' '.join(words)
    
    return cleaned_text

# Apply the preprocess_text function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(preprocess_text)

# Display the DataFrame with stopwords removed and lemmatization applied
print(sel_job_desp_df)
# Out:
#                                       job_description  \
# 0   vita healthcare group leading name skilled nur...
# 1   ideajob detailsjob typeparttimequalificationsc...
# 2   position cover woman health clinical account t...
# 3   working commercewouldnt great build career ban...
# 4   overviewlocation construction pm currently see...
# 5   go beyond obvious using intelligence passion c...
# 6   type requisition regularclearance level must a...
# 7   job summaryrandstad federalwe decade experienc...
# 8   company descriptionproject find mission provid...
# 9   orangetheory fitness seven cornershonors holdi...
# 10  job descriptionjob summarymolina healthcare se...
# 11  scale growing people team looking people opera...
# 12  overviewthe sale associate key employee whose ...
# 13  descriptionour teacher bring warmth patience u...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %%
sel_job_desp_df
# Out:
#                                       job_description  \
# 0   vita healthcare group leading name skilled nur...
# 1   ideajob detailsjob typeparttimequalificationsc...
# 2   position cover woman health clinical account t...
# 3   working commercewouldnt great build career ban...
# 4   overviewlocation construction pm currently see...
# 5   go beyond obvious using intelligence passion c...
# 6   type requisition regularclearance level must a...
# 7   job summaryrandstad federalwe decade experienc...
# 8   company descriptionproject find mission provid...
# 9   orangetheory fitness seven cornershonors holdi...
# 10  job descriptionjob summarymolina healthcare se...
# 11  scale growing people team looking people opera...
# 12  overviewthe sale associate key employee whose ...
# 13  descriptionour teacher bring warmth patience u...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %% [markdown]
# ### Utilizing the DistilBERT model and tokenizer to extract embeddings from the "job_description" column in a DataFrame and replaces the text with these embeddings in a single line.

# %%
import pandas as pd
from transformers import DistilBertTokenizer, DistilBertModel
import torch


# Initialize the DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased")

# Function to extract DistilBERT embeddings
def extract_embeddings(text):
    # Tokenize the text
    input_ids = tokenizer(text, return_tensors='pt', padding=True, truncation=True)["input_ids"]
    
    # Extract embeddings using the model
    with torch.no_grad():
        outputs = model(input_ids)
    
    # Extract the embeddings for the [CLS] token
    embeddings = outputs.last_hidden_state[:, 0, :].numpy()
    
    return embeddings

# Apply the extract_embeddings function to the "job_description" column
sel_job_desp_df['job_description'] = sel_job_desp_df['job_description'].apply(extract_embeddings)

# Display the DataFrame with embeddings in the "job_description" column
print(sel_job_desp_df[['job_description']])
# Out:
#                                       job_description
# 0   [[-0.2349301, 0.23931362, -0.0066209063, 0.012...
# 1   [[-0.48101765, 0.12456707, -0.012981296, -0.10...
# 2   [[-0.41524535, 0.18179955, -0.009882465, -0.07...
# 3   [[-0.52538115, 0.12988769, -0.02525802, -0.068...
# 4   [[-0.37318966, 0.15656477, -0.053767644, -0.08...
# 5   [[-0.4030924, 0.10880383, 0.05623078, -0.03711...
# 6   [[-0.43022907, 0.1107656, 0.030928671, -0.0072...
# 7   [[-0.3756775, 0.21737866, -0.23779063, -0.0189...
# 8   [[-0.3724737, 0.18712647, -0.061148852, -0.016...
# 9   [[-0.37973148, 0.110710956, 0.011414934, -0.04...
# 10  [[-0.48247072, 0.18552431, 0.028860055, 0.0378...
# 11  [[-0.46628553, 0.1547784, 0.03934186, -0.01833...
# 12  [[-0.5785006, 0.20030381, -0.14895616, -0.1038...
# 13  [[-0.29803705, 0.1478748, 0.022891663, 0.12934...

# %%
sel_job_desp_df
# Out:
#                                       job_description  \
# 0   [[-0.2349301, 0.23931362, -0.0066209063, 0.012...
# 1   [[-0.48101765, 0.12456707, -0.012981296, -0.10...
# 2   [[-0.41524535, 0.18179955, -0.009882465, -0.07...
# 3   [[-0.52538115, 0.12988769, -0.02525802, -0.068...
# 4   [[-0.37318966, 0.15656477, -0.053767644, -0.08...
# 5   [[-0.4030924, 0.10880383, 0.05623078, -0.03711...
# 6   [[-0.43022907, 0.1107656, 0.030928671, -0.0072...
# 7   [[-0.3756775, 0.21737866, -0.23779063, -0.0189...
# 8   [[-0.3724737, 0.18712647, -0.061148852, -0.016...
# 9   [[-0.37973148, 0.110710956, 0.011414934, -0.04...
# 10  [[-0.48247072, 0.18552431, 0.028860055, 0.0378...
# 11  [[-0.46628553, 0.1547784, 0.03934186, -0.01833...
# 12  [[-0.5785006, 0.20030381, -0.14895616, -0.1038...
# 13  [[-0.29803705, 0.1478748, 0.022891663, 0.12934...
#
#                                        position_title
# 0                                          Accountant
# 1                        Part-time   Patient Advocate
# 2   Account Executive, Urology - Ohio and parts of...
# 3               Business Banking Relationship Manager
# 4                        Construction Project Manager
# 5                                Ecommerce Consultant
# 6                                    SR. Web Designer
# 7                                Software Engineering
# 8                                 Director of Finance
# 9                                       Fitness Coach
# 10                            VP, Healthcare Services
# 11                                      HR Generalist
# 12                                    Sales Associate
# 13                  Teachers at Alpha Park KinderCare

# %% [markdown]
# ### This code extracts text content, job roles, skills, and education information from PDF files in a specified folder, organizes the data into DataFrames, and stores them in a dictionary with subfolder names as keys.

# %%
import os
import re
import fitz  # PyMuPDF
import pandas as pd

# Function to extract text content from a PDF file using PyMuPDF
def extract_text_from_pdf(pdf_file_path):
    doc = fitz.open(pdf_file_path)
    text = ""
    for page_num in range(doc.page_count):
        page = doc[page_num]
        text += page.get_text()
    return text

# Function to extract the job role from the first line of text in a PDF file
def extract_job_role_from_pdf(pdf_file_path):
    job_role = ""
    try:
        pdf_text = extract_text_from_pdf(pdf_file_path)
        
        # Extract first line (Job Role)
        job_role = pdf_text.split('\n')[0].strip()
    except Exception as e:
        print(f"Error extracting job role from {pdf_file_path}: {str(e)}")
    return job_role

# Function to extract the skills section from a PDF file's text content
def extract_skills_from_pdf(pdf_file_path):
    skills = ""
    try:
        pdf_text = extract_text_from_pdf(pdf_file_path)
        
        # Extract the "Skills" section
        in_skills_section = False
        lines = pdf_text.split('\n')
        
        for line in lines:
            if "Skills" in line:
                in_skills_section = True
            elif in_skills_section and line.strip() == "":
                break  # Exit the skills section when encountering an empty line
            elif in_skills_section:
                skills += line + "\n"
    except Exception as e:
        print(f"Error extracting skills from {pdf_file_path}: {str(e)}")
    return skills

# Function to extract the education section from a PDF file's text content
def extract_education_from_pdf(pdf_file_path):
    education = ""
    try:
        pdf_text = extract_text_from_pdf(pdf_file_path)
        
        # Extract the "Education" section
        in_education_section = False
        lines = pdf_text.split('\n')
        
        for line in lines:
            if "Education" in line:
                in_education_section = True
            elif in_education_section and line.strip() == "":
                break  # Exit the education section when encountering an empty line
            elif in_education_section:
                education += line + "\n"
    except Exception as e:
        print(f"Error extracting education from {pdf_file_path}: {str(e)}")
    return education

# Function to extract job details from a folder of PDFs and organize them into a corpus
def extract_details_from_folder(root_folder):
    corpus = {}

    for dirpath, dirnames, filenames in os.walk(root_folder):
        for file in filenames:
            if file.endswith(".pdf"):
                pdf_path = os.path.join(dirpath, file)
                job_role = extract_job_role_from_pdf(pdf_path)
                skills = extract_skills_from_pdf(pdf_path)
                education = extract_education_from_pdf(pdf_path)
                
                # Remove "Skills" and "Education" labels
                skills = skills.replace("Skills", "").strip()
                education = education.replace("Education", "").strip()
                
                # Get the PDF file name
                pdf_file_name = os.path.basename(pdf_path)
                
                # Create a subfolder-based corpus
                subfolder = os.path.basename(dirpath)
                if subfolder not in corpus:
                    corpus[subfolder] = {"PDF File Name": [], "Job Role": [], "Skills": [], "Education": []}
                
                corpus[subfolder]["PDF File Name"].append(pdf_file_name)
                corpus[subfolder]["Job Role"].append(job_role)
                corpus[subfolder]["Skills"].append(skills)
                corpus[subfolder]["Education"].append(education)

    return corpus

# Specify the root folder path containing subfolders with PDFs
root_folder = r"C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\candidate_cvs"

# Extract job details from the specified folder and organize them into DataFrames
extracted_corpus = extract_details_from_folder(root_folder)

# Create DataFrames for each subdirectory within the corpus
dataframes = {}
for subfolder, details_dict in extracted_corpus.items():
    df = pd.DataFrame(details_dict)
    dataframes[subfolder] = df

# Now, dataframes dictionary contains DataFrames for each subdirectory, and you can access them by their names.

# %% [markdown]
# ### Exporting extracted data from CVs pdf as csv.

# %%
# Specify the output folder where you want to save the exported CSV files
output_folder = r"C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data"

# Ensure the output folder exists, or create it if necessary
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Export each DataFrame as a CSV file
for subfolder, df in dataframes.items():
    csv_filename = os.path.join(output_folder, f"{subfolder}_job_details.csv")
    df.to_csv(csv_filename, index=False)
    print(f"Exported data for {subfolder} to {csv_filename}")
# Out:
# Exported data for ACCOUNTANT to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\ACCOUNTANT_job_details.csv
# Exported data for ADVOCATE to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\ADVOCATE_job_details.csv
# Exported data for AGRICULTURE to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\AGRICULTURE_job_details.csv
# Exported data for APPAREL to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\APPAREL_job_details.csv
# Exported data for ARTS to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\ARTS_job_details.csv
# Exported data for AUTOMOBILE to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\AUTOMOBILE_job_details.csv
# Exported data for AVIATION to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\AVIATION_job_details.csv
# Exported data for BANKING to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\BANKING_job_details.csv
# Exported data for BPO to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\BPO_job_details.csv
# Exported data for BUSINESS-DEVELOPMENT to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\BUSINESS-DEVELOPMENT_job_details.csv
# Exported data for CHEF to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\CHEF_job_details.csv
# Exported data for CONSTRUCTION to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\CONSTRUCTION_job_details.csv
# Exported data for CONSULTANT to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\CONSULTANT_job_details.csv
# Exported data for DESIGNER to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\DESIGNER_job_details.csv
# Exported data for DIGITAL-MEDIA to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\DIGITAL-MEDIA_job_details.csv
# Exported data for ENGINEERING to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\ENGINEERING_job_details.csv
# Exported data for FINANCE to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\FINANCE_job_details.csv
# Exported data for FITNESS to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\FITNESS_job_details.csv
# Exported data for HEALTHCARE to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\HEALTHCARE_job_details.csv
# Exported data for HR to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\HR_job_details.csv
# Exported data for INFORMATION-TECHNOLOGY to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\INFORMATION-TECHNOLOGY_job_details.csv
# Exported data for PUBLIC-RELATIONS to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\PUBLIC-RELATIONS_job_details.csv
# Exported data for SALES to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\SALES_job_details.csv
# Exported data for TEACHER to C:\Users\Vinith MH\OneDrive\Desktop\Capital Placement\exported_data\TEACHER_job_details.csv

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name              Job Role  \
# 0    10554236.pdf            ACCOUNTANT
# 1    10674770.pdf      STAFF ACCOUNTANT
# 2    11163645.pdf            ACCOUNTANT
# 3    11759079.pdf     SENIOR ACCOUNTANT
# 4    12065211.pdf     SENIOR ACCOUNTANT
# ..            ...                   ...
# 113  78403342.pdf            ACCOUNTANT
# 114  80053367.pdf    GENERAL ACCOUNTANT
# 115  82649935.pdf     SENIOR ACCOUNTANT
# 116  87635012.pdf  PRINCIPAL ACCOUNTANT
# 117  98559931.pdf    PAYROLL ACCOUNTANT
#
#                                                 Skills  \
# 0    Accounting; General Accounting; Accounts Payab...
# 1    accounting, accounts payable, Accounts Receiva...
# 2    accounts payables, accounts receivables, Accou...
# 3    accounting, balance sheet, budgets, client, cl...
# 4    Aderant/CMS\nExcel\nQuickBooks Pro\nSQL\nAcces...
# ..                                                 ...
# 113  Accounting, balance, budget, business analyst,...
# 114  Healthcare: Â \nSound, ethical and independent...
# 115
# 116  Microsoft Excel, Peachtree, PeopleSoft, SAP, S...
# 117  ACCOUNTING, A/P, attention to detail, bank rec...
#
#                                              Education
# 0    Northern Maine Community College 1994 Associat...
# 1    Bachelor of Science : Accounting , May 2010 Un...
# 2    Skills\naccounts payables, accounts receivable...
# 3    EMORY UNIVERSITY, Goizueta Business School 5 2...
# 4    Bachelor of Business Administration : Accounti...
# ..                                                 ...
# 113  Accounting Certificate : Accounting , 2012 Cec...
# 114  Bachelor of Science : Nursing , 2016 Californi...
# 115  Bachelor of Arts : Economics City College of N...
# 116  Master of Business Administration , Finance 20...
# 117  Bachelor of Science , Accounting May 2014 Will...
#
# [118 rows x 4 columns]

# %% [markdown]
# ### Combine "Job Role," "Skills," and "Education" columns into a single "Details" column, separating them with newline characters, and drop the individual columns for all DataFrames within the dataframes dictionary.

# %%
# Combine "Job Role," "Skills," and "Education" columns into a single column for all DataFrames
for subfolder, df in dataframes.items():
    # Combine the columns and separate them with newline characters
    df["Details"] = df["Job Role"] + "\n" + df["Skills"] + "\n" + df["Education"]
    
    # Drop the individual columns
    df.drop(columns=["Job Role", "Skills", "Education"], inplace=True)

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  ACCOUNTANT\nAccounting; General Accounting; Ac...
# 1    10674770.pdf  STAFF ACCOUNTANT\naccounting, accounts payable...
# 2    11163645.pdf  ACCOUNTANT\naccounts payables, accounts receiv...
# 3    11759079.pdf  SENIOR ACCOUNTANT\naccounting, balance sheet, ...
# 4    12065211.pdf  SENIOR ACCOUNTANT\nAderant/CMS\nExcel\nQuickBo...
# ..            ...                                                ...
# 113  78403342.pdf  ACCOUNTANT\nAccounting, balance, budget, busin...
# 114  80053367.pdf  GENERAL ACCOUNTANT\nHealthcare: Â \nSound, eth...
# 115  82649935.pdf  SENIOR ACCOUNTANT\n\nBachelor of Arts : Econom...
# 116  87635012.pdf  PRINCIPAL ACCOUNTANT\nMicrosoft Excel, Peachtr...
# 117  98559931.pdf  PAYROLL ACCOUNTANT\nACCOUNTING, A/P, attention...
#
# [118 rows x 2 columns]

# %% [markdown]
# # Cleaning CVs Data.
#
# ### Cleaning the "Details" column in each DataFrame within the dataframes dictionary by removing punctuation characters.

# %%
import re

# Function to remove punctuation from text
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# Iterate through the dataframes dictionary and clean text columns
for subfolder, df in dataframes.items():
    # Clean the "Details" column (assuming you've already combined the columns)
    df["Details"] = df["Details"].apply(remove_punctuation)

# Now, the "Details" column in each DataFrame within dataframes is cleaned from punctuation.

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  ACCOUNTANT\nAccounting General Accounting Acco...
# 1    10674770.pdf  STAFF ACCOUNTANT\naccounting accounts payable ...
# 2    11163645.pdf  ACCOUNTANT\naccounts payables accounts receiva...
# 3    11759079.pdf  SENIOR ACCOUNTANT\naccounting balance sheet bu...
# 4    12065211.pdf  SENIOR ACCOUNTANT\nAderantCMS\nExcel\nQuickBoo...
# ..            ...                                                ...
# 113  78403342.pdf  ACCOUNTANT\nAccounting balance budget business...
# 114  80053367.pdf  GENERAL ACCOUNTANT\nHealthcare Â \nSound ethic...
# 115  82649935.pdf  SENIOR ACCOUNTANT\n\nBachelor of Arts  Economi...
# 116  87635012.pdf  PRINCIPAL ACCOUNTANT\nMicrosoft Excel Peachtre...
# 117  98559931.pdf  PAYROLL ACCOUNTANT\nACCOUNTING AP attention to...
#
# [118 rows x 2 columns]

# %% [markdown]
# ### Remove newline characters from the "Details" column in each DataFrame within the dataframes dictionary.

# %%
# Iterate through the dataframes dictionary and remove newline characters
for subfolder, df in dataframes.items():
    # Remove newline characters from the "Details" column
    df["Details"] = df["Details"].str.replace('\n', ' ')

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  ACCOUNTANT Accounting General Accounting Accou...
# 1    10674770.pdf  STAFF ACCOUNTANT accounting accounts payable A...
# 2    11163645.pdf  ACCOUNTANT accounts payables accounts receivab...
# 3    11759079.pdf  SENIOR ACCOUNTANT accounting balance sheet bud...
# 4    12065211.pdf  SENIOR ACCOUNTANT AderantCMS Excel QuickBooks ...
# ..            ...                                                ...
# 113  78403342.pdf  ACCOUNTANT Accounting balance budget business ...
# 114  80053367.pdf  GENERAL ACCOUNTANT Healthcare Â  Sound ethical...
# 115  82649935.pdf  SENIOR ACCOUNTANT  Bachelor of Arts  Economics...
# 116  87635012.pdf  PRINCIPAL ACCOUNTANT Microsoft Excel Peachtree...
# 117  98559931.pdf  PAYROLL ACCOUNTANT ACCOUNTING AP attention to ...
#
# [118 rows x 2 columns]

# %% [markdown]
# ### Lowercasing: Converting all text to lowercase for consistency.

# %%
# Iterate through the dataframes dictionary and convert text to lowercase
for subfolder, df in dataframes.items():
    # Convert the "Details" column to lowercase
    df["Details"] = df["Details"].str.lower()

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  accountant accounting general accounting accou...
# 1    10674770.pdf  staff accountant accounting accounts payable a...
# 2    11163645.pdf  accountant accounts payables accounts receivab...
# 3    11759079.pdf  senior accountant accounting balance sheet bud...
# 4    12065211.pdf  senior accountant aderantcms excel quickbooks ...
# ..            ...                                                ...
# 113  78403342.pdf  accountant accounting balance budget business ...
# 114  80053367.pdf  general accountant healthcare â  sound ethical...
# 115  82649935.pdf  senior accountant  bachelor of arts  economics...
# 116  87635012.pdf  principal accountant microsoft excel peachtree...
# 117  98559931.pdf  payroll accountant accounting ap attention to ...
#
# [118 rows x 2 columns]

# %%
from collections import Counter

# Initialize a dictionary to store word frequencies for each DataFrame
word_frequencies = {}

# Iterate through the dataframes dictionary
for subfolder, df in dataframes.items():
    # Concatenate all text in the "Details" column
    concatenated_text = ' '.join(df["Details"])
    
    # Tokenize the text (split it into words)
    words = concatenated_text.split()
    
    # Count word frequencies using Counter
    word_freq = Counter(words)
    
    # Store the word frequencies in the dictionary
    word_frequencies[subfolder] = word_freq

# Now, word_frequencies contains word frequencies for each DataFrame within dataframes.
# You can access word frequencies for a specific DataFrame using its subfolder name.

# %%
word_frequencies
# Out:
# {'ACCOUNTANT': Counter({'accountant': 322,
#           'accounting': 1006,
#           'general': 290,
#           'accounts': 569,
#           'payable': 177,
#           'program': 32,
#           'management': 457,
#           'northern': 5,
#           'maine': 1,
#           'community': 37,
#           'college': 76,
#           '1994': 4,
#           'associate': 25,
#           'city': 432,
#           'state': 494,
#           'usa': 28,
#           'emphasis': 3,
#           'in': 545,
#           'business': 361,
#           'associates': 13,
#           'gpa': 111,
#           '341': 2,
#           '174': 1,
#           'hours': 18,
#           'quarter': 7,
#           'attended': 1,
#           'husson': 1,
#           'major': 6,
#           '78': 1,
#           'semester': 3,
#           'toward': 1,
#           'bachelors': 10,
#           'degree': 22,
#           'professional': 54,
#           'military': 16,
#           'comptroller': 1,
#           'school': 55,
#           '6wk': 1,
#           '498': 1,
#           'managerial': 13,
#           'i': 48,
#           '0998': 2,
#           'interestedbased': 1,
#           'bargaining': 3,
#           'training': 90,
#           'for': 688,
#           '24hrs': 1,
#           '0901': 1,
#           'auditing': 48,
#           'methods': 11,
#           'and': 2633,
#           'concepts': 4,
#           'organizational': 34,
#           'leadership': 36,
#           '32hrs': 2,
#           '0703': 2,
#           'development': 73,
#           'ii': 33,
#           'certifications': 22,
#           'certified': 52,
#           'defense': 5,
#           'financial': 829,
#           'manager': 63,
#           'cdfm': 1,
#           'may': 43,
#           '2005': 22,
#           'interests': 15,
#           'american': 5,
#           'society': 22,
#           'of': 1178,
#           'comptrollers': 1,
#           'additional': 40,
#           'information': 168,
#           'skills': 255,
#           'staff': 99,
#           'receivable': 127,
#           'adp': 30,
#           'advertising': 11,
#           'ar': 59,
#           'balance': 179,
#           'sheet': 108,
#           'bank': 225,
#           'reconciliations': 165,
#           'benefits': 38,
#           'billing': 116,
#           'billings': 23,
#           'book': 23,
#           'keeping': 18,
#           'budget': 165,
#           'cash': 230,
#           'flow': 73,
#           'projections': 6,
#           'controller': 35,
#           'credit': 113,
#           'clients': 100,
#           'data': 77,
#           'collection': 26,
#           'delivery': 23,
#           'documentation': 106,
#           'email': 31,
#           'finance': 157,
#           'reporting': 220,
#           'statements': 232,
#           'fixed': 119,
#           'assets': 107,
#           'ledger': 259,
#           'inventory': 134,
#           'job': 31,
#           'costing': 23,
#           'legal': 32,
#           'materials': 44,
#           'meetings': 24,
#           'microsoft': 212,
#           'access': 76,
#           'excel': 188,
#           'word': 117,
#           'negotiating': 6,
#           'dba': 2,
#           'payables': 45,
#           'payroll': 243,
#           'peachtree': 38,
#           'processes': 132,
#           'coding': 47,
#           'purchasing': 28,
#           'express': 8,
#           'quick': 17,
#           'books': 17,
#           'quickbooks': 136,
#           'research': 80,
#           'sage': 40,
#           'sales': 214,
#           'spreadsheet': 36,
#           'tax': 351,
#           'software': 141,
#           'support': 62,
#           'valuation': 9,
#           'yearend': 62,
#           'activities': 42,
#           'alpha': 15,
#           'sigma': 9,
#           'phi': 12,
#           'officer': 20,
#           'chair': 12,
#           'positions': 9,
#           'january': 49,
#           '2006': 32,
#           '2010': 35,
#           'vice': 7,
#           'president': 14,
#           'social': 5,
#           'greek': 3,
#           'week': 5,
#           'delegate': 3,
#           'livestrong': 3,
#           'foundation': 5,
#           'bikeathon': 3,
#           'bachelor': 111,
#           'science': 104,
#           'university': 206,
#           'north': 11,
#           'carolina': 10,
#           'ï¼': 199,
#           'administration': 144,
#           'experience': 69,
#           '2014': 29,
#           'to': 954,
#           'october': 4,
#           'company': 322,
#           'name': 242,
#           'performed': 62,
#           'all': 195,
#           'month': 76,
#           'end': 96,
#           'functions': 52,
#           'produce': 2,
#           'the': 798,
#           'include': 31,
#           'reconciliation': 141,
#           'operating': 26,
#           'recorded': 36,
#           'journals': 3,
#           'accrued': 3,
#           'submitted': 8,
#           'nc': 3,
#           'department': 70,
#           'revenue': 41,
#           'adjustments': 19,
#           'entries': 100,
#           'entered': 12,
#           'receivables': 35,
#           '7': 9,
#           'franchise': 3,
#           'locations': 7,
#           'worked': 34,
#           'with': 406,
#           'vendors': 34,
#           'resolve': 30,
#           'any': 33,
#           'situations': 1,
#           'that': 86,
#           'arose': 3,
#           'reviewed': 31,
#           'maintained': 65,
#           'needed': 46,
#           'document': 11,
#           'were': 22,
#           'on': 206,
#           'file': 15,
#           'up': 44,
#           'date': 21,
#           'directly': 10,
#           'review': 66,
#           'assembled': 5,
#           'requested': 7,
#           'was': 31,
#           'put': 1,
#           'into': 28,
#           'presentable': 1,
#           'formats': 6,
#           'weekly': 45,
#           'collected': 5,
#           'royalties': 2,
#           'fees': 11,
#           'this': 20,
#           'is': 30,
#           'used': 16,
#           'audit': 83,
#           'managed': 56,
#           'a': 214,
#           'owned': 2,
#           'rented': 1,
#           'out': 29,
#           '12': 13,
#           'commercial': 15,
#           'properties': 7,
#           'shopping': 1,
#           'center': 17,
#           'approved': 13,
#           'businesses': 7,
#           'responsible': 92,
#           'rent': 8,
#           'rates': 3,
#           'new': 78,
#           'or': 42,
#           'renewing': 1,
#           'tenants': 2,
#           'writing': 13,
#           'leases': 4,
#           'collecting': 6,
#           'resolving': 12,
#           'tenant': 3,
#           'complaints': 12,
#           'inquires': 1,
#           'small': 9,
#           'farming': 2,
#           'entity': 7,
#           'maintaining': 19,
#           'setting': 10,
#           'employed': 1,
#           'labor': 6,
#           'work': 89,
#           'at': 59,
#           'filed': 13,
#           'annual': 69,
#           'report': 46,
#           'companies': 22,
#           'by': 136,
#           'cary': 1,
#           'keisler': 1,
#           'inc': 4,
#           'verified': 22,
#           'current': 59,
#           'their': 30,
#           'filings': 13,
#           'march': 6,
#           '2013': 35,
#           'collect': 6,
#           'daily': 86,
#           'deposits': 36,
#           'newly': 1,
#           'sos': 1,
#           'as': 220,
#           'well': 31,
#           'so': 3,
#           'has': 5,
#           'completed': 31,
#           'once': 3,
#           'status': 43,
#           'been': 2,
#           'ran': 4,
#           'interact': 7,
#           'customers': 52,
#           'outstanding': 25,
#           'balances': 17,
#           'due': 15,
#           'po': 3,
#           'non': 2,
#           'entrycoding': 1,
#           'discrepancy': 4,
#           'pull': 1,
#           'weeklyunpaid': 1,
#           'bills': 11,
#           'reports': 278,
#           'are': 43,
#           'complete': 29,
#           'check': 26,
#           'run': 6,
#           'reconcile': 42,
#           'monthly': 194,
#           'card': 17,
#           'ranges': 1,
#           'from': 94,
#           '6000000': 1,
#           '10000000': 1,
#           'helped': 8,
#           'facilitate': 6,
#           'roll': 8,
#           'during': 17,
#           'turnover': 2,
#           'period': 12,
#           'september': 10,
#           'december': 11,
#           'ordering': 12,
#           'materialssupplies': 1,
#           'factory': 1,
#           'production': 16,
#           'floor': 2,
#           'vp': 2,
#           'members': 23,
#           'develop': 15,
#           'unit': 8,
#           'combined': 1,
#           'continued': 7,
#           'being': 10,
#           'future': 6,
#           'april': 12,
#           '2012': 31,
#           'lead': 16,
#           'ensure': 60,
#           'no': 5,
#           'transaction': 10,
#           'deviating': 1,
#           'ordinary': 1,
#           'operations': 71,
#           'project': 54,
#           'cost': 66,
#           'billable': 2,
#           'expenses': 34,
#           'posted': 11,
#           'ensures': 1,
#           'enries': 1,
#           'correct': 12,
#           'account': 198,
#           'provides': 3,
#           'bottom': 1,
#           'line': 6,
#           'each': 31,
#           'design': 20,
#           'prepaid': 16,
#           'employee': 32,
#           'eom': 1,
#           'purposes': 7,
#           'sdi': 2,
#           'battleware': 2,
#           '10': 6,
#           'entry': 40,
#           'custodial': 1,
#           'sdis': 2,
#           'depreciation': 24,
#           'interest': 16,
#           'sweep': 1,
#           'most': 5,
#           'accurate': 49,
#           'items': 24,
#           'prepare': 115,
#           'use': 27,
#           'partner': 9,
#           'july': 5,
#           'august': 14,
#           '2011': 38,
#           'identified': 12,
#           'reported': 13,
#           'tracked': 13,
#           'resolved': 38,
#           'subsidiary': 8,
#           'discrepancies': 46,
#           'phases': 2,
#           'revenues': 5,
#           'provide': 30,
#           'an': 44,
#           'statement': 65,
#           'assurance': 17,
#           'presentation': 20,
#           'aiding': 1,
#           'completing': 9,
#           'tasks': 12,
#           'areas': 14,
#           'performing': 24,
#           'applying': 4,
#           'required': 33,
#           'regulations': 8,
#           'preparing': 43,
#           'provided': 34,
#           'other': 88,
#           'employees': 35,
#           'via': 10,
#           'implementations': 3,
#           'issues': 55,
#           'aspects': 11,
#           'daytoday': 3,
#           'trained': 18,
#           'functionality': 1,
#           'demonstration': 1,
#           'assist': 47,
#           'proficient': 19,
#           'transitioning': 2,
#           'ie': 2,
#           'able': 6,
#           'perform': 41,
#           'duties': 35,
#           'departments': 32,
#           'including': 114,
#           'coordination': 18,
#           'transactional': 1,
#           'coordinate': 6,
#           'lien': 4,
#           'foreclosure': 3,
#           'preparations': 6,
#           'ownership': 2,
#           'histories': 4,
#           'order': 24,
#           'accurately': 15,
#           'claims': 5,
#           'behalf': 2,
#           'our': 15,
#           'cliental': 1,
#           'constant': 1,
#           'analysis': 212,
#           'interim': 4,
#           'comparative': 2,
#           'verify': 13,
#           'validity': 8,
#           'monitor': 15,
#           'inconsistency': 1,
#           'variance': 30,
#           'explanations': 3,
#           'quickly': 8,
#           'summarize': 2,
#           'increased': 12,
#           'variances': 28,
#           'fund': 25,
#           'board': 19,
#           'audits': 46,
#           'returns': 85,
#           'cycles': 1,
#           'adjusting': 9,
#           'transactions': 75,
#           'gl': 52,
#           'posting': 18,
#           'errors': 18,
#           'administrative': 79,
#           'trial': 20,
#           'banking': 56,
#           'bi': 18,
#           'closing': 132,
#           'computer': 53,
#           'applications': 34,
#           'customer': 146,
#           'service': 102,
#           'driving': 16,
#           'insurance': 63,
#           'outlook': 83,
#           'powerpoint': 72,
#           'mortgage': 7,
#           'loan': 20,
#           'enterprise': 19,
#           'policies': 95,
#           'telecommunications': 3,
#           'phone': 29,
#           'workflow': 4,
#           'written': 36,
#           'senior': 67,
#           'budgets': 42,
#           'client': 59,
#           'derivatives': 6,
#           'drafting': 8,
#           'equity': 16,
#           'funds': 64,
#           'government': 49,
#           'technology': 17,
#           'investments': 4,
#           'ma': 6,
#           'natural': 4,
#           'page': 6,
#           'programming': 9,
#           'real': 29,
#           'estate': 29,
#           'scheme': 2,
#           'telephone': 23,
#           'awards': 8,
#           'fulton': 6,
#           'county': 17,
#           'casa': 6,
#           'directors': 13,
#           'member': 33,
#           'treasurer': 7,
#           'plan': 19,
#           'raisers': 4,
#           'supervise': 8,
#           'notforprofit': 4,
#           'organization': 31,
#           'trains': 4,
#           'volunteers': 6,
#           'mentor': 3,
#           'children': 3,
#           'pulled': 3,
#           'homes': 5,
#           'through': 48,
#           'court': 5,
#           'system': 145,
#           'abuse': 3,
#           'neglect': 3,
#           'cpa': 50,
#           'hold': 7,
#           'active': 11,
#           'georgia': 3,
#           'license': 19,
#           'scored': 5,
#           'between': 20,
#           '87': 3,
#           '93': 3,
#           'possible': 4,
#           '99': 3,
#           'four': 6,
#           'sections': 4,
#           'exam': 5,
#           'cfe': 3,
#           'fraud': 12,
#           'examiner': 5,
#           'which': 43,
#           'requires': 3,
#           'passing': 2,
#           'exams': 2,
#           'two': 11,
#           'years': 16,
#           'preventing': 3,
#           'detecting': 2,
#           'recipient': 7,
#           '2007': 16,
#           'john': 2,
#           'r': 3,
#           'jones': 2,
#           'award': 15,
#           'given': 2,
#           'annually': 10,
#           'vote': 2,
#           'emory': 7,
#           'professors': 4,
#           'recognize': 4,
#           'top': 7,
#           'year': 41,
#           'student': 28,
#           'academia': 2,
#           'involvement': 4,
#           'character': 2,
#           'ben': 2,
#           'pius': 2,
#           'awarded': 12,
#           'exceptional': 6,
#           'achievements': 2,
#           'highest': 4,
#           'junior': 4,
#           'goizueta': 1,
#           '5': 17,
#           '36340': 2,
#           '37740': 2,
#           'aderantcms': 2,
#           'pro': 16,
#           'sql': 9,
#           'accessâ': 1,
#           'hyperion': 28,
#           'us': 38,
#           'gaap': 25,
#           'principles': 18,
#           'ifrs': 1,
#           'bookkeeping': 51,
#           'individual': 23,
#           'essbase': 11,
#           'history': 21,
#           'mar': 4,
#           'various': 80,
#           'not': 11,
#           'limited': 8,
#           'liability': 5,
#           'purpose': 3,
#           'accuracy': 45,
#           'accordance': 21,
#           'international': 46,
#           'legislative': 1,
#           'basis': 54,
#           'primary': 5,
#           'liaison': 8,
#           'function': 6,
#           'deloitteâ': 1,
#           'assigned': 18,
#           'schedules': 28,
#           'auditsâ': 1,
#           'auditors': 28,
#           'understanding': 14,
#           'firms': 2,
#           'internal': 52,
#           'controls': 26,
#           'expenditure': 5,
#           'cycle': 17,
#           'â': 174,
#           'analyze': 37,
#           'journal': 82,
#           'original': 2,
#           'source': 3,
#           'if': 4,
#           'found': 5,
#           'initiate': 2,
#           'discussions': 1,
#           'specialists': 1,
#           'payrolls': 2,
#           'inâ': 1,
#           'aspect': 1,
#           'income': 35,
#           'local': 28,
#           'consumption': 1,
#           'fringe': 3,
#           'benefit': 15,
#           'deductions': 3,
#           'seoul': 4,
#           'shanghai': 2,
#           'tokyo': 3,
#           'office': 277,
#           'upload': 2,
#           'reconcileâ': 1,
#           'value': 6,
#           'added': 4,
#           'vienna': 2,
#           'currency': 5,
#           'fluctuation': 1,
#           'record': 47,
#           'gainslosses': 3,
#           'related': 36,
#           'exchange': 10,
#           'offices': 6,
#           'firm': 12,
#           'using': 29,
#           'mode': 1,
#           'expatriate': 3,
#           'expenditures': 16,
#           'be': 19,
#           'w2': 4,
#           'form': 4,
#           'initial': 2,
#           'k1': 2,
#           'monthend': 32,
#           'accrual': 21,
#           'base': 4,
#           'wage': 3,
#           'bonus': 1,
#           'occupancy': 1,
#           'property': 37,
#           'catering': 1,
#           'accruals': 49,
#           'expense': 49,
#           'allocations': 5,
#           'intercompany': 10,
#           'shared': 4,
#           'partners': 6,
#           'translation': 1,
#           'asset': 54,
#           'invoices': 54,
#           'asian': 1,
#           'travel': 20,
#           'notable': 1,
#           'accomplishments': 18,
#           'material': 14,
#           'misstatement': 1,
#           'first': 13,
#           '08': 2,
#           'made': 13,
#           'prospective': 3,
#           'clarity': 1,
#           'japanese': 1,
#           'systems': 85,
#           'associated': 7,
#           'health': 23,
#           'welfare': 1,
#           'childcare': 1,
#           'allowance': 5,
#           'jan': 26,
#           'maintain': 45,
#           'records': 48,
#           'parent': 1,
#           'investors': 4,
#           'semiannual': 3,
#           'bs': 12,
#           'flows': 8,
#           'warehouse': 7,
#           'shipping': 9,
#           'communicate': 5,
#           'outside': 8,
#           'companys': 16,
#           'designated': 1,
#           'cpas': 6,
#           'when': 12,
#           'arise': 2,
#           'establish': 6,
#           'master': 40,
#           'receive': 6,
#           'compute': 1,
#           'make': 21,
#           '401k': 7,
#           'thru': 1,
#           'paychex': 3,
#           'factoring': 1,
#           'arrangements': 8,
#           'schedule': 14,
#           'guidance': 5,
#           'site': 4,
#           'personnel': 47,
#           'analyst': 20,
#           'aug': 10,
#           '2002': 15,
#           'manage': 33,
#           'forecast': 19,
#           'palm': 1,
#           'desert': 1,
#           'national': 23,
#           'sponsored': 1,
#           '350': 2,
#           'atm': 10,
#           'terminals': 1,
#           'averaging': 1,
#           '25': 5,
#           'million': 15,
#           'settle': 2,
#           'act': 13,
#           'innobeta': 1,
#           'affiliate': 2,
#           'money': 15,
#           'marketing': 37,
#           'profit': 29,
#           'loss': 14,
#           'surcharge': 1,
#           'interchange': 1,
#           'communication': 68,
#           'armor': 1,
#           'carrier': 1,
#           'temporary': 5,
#           'team': 74,
#           'diligence': 7,
#           'procedure': 6,
#           'world': 6,
#           'corp': 3,
#           'processing': 63,
#           'costs': 26,
#           'network': 4,
#           'terms': 6,
#           'efts': 2,
#           'papers': 7,
#           'confirmations': 1,
#           'efficient': 15,
#           'connection': 1,
#           'prepared': 96,
#           'closings': 7,
#           'preparation': 124,
#           'full': 26,
#           'footnotes': 1,
#           'lenders': 1,
#           'assure': 7,
#           'certain': 2,
#           'procedures': 108,
#           'routinely': 2,
#           'according': 5,
#           'translate': 1,
#           'documents': 26,
#           'pertaining': 5,
#           'defective': 1,
#           'parts': 3,
#           'comnet': 2,
#           'series': 3,
#           'distributed': 5,
#           'nextran': 1,
#           'industries': 2,
#           'chungho': 1,
#           'co': 4,
#           'ltd': 1,
#           'consult': 1,
#           'private': 5,
#           'services': 40,
#           'education': 55,
#           'temple': 5,
#           'identifying': 3,
#           'potential': 8,
#           'risks': 9,
#           'would': 11,
#           'impact': 7,
#           'xerox': 8,
#           'select': 7,
#           'courses': 16,
#           'advance': 11,
#           'taxation': 28,
#           'travelphotographygolfsoccermoviefashion': 2,
#           'public': 50,
#           'york': 9,
#           'issued': 8,
#           '03042015': 2,
#           'number': 14,
#           '117205': 2,
#           'aps': 2,
#           '2001': 8,
#           'investment': 26,
#           'internet': 10,
#           'ms': 82,
#           'power': 28,
#           'point': 29,
#           'pivot': 27,
#           'tables': 38,
#           'spreadsheets': 38,
#           'macros': 12,
#           'objects': 12,
#           'lombardi': 4,
#           'eagle': 5,
#           'pega': 4,
#           'dras': 3,
#           'workbench': 4,
#           'detailoriented': 6,
#           'analytical': 32,
#           'expert': 13,
#           'suite': 19,
#           'effective': 15,
#           'time': 43,
#           'complex': 23,
#           'problem': 30,
#           'solving': 21,
#           'superior': 18,
#           'multiple': 25,
#           'performanceformally': 1,
#           'recognized': 7,
#           'excellence': 7,
#           'achieved': 4,
#           'budgeting': 53,
#           'forecastingincreased': 1,
#           'efficiency': 16,
#           'investigations': 11,
#           'designing': 3,
#           'more': 11,
#           'cashforecasting': 1,
#           '102012': 1,
#           '112015': 1,
#           'reconciled': 52,
#           'mutual': 1,
#           'custody': 3,
#           'differences': 4,
#           'iax': 1,
#           'communicated': 11,
#           'collaborated': 3,
#           'custodians': 2,
#           'impacted': 1,
#           'conducted': 20,
#           'special': 30,
#           'projects': 26,
#           'oversee': 10,
#           'assisted': 62,
#           'offshore': 1,
#           'pune': 2,
#           'india': 19,
#           'acted': 2,
#           'tests': 12,
#           'vs': 2,
#           'platform': 1,
#           'migration': 5,
#           'them': 10,
#           'meet': 19,
#           'goals': 15,
#           'accountants': 17,
#           'database': 56,
#           'received': 21,
#           'achievement': 17,
#           'bny': 2,
#           'mellon': 2,
#           'servicing': 1,
#           'dec': 12,
#           'servcing': 1,
#           'aml': 1,
#           'compliance': 77,
#           '112011': 1,
#           '032012': 2,
#           'audited': 12,
#           'quality': 36,
#           'reviews': 14,
#           'results': 10,
#           'background': 4,
#           'search': 4,
#           'tools': 15,
#           'such': 45,
#           'google': 1,
#           'ud': 1,
#           '1': 26,
#           'group': 7,
#           'simulation': 1,
#           'philosophy': 1,
#           'strategy': 16,
#           'drive': 4,
#           'simulated': 1,
#           '1000000': 1,
#           'stocktrack': 1,
#           'invested': 3,
#           'about': 7,
#           '50': 3,
#           'moderate': 4,
#           'highrisk': 1,
#           'achieve': 11,
#           'capital': 20,
#           'appreciation': 1,
#           'low': 3,
#           'risk': 19,
#           'preserve': 1,
#           'rest': 1,
#           'index': 1,
#           'market': 15,
#           'determine': 20,
#           'allocation': 8,
#           'stocks': 5,
#           'minimizing': 3,
#           'cv': 1,
#           'graphed': 1,
#           'regression': 2,
#           'analyzed': 38,
#           'statistics': 11,
#           'groups': 10,
#           'portfolio': 9,
#           'case': 9,
#           'price': 7,
#           'momentum': 4,
#           'model': 5,
#           'test': 7,
#           'whether': 1,
#           'will': 3,
#           'stock': 5,
#           'it': 14,
#           'did': 2,
#           'canadian': 1,
#           'weighted': 1,
#           'created': 23,
#           'worst': 1,
#           'best': 21,
#           'selected': 3,
#           'eight': 1,
#           'create': 5,
#           'compared': 3,
#           'pricing': 24,
#           'calculated': 4,
#           'average': 3,
#           'return': 14,
#           'rebalanced': 1,
#           'sp': 1,
#           '500': 4,
#           'within': 31,
#           'same': 6,
#           'medical': 33,
#           'technologist': 1,
#           '072008': 1,
#           'clinical': 3,
#           'microbiology': 1,
#           'highlights': 6,
#           'plating': 1,
#           'culturing': 1,
#           'patients': 10,
#           'specimens': 1,
#           'rapid': 4,
#           'flu': 1,
#           'cdiff': 1,
#           'many': 4,
#           'confirmatory': 1,
#           'identify': 16,
#           'organism': 1,
#           'reading': 10,
#           'gram': 1,
#           'stain': 1,
#           'slides': 1,
#           'maintenance': 27,
#           'running': 3,
#           'control': 36,
#           'instruments': 5,
#           'delaware': 4,
#           '2008': 24,
#           'course': 17,
#           'corporate': 78,
#           'governance': 3,
#           'engineering': 3,
#           'languages': 27,
#           'english': 30,
#           'marathi': 2,
#           'hindi': 8,
#           ...}),
#  'ADVOCATE': Counter({'child': 67,
#           'family': 45,
#           'advocate': 158,
#           'scheduling': 58,
#           'appointments': 37,
#           'as': 313,
#           '400': 3,
#           'budgets': 17,
#           'call': 51,
#           'center': 68,
#           'customer': 378,
#           'service': 306,
#           'financial': 122,
#           'funds': 8,
#           'labor': 13,
#           'relations': 59,
#           'leadership': 87,
#           'sales': 235,
#           'l': 6,
#           'coursework': 13,
#           'in': 841,
#           'organizational': 56,
#           'behavior': 35,
#           'compensation': 14,
#           'and': 3343,
#           'recruitment': 15,
#           'continuing': 8,
#           'education': 100,
#           'human': 116,
#           'services': 151,
#           'greenville': 1,
#           'college': 142,
#           'desktop': 2,
#           'publishing': 1,
#           'workshop': 3,
#           'ï¼': 269,
#           'city': 624,
#           'state': 676,
#           'skills': 321,
#           'summary': 7,
#           'army': 5,
#           'benefits': 55,
#           'billing': 85,
#           'blueprints': 2,
#           'catalogs': 2,
#           'coaching': 42,
#           'hand': 8,
#           'tools': 14,
#           'inspect': 2,
#           'logistics': 10,
#           'mechanical': 4,
#           'mail': 30,
#           'power': 29,
#           'quality': 113,
#           'read': 3,
#           'recording': 14,
#           'research': 78,
#           'safety': 53,
#           'soldering': 2,
#           'solder': 2,
#           'supply': 7,
#           'chain': 3,
#           'management': 382,
#           'phone': 72,
#           'troubleshooting': 33,
#           'typing': 19,
#           'wiring': 4,
#           'post': 6,
#           'secondary': 1,
#           'training': 191,
#           'certificate': 53,
#           '2011': 33,
#           'florida': 3,
#           'at': 105,
#           'jacksonville': 6,
#           'diploma': 44,
#           '2003': 10,
#           'concorde': 1,
#           'career': 14,
#           'institution': 5,
#           'military': 16,
#           '84': 1,
#           '92': 1,
#           'united': 23,
#           'states': 26,
#           'communications': 25,
#           'specialist': 32,
#           'received': 29,
#           'honorable': 3,
#           'discharge': 9,
#           'substitute': 2,
#           'teacher': 13,
#           'adaptive': 4,
#           'equipment': 41,
#           'administrative': 84,
#           'duties': 45,
#           'appointment': 11,
#           'setting': 26,
#           'agency': 40,
#           'blood': 22,
#           'pressure': 16,
#           'cna': 8,
#           'consultant': 25,
#           'cpr': 35,
#           'certified': 44,
#           'first': 31,
#           'aid': 20,
#           'home': 43,
#           'care': 235,
#           'team': 182,
#           'building': 39,
#           'meal': 3,
#           'prep': 5,
#           'medical': 160,
#           'terminology': 15,
#           'medication': 23,
#           'meetings': 83,
#           'bathing': 4,
#           'policies': 98,
#           'record': 37,
#           'keeping': 14,
#           'inventory': 58,
#           'teaching': 18,
#           'phones': 27,
#           'therapy': 15,
#           'vision': 10,
#           'wounds': 2,
#           'written': 42,
#           'communication': 84,
#           'bachelor': 77,
#           'of': 1344,
#           'arts': 39,
#           'psychology': 49,
#           'minor': 11,
#           'social': 78,
#           'work': 156,
#           '2012': 61,
#           'governor': 1,
#           'university': 196,
#           'associate': 46,
#           'science': 110,
#           '2004': 24,
#           'south': 14,
#           'suburban': 2,
#           'express': 5,
#           'scripts': 10,
#           'cash': 78,
#           'handling': 27,
#           'excellent': 68,
#           'interpersonal': 47,
#           'detailoriented': 15,
#           'merchandising': 11,
#           'selfmotivated': 14,
#           '70': 3,
#           'wpm': 11,
#           'high': 112,
#           'school': 121,
#           'business': 200,
#           'computers': 7,
#           'camden': 1,
#           'county': 12,
#           'rn': 21,
#           'asst': 3,
#           'head': 11,
#           'nurse': 54,
#           'practice': 20,
#           'leader': 21,
#           'planning': 61,
#           'case': 71,
#           'health': 183,
#           'hospice': 1,
#           'infection': 2,
#           'control': 37,
#           'injections': 11,
#           'manager': 84,
#           'oncology': 10,
#           'staff': 161,
#           'development': 113,
#           'trauma': 16,
#           'triage': 7,
#           'tutoring': 4,
#           'urology': 5,
#           'experience': 98,
#           '092010': 1,
#           'to': 1651,
#           '122011': 3,
#           'company': 381,
#           'name': 348,
#           'hired': 4,
#           'adon': 1,
#           'assistant': 60,
#           'director': 57,
#           'nursing': 94,
#           'for': 788,
#           'an': 67,
#           '85': 2,
#           '90': 3,
#           'bed': 4,
#           'long': 8,
#           'term': 12,
#           'mentally': 3,
#           'physically': 1,
#           'disabled': 5,
#           'children': 69,
#           'from': 107,
#           '2': 17,
#           'years': 38,
#           'upper': 5,
#           '20s': 1,
#           'with': 618,
#           'a': 417,
#           'few': 2,
#           'older': 1,
#           'individuals': 20,
#           'my': 73,
#           'job': 21,
#           'there': 2,
#           'included': 17,
#           'staffing': 25,
#           'all': 205,
#           'the': 949,
#           'nurses': 8,
#           'monthly': 50,
#           'up': 45,
#           'transportation': 15,
#           'outside': 12,
#           'md': 5,
#           'office': 183,
#           'visits': 15,
#           'residents': 14,
#           'monitoring': 36,
#           '3': 4,
#           'units': 6,
#           'day': 29,
#           'documentation': 72,
#           'taking': 16,
#           'needed': 47,
#           'twice': 3,
#           'month': 7,
#           'being': 8,
#           'mod': 1,
#           'entire': 1,
#           'i': 117,
#           'conducted': 32,
#           'inservices': 2,
#           'answered': 13,
#           'pages': 2,
#           'during': 27,
#           'questions': 31,
#           'or': 160,
#           'oversee': 5,
#           'any': 52,
#           'critical': 29,
#           'changes': 40,
#           'helped': 23,
#           'decisions': 7,
#           'transfer': 5,
#           'out': 41,
#           'hospital': 45,
#           'after': 14,
#           'speaking': 25,
#           'mdhelped': 1,
#           'secured': 8,
#           'position': 14,
#           'rescare': 1,
#           'located': 8,
#           'oak': 3,
#           'park': 9,
#           'illinois': 34,
#           '2015': 45,
#           'made': 22,
#           'overseeing': 4,
#           'clients': 178,
#           'overall': 7,
#           'did': 7,
#           'basic': 27,
#           'assessments': 26,
#           'listened': 2,
#           'new': 149,
#           'complaints': 22,
#           'change': 23,
#           'status': 39,
#           'would': 11,
#           'doctor': 6,
#           'if': 12,
#           'inform': 5,
#           'him': 1,
#           'gave': 3,
#           'infusions': 1,
#           'participated': 22,
#           'one': 21,
#           'clinical': 66,
#           'trial': 2,
#           'where': 17,
#           'aspects': 14,
#           'visit': 6,
#           'were': 55,
#           'timed': 1,
#           'documented': 13,
#           'per': 28,
#           'protocal': 1,
#           'am': 18,
#           'still': 4,
#           'registered': 13,
#           'this': 12,
#           'but': 9,
#           'they': 17,
#           'have': 28,
#           'very': 7,
#           'need': 21,
#           'most': 14,
#           'their': 115,
#           'only': 3,
#           'part': 21,
#           'time': 78,
#           'can': 8,
#           'july': 16,
#           '2016': 31,
#           'best': 32,
#           'jobs': 10,
#           'that': 109,
#           'available': 21,
#           'minimal': 2,
#           'so': 4,
#           'took': 17,
#           'myself': 4,
#           'off': 8,
#           'roster': 3,
#           'fall': 4,
#           'worked': 53,
#           'maxim': 1,
#           'asking': 1,
#           'infusion': 3,
#           'cases': 21,
#           'again': 1,
#           'was': 67,
#           'promised': 1,
#           'what': 6,
#           'ones': 1,
#           '40': 16,
#           'miles': 4,
#           'away': 2,
#           'didnt': 2,
#           'cover': 4,
#           'milage': 1,
#           'on': 360,
#           'rarely': 1,
#           'called': 8,
#           'currently': 10,
#           'looking': 4,
#           'line': 8,
#           'going': 5,
#           'into': 33,
#           'facility': 20,
#           'not': 16,
#           'more': 23,
#           'than': 12,
#           '30': 27,
#           'minute': 4,
#           'drive': 7,
#           'do': 4,
#           'online': 26,
#           'willing': 5,
#           'learn': 13,
#           'pt': 2,
#           'oncologyhospice': 1,
#           'additional': 50,
#           'professional': 103,
#           'activities': 57,
#           'ocn': 2,
#           'past': 13,
#           'med': 9,
#           'surg': 4,
#           'plan': 65,
#           'recertify': 1,
#           'future': 11,
#           'north': 9,
#           'shore': 1,
#           'youth': 14,
#           'baseball': 2,
#           'league': 5,
#           '4': 22,
#           'references': 1,
#           'dr': 4,
#           'emil': 1,
#           'totonchi': 1,
#           'masonic': 11,
#           'michael': 1,
#           'friedman': 1,
#           'beverly': 1,
#           'bohus': 1,
#           'lorel': 1,
#           'hedges': 1,
#           'practioner': 1,
#           'now': 9,
#           'works': 14,
#           'tennessee': 4,
#           'uma': 1,
#           'kelkar': 1,
#           'rehab': 3,
#           'manor': 5,
#           'northbrook': 3,
#           'jean': 1,
#           'gavina': 1,
#           'mds': 14,
#           'elma': 1,
#           'ramos': 1,
#           'evening': 1,
#           'supervisor': 49,
#           'contact': 24,
#           'information': 169,
#           'upon': 10,
#           'request': 13,
#           '062009': 5,
#           '072010': 11,
#           'started': 3,
#           'promoted': 10,
#           'dcd': 1,
#           'delivery': 33,
#           'managing': 45,
#           'locked': 1,
#           'dementia': 2,
#           'unit': 51,
#           'later': 3,
#           '60': 4,
#           'recently': 1,
#           'back': 11,
#           'along': 8,
#           'leading': 11,
#           'priorities': 7,
#           'upholding': 1,
#           'corporate': 16,
#           'standards': 14,
#           'communicating': 7,
#           'through': 84,
#           'existing': 26,
#           'systems': 79,
#           'material': 6,
#           'qa': 1,
#           'understanding': 23,
#           'issues': 103,
#           'valuing': 1,
#           'every': 9,
#           'employee': 58,
#           'supporting': 4,
#           'attending': 12,
#           'interdisciplinary': 9,
#           'daily': 64,
#           'weekly': 22,
#           'such': 35,
#           'medicare': 14,
#           'investigation': 5,
#           'falls': 5,
#           'skin': 4,
#           'injuries': 6,
#           'admissions': 10,
#           'assists': 2,
#           'hiring': 22,
#           'disciplinary': 4,
#           'actions': 5,
#           'resigned': 1,
#           '2010': 34,
#           'want': 2,
#           'take': 13,
#           'some': 8,
#           'vacation': 4,
#           'find': 6,
#           'somewhat': 1,
#           'closer': 2,
#           '011977': 2,
#           '012009': 12,
#           'responsible': 64,
#           '24': 7,
#           'hr': 18,
#           'basis': 24,
#           'including': 86,
#           'payroll': 42,
#           'monitor': 11,
#           'rns': 7,
#           'ncts': 1,
#           'clerks': 1,
#           'assignments': 8,
#           'learning': 37,
#           'needs': 113,
#           'occasionally': 1,
#           'fill': 13,
#           'voids': 1,
#           'reported': 9,
#           'tasks': 25,
#           'keep': 10,
#           'her': 1,
#           'current': 76,
#           'problems': 31,
#           'interview': 5,
#           'process': 71,
#           'both': 23,
#           'activity': 10,
#           'terminations': 3,
#           'sought': 2,
#           'scheduled': 11,
#           'sure': 8,
#           'attended': 16,
#           'required': 29,
#           'mandatories': 1,
#           'yearly': 6,
#           'when': 54,
#           'general': 38,
#           'recruited': 2,
#           'by': 177,
#           'chairman': 1,
#           'be': 26,
#           'open': 11,
#           '1st': 7,
#           'inpatient': 7,
#           'also': 30,
#           'next': 2,
#           '20': 13,
#           'earned': 5,
#           'instruct': 1,
#           'become': 3,
#           'mix': 1,
#           'chemo': 1,
#           'drugs': 6,
#           'via': 29,
#           'laminar': 1,
#           'flow': 14,
#           'hood': 1,
#           'administer': 2,
#           'safely': 2,
#           'side': 14,
#           'effects': 11,
#           'manage': 41,
#           'symptoms': 6,
#           'beside': 1,
#           'patient': 162,
#           'load': 6,
#           'many': 25,
#           'days': 8,
#           'week': 15,
#           '1999': 7,
#           'changed': 2,
#           'surgical': 14,
#           '23hr': 1,
#           'observation': 2,
#           'approximately': 9,
#           'leaderequal': 1,
#           'expanded': 2,
#           'installed': 13,
#           'computer': 66,
#           'profiency': 1,
#           'classes': 7,
#           'progress': 43,
#           'charting': 3,
#           'patients': 150,
#           'workshops': 13,
#           'seminar': 6,
#           'picc': 5,
#           'insertion': 7,
#           'point': 33,
#           'headed': 1,
#           'program': 97,
#           'kept': 15,
#           'records': 47,
#           'piccs': 1,
#           'placed': 1,
#           'complications': 4,
#           'became': 7,
#           'nationally': 5,
#           'exam': 5,
#           'passing': 1,
#           'types': 9,
#           'seen': 2,
#           'thisunit': 1,
#           'include': 23,
#           'gyne': 1,
#           'sicu': 1,
#           'neck': 2,
#           'ent': 1,
#           'fetal': 1,
#           'demises': 1,
#           'less': 1,
#           'weeks': 2,
#           'due': 12,
#           'number': 5,
#           'private': 6,
#           'rooms': 8,
#           'we': 7,
#           'isolation': 2,
#           'ro': 1,
#           'tb': 2,
#           'our': 19,
#           'negative': 6,
#           'air': 1,
#           'room': 7,
#           'short': 1,
#           'stay': 5,
#           'anywhere': 5,
#           'overnight': 4,
#           '23': 3,
#           'overflow': 1,
#           'medicals': 1,
#           'extensive': 12,
#           '45': 5,
#           'result': 4,
#           'fast': 20,
#           'paced': 6,
#           'half': 2,
#           'discharged': 1,
#           'within': 48,
#           '12': 5,
#           'shifts': 4,
#           'beds': 1,
#           'filled': 2,
#           'main': 1,
#           'placing': 3,
#           'correctly': 7,
#           'assignment': 1,
#           'competent': 3,
#           'coming': 4,
#           'frequent': 1,
#           'rounds': 5,
#           'assure': 4,
#           'satisfaction': 56,
#           'quickly': 16,
#           'preventing': 2,
#           'escalating': 2,
#           'had': 5,
#           'try': 3,
#           'set': 21,
#           'review': 51,
#           'based': 53,
#           'inservice': 3,
#           'send': 8,
#           'seminars': 16,
#           'budget': 44,
#           'allowed': 1,
#           'checking': 4,
#           'printed': 1,
#           'areas': 24,
#           'missing': 8,
#           'incorrect': 5,
#           'make': 18,
#           'aware': 1,
#           'them': 32,
#           'correct': 23,
#           'help': 49,
#           'correction': 1,
#           'last': 3,
#           'done': 3,
#           'two': 18,
#           'adequate': 2,
#           '1976': 6,
#           '1974': 2,
#           'northeastern': 2,
#           '1973': 2,
#           'western': 8,
#           'awards': 19,
#           'dorothy': 2,
#           'rome': 2,
#           'nominee': 2,
#           'highest': 4,
#           'award': 51,
#           'experienced': 15,
#           'awarded': 12,
#           'applause': 2,
#           'awardsâ': 2,
#           'nominated': 2,
#           'excellence': 8,
#           'asked': 5,
#           'until': 6,
#           'turned': 2,
#           'over': 32,
#           'interventional': 3,
#           'radiology': 3,
#           'above': 10,
#           'travel': 12,
#           'booking': 1,
#           'thinking': 17,
#           'creative': 19,
#           'problem': 80,
#           'solving': 39,
#           'cellular': 3,
#           'expert': 13,
#           'smartphones': 1,
#           'network': 50,
#           'connections': 4,
#           'internet': 20,
#           'wifi': 1,
#           'core': 2,
#           'accomplishments': 14,
#           'calendaring': 1,
#           'â': 348,
#           'planned': 10,
#           'ceo': 4,
#           'improvement': 16,
#           'oversaw': 14,
#           'implementation': 21,
#           'system': 100,
#           'which': 32,
#           'resulted': 9,
#           'costeffective': 1,
#           'investigated': 4,
#           'analyzed': 15,
#           'client': 142,
#           'identify': 28,
#           'resolve': 29,
#           'multitasking': 18,
#           'demonstrated': 11,
#           'proficiencies': 1,
#           'telephone': 37,
#           'email': 23,
#           'fax': 4,
#           'frontdesk': 1,
#           'reception': 2,
#           'highvolume': 3,
#           'environment': 50,
#           'handled': 16,
#           'customers': 103,
#           'effectively': 28,
#           'identifying': 11,
#           'gaining': 3,
#           'trust': 9,
#           'approaching': 1,
#           'complex': 21,
#           'situations': 20,
#           'resolving': 15,
#           'maximize': 7,
#           'efficiency': 20,
#           'assistance': 52,
#           'assisted': 41,
#           'preparation': 10,
#           'entered': 8,
#           'data': 138,
#           'cumulative': 3,
#           'document': 15,
#           'september': 19,
#           '2007': 30,
#           'march': 21,
#           'volume': 34,
#           'incoming': 16,
#           'calls': 57,
#           'national': 43,
#           'prospective': 17,
#           'well': 62,
#           'associates': 16,
#           'actively': 4,
#           'each': 44,
#           'ensure': 43,
#           'complete': 18,
#           'concerns': 24,
#           'provided': 94,
#           'innovative': 6,
#           'individualized': 4,
#           'solutions': 34,
#           'obtained': 9,
#           'resolution': 60,
#           'reassurance': 1,
#           'positive': 24,
#           'end': 8,
#           'accessed': 3,
#           'account': 41,
#           'database': 75,
#           'retrieve': 1,
#           'update': 11,
#           'while': 39,
#           'maintaining': 21,
#           'personable': 1,
#           'conversations': 4,
#           'flexibly': 1,
#           'adjusted': 2,
#           'styles': 1,
#           'caller': 2,
#           'particularly': 1,
#           'terms': 7,
#           'level': 36,
#           'familiarity': 2,
#           'technology': 45,
#           'structures': 1,
#           'understood': 1,
#           'instructions': 2,
#           'procedures': 47,
#           'administered': 19,
#           'devicerelated': 1,
#           'interactions': 10,
#           'transactions': 24,
#           'details': 13,
#           'inquiries': 36,
#           'comments': 2,
#           'taken': 3,
#           'maintained': 56,
#           'uptodate': 6,
#           'knowledge': 68,
#           'constantly': 1,
#           'changing': 4,
#           'products': 50,
#           'order': 48,
#           'provide': 86,
#           'accurate': 43,
#           'legal': 50,
#           'secretary': 14,
#           'january': 46,
#           '2006': 21,
#           'may': 49,
#           'prepared': 25,
#           'court': 28,
#           'documents': 39,
#           'deeds': 1,
#           'real': 9,
#           'estate': 5,
#           'statements': 9,
#           'purchase': 10,
#           'agreements': 5,
#           'contracts': 30,
#           'attorney': 4,
#           'wills': 1,
#           'routine': 10,
#           'correspondence': 13,
#           'performed': 43,
#           'accounting': 40,
#           'accounts': 90,
#           'receivable': 11,
#           'payable': 17,
#           'entry': 61,
#           'slips': 1,
#           'taxes': 4,
#           'balancing': 3,
#           'estates': 1,
#           'greeted': 5,
#           'offered': 5,
#           'seats': 1,
#           'waited': 1,
#           'updating': 3,
#           'administering': 3,
#           'reminders': 1,
#           'lawyers': 6,
#           'ensured': 20,
#           'wellstocked': 1,
#           'supplies': 19,
#           'organized': 40,
#           'maximum': 3,
#           'assistantcustomer': 1,
#           'rep': 4,
#           'august': 17,
#           '2005': 28,
#           'directly': 7,
#           'president': 25,
#           'doane': 13,
#           'chief': 8,
#           'officer': 21,
#           'schedule': 22,
#           'events': 29,
#           'put': 1,
#           'together': 1,
#           'materials': 36,
#           'board': 24,
#           'meeting': 11,
#           'minutes': 5,
#           'member': 101,
#           'booked': 1,
#           'arrangements': 4,
#           'created': 46,
#           'itinerary': 1,
#           'trips': 1,
#           'retail': 19,
#           'banking': 11,
#           'representative': 34,
#           'ii': 16,
#           'june': 16,
#           '2002': 14,
#           'assisting': 25,
#           'person': 8,
#           'opened': 6,
#           'solved': 5,
#           'crosssold': 1,
#           'scanned': 2,
#           'checks': 13,
#           'drawer': 3,
#           'atm': 3,
#           'vault': 4,
#           'total': 7,
#           'branch': 1,
#           'majors': 2,
#           'fine': 3,
#           'art': 12,
#           'biology': 3,
#           '1985': 12,
#           'presidents': 10,
#           'scholarship': 17,
#           'outstanding': 11,
#           'achievement': 24,
#           'pallet': 2,
#           'scholar': 3,
#           'american': 33,
#           'legion': 2,
#           'loup': 2,
#           'ne': 2,
#           '1981': 3,
#           'special': 31,
#           'recognition': 14,
#           'yearbook': 4,
#           'editor': 7,
#           'mary': 2,
#           'chapin': 2,
#           'senior': 40,
#           'cohead': 2,
#           'photographer': 2,
#           '1984': 4,
#           'delta': 8,
#           'chi': 3,
#           'upsilon': 2,
#           'sorority': 3,
#           'xanadu': 2,
#           'literary': 2,
#           'magazine': 7,
#           'alpha': 11,
#           'lambda': 5,
#           'cardinal': 2,
#           'key': 25,
#           'honor': 24,
#           'societies': 3,
#           'gpa': 74,
#           '344': 2,
#           'executive': 31,
#           'personal': 47,
#           'banker': 8,
#           'major': 9,
#           'wireless': 11,
#           'device': 5,
#           'benefit': 11,
#           'cisco': 8,
#           'coach': 27,
#           'com': 3,
#           'counseling': 40,
#           'direction': 18,
#           'insurance': 96,
#           'kronos': 4,
#           'law': 52,
#           'letters': 27,
#           'mentoring': 20,
#           'excel': 98,
#           'ms': 53,
#           'sharepoint': 11,
#           'windows': 39,
#           'analysis': 63,
#           'enterprise': 6,
#           'newsletter': 4,
#           'organizing': 13,
#           'peak': 3,
#           'performance': 56,
#           'reviews': 14,
#           'pivot': 3,
#           'tables': 6,
#           'improve': 23,
#           'processes': 73,
#           'project': 58,
#           'assurance': 17,
#           'selling': 19,
#           'support': 106,
#           'supervising': 14,
#           'technical': 28,
#           'underwriter': 5,
#           'underwriting': 8,
#           'articles': 2,
#           'councilor': 1,
# ...
#           'promoted': 39,
#           'storytellingapplied': 8,
#           'behaviorsconducted': 6,
#           'needsassisted': 2,
#           '56': 6,
#           'per': 17,
#           'station': 10,
#           'during': 68,
#           'periods': 6,
#           'organized': 43,
#           'encouraged': 52,
#           'engagedhelped': 2,
#           'supplied': 4,
#           'groupphysically': 6,
#           'engagedcommunicated': 4,
#           'effectively': 29,
#           'educators': 17,
#           'levelswrote': 4,
#           'studentsto': 2,
#           'participationorganized': 2,
#           'zoosmaintained': 2,
#           'childrens': 61,
#           'behaviors': 43,
#           'naps': 8,
#           'established': 50,
#           'safe': 35,
#           'play': 36,
#           'childrendistributed': 4,
#           'quarterly': 16,
#           'assessments': 28,
#           'similar': 7,
#           'cards': 9,
#           'parentdeveloped': 2,
#           'professional': 88,
#           'directors': 10,
#           'therapistsobserved': 3,
#           'signs': 23,
#           'illness': 7,
#           'injury': 6,
#           'emotional': 48,
#           'disturbance': 7,
#           'disorders': 12,
#           'speech': 13,
#           'problemsmaintained': 2,
#           'aide': 10,
#           '1999': 15,
#           'mar': 7,
#           '2001': 19,
#           'zoos': 5,
#           'assisted': 56,
#           'periodsencouraged': 2,
#           'dynamicshelped': 2,
#           'participation': 16,
#           'groupcommunicated': 2,
#           'studentsmaintained': 2,
#           'napsestablished': 3,
#           'childrencreated': 2,
#           'developmentallyappropriate': 5,
#           'that': 151,
#           'addressed': 14,
#           'all': 196,
#           'stylesdistributed': 2,
#           'parentmaintained': 2,
#           'childfriendly': 8,
#           'access': 19,
#           'outdoor': 22,
#           'activitiescompleted': 3,
#           'required': 29,
#           'national': 52,
#           'head': 22,
#           'start': 11,
#           'program': 103,
#           'extracurricular': 5,
#           'ran': 7,
#           'nursery': 3,
#           'at': 121,
#           'my': 76,
#           'church': 18,
#           'yea': 2,
#           'then': 9,
#           'taught': 83,
#           'sunday': 7,
#           'older': 2,
#           'kids': 12,
#           'another': 7,
#           'two': 18,
#           'years': 48,
#           'also': 27,
#           'helped': 29,
#           'run': 7,
#           'an': 77,
#           'after': 50,
#           'get': 6,
#           'your': 7,
#           'homework': 32,
#           'done': 6,
#           'here': 2,
#           'started': 5,
#           'where': 11,
#           'didnt': 2,
#           'help': 43,
#           'home': 14,
#           'could': 17,
#           'come': 6,
#           'us': 34,
#           'their': 133,
#           'younger': 5,
#           'enroll': 3,
#           'they': 18,
#           'would': 22,
#           'summary': 6,
#           'talented': 2,
#           'diverse': 19,
#           'planning': 97,
#           'implementing': 24,
#           'promoting': 19,
#           'physical': 46,
#           'social': 119,
#           'intellectual': 4,
#           'growth': 24,
#           'programs': 67,
#           'strong': 22,
#           'communicator': 2,
#           'toddler': 9,
#           'preschool': 30,
#           'curricula': 13,
#           'academic': 96,
#           'autism': 17,
#           'book': 11,
#           'clients': 52,
#           'customer': 85,
#           'service': 106,
#           'internet': 26,
#           'explorer': 6,
#           'windows': 11,
#           'microsoft': 87,
#           'purchasing': 23,
#           'quick': 4,
#           'read': 22,
#           'sabre': 2,
#           'staffing': 2,
#           'inspect': 5,
#           'vehicles': 5,
#           'additional': 39,
#           'information': 101,
#           'willing': 9,
#           'relocate': 5,
#           'anywhere': 5,
#           'authorized': 7,
#           'any': 29,
#           'employer': 6,
#           'liberal': 17,
#           'thomas': 4,
#           'jefferson': 1,
#           'guest': 9,
#           'branding': 3,
#           'case': 15,
#           'interpersonal': 24,
#           'oral': 13,
#           'critical': 31,
#           'thinking': 25,
#           'functional': 12,
#           'meetings': 88,
#           'office': 119,
#           'relationship': 9,
#           'building': 21,
#           'seminars': 14,
#           'written': 27,
#           'communication': 85,
#           'mba': 5,
#           '2006': 37,
#           'nevada': 3,
#           'jan': 11,
#           '2015': 30,
#           'responsibilities': 23,
#           'continuity': 1,
#           'process': 29,
#           'incorporated': 16,
#           'cooperative': 3,
#           'role': 13,
#           'playing': 7,
#           'between': 14,
#           'course': 46,
#           'material': 25,
#           'life': 10,
#           'experiences': 6,
#           'use': 34,
#           'challenging': 17,
#           'debate': 1,
#           'account': 9,
#           '2014': 36,
#           'develop': 36,
#           'deeper': 1,
#           'hq': 1,
#           'regional': 7,
#           'grow': 4,
#           'gaming': 4,
#           'lodging': 5,
#           'channel': 1,
#           'starbucks': 4,
#           'coffee': 4,
#           'mgm': 1,
#           'international': 24,
#           'caesars': 3,
#           'entertainment': 1,
#           'stationâ': 1,
#           'casinos': 2,
#           'intercontinental': 3,
#           'hotels': 5,
#           'hilton': 2,
#           'credited': 1,
#           'store': 19,
#           'along': 2,
#           'las': 16,
#           'vegas': 16,
#           'strip': 2,
#           'zero': 2,
#           'base': 8,
#           'present': 24,
#           '105mm': 1,
#           'revenue': 11,
#           'built': 7,
#           'strategic': 8,
#           'alliances': 1,
#           'internal': 17,
#           'external': 10,
#           'teams': 15,
#           'resulted': 6,
#           'sustained': 1,
#           'over': 29,
#           '14': 3,
#           'yrs': 1,
#           'feb': 1,
#           'led': 14,
#           'crossfunctional': 5,
#           'ensure': 25,
#           'franchise': 3,
#           'openings': 2,
#           'execution': 5,
#           'foodservice': 1,
#           'agreements': 3,
#           'california': 20,
#           'arizona': 6,
#           'as': 314,
#           'viable': 2,
#           'segment': 3,
#           'accomplishments': 44,
#           'leveraged': 3,
#           'corporate': 14,
#           'executive': 22,
#           'launch': 3,
#           'customized': 3,
#           'stores': 5,
#           'profile': 2,
#           'partners': 4,
#           'expand': 4,
#           'product': 24,
#           'beyond': 2,
#           'franchised': 1,
#           'locations': 6,
#           'eventually': 3,
#           'secure': 4,
#           'distribution': 11,
#           'mandates': 1,
#           'resulting': 6,
#           'excess': 1,
#           '105': 1,
#           'million': 1,
#           'ongoing': 4,
#           'revenues': 4,
#           'increase': 19,
#           'number': 20,
#           'license': 12,
#           '1': 22,
#           '51': 1,
#           'volume': 2,
#           'presented': 10,
#           'comprehensive': 6,
#           'instructional': 57,
#           'topics': 9,
#           'included': 19,
#           'site': 18,
#           'placement': 5,
#           'perspective': 1,
#           'show': 5,
#           'roi': 1,
#           'contract': 4,
#           'compliance': 18,
#           'identifying': 5,
#           'publications': 5,
#           'history': 45,
#           'wwwlawrencelibksusoralhistorynetherhtml': 1,
#           'â': 262,
#           'presentations': 24,
#           'culture': 5,
#           'httpswwwyoutubecomwatchvtath6y7ebdo': 1,
#           'membershipsscholarly': 1,
#           'societies': 1,
#           'fraternity': 5,
#           'wwwlasvegasnupescomcurtisnetherhtml': 1,
#           'modern': 4,
#           'technology': 64,
#           'conflict': 13,
#           'resolution': 14,
#           'iep': 29,
#           'familiarity': 4,
#           'organizationplanning': 1,
#           'bls': 1,
#           'cpr': 46,
#           'studentcentered': 4,
#           'grading': 7,
#           'integration': 6,
#           'punctual': 2,
#           'inquirybased': 3,
#           'proctoring': 3,
#           '082014': 12,
#           '062017': 4,
#           'performed': 24,
#           'aspects': 3,
#           'managementâ': 2,
#           'instructed': 31,
#           'provided': 65,
#           'support': 101,
#           'needed': 31,
#           'documented': 8,
#           'attendance': 24,
#           'assignments': 39,
#           'grades': 30,
#           'planned': 33,
#           'cover': 1,
#           'collaborated': 18,
#           'administrators': 41,
#           'counselors': 6,
#           'improvement': 7,
#           'struggling': 5,
#           'developed': 61,
#           'integrated': 7,
#           'diversify': 6,
#           'met': 32,
#           'resolve': 10,
#           'conflicting': 2,
#           'priorities': 7,
#           'issues': 51,
#           'created': 61,
#           '081998': 4,
#           'administered': 23,
#           'quizzes': 17,
#           'assess': 10,
#           'fostered': 18,
#           'meaningful': 1,
#           'among': 7,
#           'fieldtrip': 1,
#           'retreats': 1,
#           'teamwork': 7,
#           'projects': 50,
#           'served': 25,
#           'affiliation': 1,
#           'board': 45,
#           'revised': 4,
#           'institutes': 1,
#           'policies': 50,
#           'rules': 25,
#           'assistant': 74,
#           '081989': 1,
#           '061998': 1,
#           'safety': 47,
#           'outside': 6,
#           'environments': 1,
#           'interventions': 10,
#           'team': 124,
#           'professionals': 4,
#           'different': 10,
#           'disciplines': 3,
#           'implement': 24,
#           'action': 9,
#           'plan': 50,
#           'worked': 62,
#           'personalized': 11,
#           'behavioral': 30,
#           'assistance': 19,
#           'including': 64,
#           'clerical': 6,
#           'document': 11,
#           'coordination': 8,
#           'relevant': 4,
#           'books': 17,
#           'poems': 1,
#           'movies': 1,
#           'themes': 5,
#           'promote': 37,
#           'interest': 23,
#           'interests': 28,
#           'educationparenting': 2,
#           'activitiesâ': 1,
#           'south': 10,
#           'carolina': 4,
#           'association': 22,
#           '4h': 7,
#           'memberteacher': 2,
#           'environmental': 9,
#           'club': 27,
#           'advisor': 19,
#           'prom': 9,
#           'coordinator': 28,
#           'junior': 9,
#           'sponsorâ': 2,
#           'volunteer': 33,
#           'boys': 13,
#           'girls': 7,
#           'rock': 7,
#           'hillâ': 2,
#           'detention': 6,
#           'hall': 5,
#           'teacherâ': 4,
#           'progressive': 5,
#           'committeeâ': 2,
#           'member': 76,
#           'responder': 6,
#           'masters': 16,
#           'studies': 44,
#           '2018': 6,
#           'winthrop': 2,
#           'gpa': 33,
#           '38': 5,
#           'sociology': 12,
#           'june': 41,
#           '1998': 22,
#           'coker': 2,
#           '30': 11,
#           'april': 12,
#           'hill': 5,
#           'northwestern': 2,
#           'staff': 120,
#           'supervising': 22,
#           'supervision': 20,
#           'tutoring': 17,
#           '8th': 6,
#           '9th': 7,
#           '11th': 7,
#           'anchor': 4,
#           'faculty': 13,
#           'juniorsenior': 2,
#           'sponsor': 6,
#           'bishopville': 4,
#           'primary': 8,
#           '1989': 6,
#           '603': 2,
#           'north': 6,
#           'dennis': 2,
#           'avenue': 6,
#           'sc': 4,
#           '29010': 2,
#           'adult': 8,
#           'committee': 21,
#           'specialists': 13,
#           'workers': 14,
#           'discuss': 36,
#           'designed': 24,
#           'educationalsocial': 2,
#           'targeted': 3,
#           'guardians': 16,
#           'determine': 5,
#           'resource': 30,
#           'mentor': 31,
#           'volunteered': 7,
#           'temporary': 4,
#           'guidance': 9,
#           'counselor': 12,
#           'mathematics': 57,
#           'art': 39,
#           'pupils': 2,
#           'study': 26,
#           'adopted': 7,
#           'certifications': 36,
#           'certified': 41,
#           'scst': 2,
#           'succeed': 2,
#           'certification': 30,
#           'monitoring': 9,
#           'evernote': 3,
#           'slack': 3,
#           'adobe': 9,
#           'photoshop': 11,
#           'scheduling': 34,
#           'financial': 22,
#           'analysis': 19,
#           'security': 15,
#           'trading': 3,
#           'portfolio': 8,
#           'managament': 3,
#           'liability': 3,
#           'structuring': 5,
#           'teaches': 3,
#           'classes': 18,
#           'accordance': 21,
#           'requirements': 25,
#           'approved': 14,
#           'courses': 28,
#           'expected': 3,
#           'expectations': 14,
#           'uses': 7,
#           'strengths': 5,
#           'designs': 9,
#           'engage': 16,
#           'cognitively': 3,
#           'aligned': 4,
#           'standards': 42,
#           'resources': 20,
#           'will': 11,
#           'levels': 27,
#           'engagement': 12,
#           'closely': 23,
#           'monitors': 11,
#           'order': 41,
#           'understand': 5,
#           'how': 17,
#           'are': 29,
#           'progressing': 3,
#           'toward': 8,
#           'provides': 9,
#           'instructive': 3,
#           'moves': 3,
#           'forward': 5,
#           'establishes': 3,
#           'is': 25,
#           'supportive': 9,
#           'risktaking': 3,
#           'feel': 5,
#           'free': 6,
#           'contribute': 4,
#           'ideas': 12,
#           'interactions': 3,
#           'respectful': 3,
#           'polite': 3,
#           'initiates': 2,
#           'participates': 3,
#           'individualized': 16,
#           'other': 72,
#           'parties': 3,
#           'involved': 7,
#           'eligible': 4,
#           'utilizes': 4,
#           'district': 39,
#           'modification': 10,
#           'goals': 30,
#           'continually': 15,
#           'goal': 23,
#           'achievement': 11,
#           'maintains': 10,
#           'incidents': 6,
#           'eg': 5,
#           'substance': 6,
#           'harassment': 4,
#           'violence': 4,
#           'communicates': 5,
#           'families': 18,
#           'create': 34,
#           'partnerships': 4,
#           'around': 12,
#           'providing': 28,
#           'programing': 4,
#           'collaboration': 16,
#           'ela': 15,
#           'evaluates': 4,
#           'performance': 55,
#           'subordinate': 4,
#           'personnel': 29,
#           'robotics': 11,
#           'instructor': 8,
#           '082012': 10,
#           '092014': 5,
#           'clear': 19,
#           'informative': 7,
#           'lectures': 21,
#           'working': 26,
#           'kits': 4,
#           'programming': 11,
#           'theory': 4,
#           'increased': 14,
#           'expertise': 12,
#           'knowledge': 53,
#           'participating': 11,
#           'instructororiented': 4,
#           'modified': 13,
#           'accommodate': 13,
#           'learners': 18,
#           'using': 56,
#           'such': 73,
#           'peerassisted': 4,
#           '082015': 6,
#           'realizing': 4,
#           '2025': 4,
#           'annually': 5,
#           '5': 20,
#           'year': 79,
#           'period': 16,
#           'analytics': 4,
#           'relocation': 4,
#           'services': 41,
#           'take': 22,
#           'though': 4,
#           'time': 90,
#           'asset': 4,
#           'restructuring': 4,
#           'system': 44,
#           'antifragile': 4,
#           'contingency': 4,
#           'recovery': 5,
#           'black': 6,
#           'swan': 4,
#           'events': 42,
#           'launched': 6,
#           'boosted': 6,
#           '15': 11,
#           'improvements': 5,
#           'automate': 4,
#           'record': 19,
#           'tracking': 15,
#           'mobile': 4,
#           'apps': 4,
#           'improved': 15,
#           'efficiency': 6,
#           'managing': 33,
#           'communications': 14,
#           'correspondence': 16,
#           'structure': 5,
#           ...})}

# %% [markdown]
# ### Removing stop words: Common words like "and," "the," "is" are often removed using custom stop words list and also inbuilt stop word list

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Initialize NLTK's stop words
stop_words = set(stopwords.words('english'))

# Iterate through the dataframes dictionary and remove stop words
for subfolder, df in dataframes.items():
    # Tokenize and remove stop words from the "Details" column
    df["Details"] = df["Details"].apply(lambda text: ' '.join([word for word in text.split() if word.lower() not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Vinith
# [nltk_data]     MH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  accountant accounting general accounting accou...
# 1    10674770.pdf  staff accountant accounting accounts payable a...
# 2    11163645.pdf  accountant accounts payables accounts receivab...
# 3    11759079.pdf  senior accountant accounting balance sheet bud...
# 4    12065211.pdf  senior accountant aderantcms excel quickbooks ...
# ..            ...                                                ...
# 113  78403342.pdf  accountant accounting balance budget business ...
# 114  80053367.pdf  general accountant healthcare â sound ethical ...
# 115  82649935.pdf  senior accountant bachelor arts economics city...
# 116  87635012.pdf  principal accountant microsoft excel peachtree...
# 117  98559931.pdf  payroll accountant accounting ap attention det...
#
# [118 rows x 2 columns]

# %%
from collections import Counter

# Initialize a dictionary to store word frequencies for each DataFrame
word_frequencies = {}

# Iterate through the dataframes dictionary
for subfolder, df in dataframes.items():
    # Concatenate all text in the "Details" column
    concatenated_text = ' '.join(df["Details"])
    
    # Tokenize the text (split it into words)
    words = concatenated_text.split()
    
    # Count word frequencies using Counter
    word_freq = Counter(words)
    
    # Store the word frequencies in the dictionary
    word_frequencies[subfolder] = word_freq

# Now, word_frequencies contains word frequencies for each DataFrame within dataframes.
# You can access word frequencies for a specific DataFrame using its subfolder name.

# %%
word_frequencies
# Out:
# {'ACCOUNTANT': Counter({'accountant': 322,
#           'accounting': 1006,
#           'general': 290,
#           'accounts': 569,
#           'payable': 177,
#           'program': 32,
#           'management': 457,
#           'northern': 5,
#           'maine': 1,
#           'community': 37,
#           'college': 76,
#           '1994': 4,
#           'associate': 25,
#           'city': 432,
#           'state': 494,
#           'usa': 28,
#           'emphasis': 3,
#           'business': 361,
#           'associates': 13,
#           'gpa': 111,
#           '341': 2,
#           '174': 1,
#           'hours': 18,
#           'quarter': 7,
#           'attended': 1,
#           'husson': 1,
#           'major': 6,
#           '78': 1,
#           'semester': 3,
#           'toward': 1,
#           'bachelors': 10,
#           'degree': 22,
#           'professional': 54,
#           'military': 16,
#           'comptroller': 1,
#           'school': 55,
#           '6wk': 1,
#           '498': 1,
#           'managerial': 13,
#           '0998': 2,
#           'interestedbased': 1,
#           'bargaining': 3,
#           'training': 90,
#           '24hrs': 1,
#           '0901': 1,
#           'auditing': 48,
#           'methods': 11,
#           'concepts': 4,
#           'organizational': 34,
#           'leadership': 36,
#           '32hrs': 2,
#           '0703': 2,
#           'development': 73,
#           'ii': 33,
#           'certifications': 22,
#           'certified': 52,
#           'defense': 5,
#           'financial': 829,
#           'manager': 63,
#           'cdfm': 1,
#           'may': 43,
#           '2005': 22,
#           'interests': 15,
#           'american': 5,
#           'society': 22,
#           'comptrollers': 1,
#           'additional': 40,
#           'information': 168,
#           'skills': 255,
#           'staff': 99,
#           'receivable': 127,
#           'adp': 30,
#           'advertising': 11,
#           'ar': 59,
#           'balance': 179,
#           'sheet': 108,
#           'bank': 225,
#           'reconciliations': 165,
#           'benefits': 38,
#           'billing': 116,
#           'billings': 23,
#           'book': 23,
#           'keeping': 18,
#           'budget': 165,
#           'cash': 230,
#           'flow': 73,
#           'projections': 6,
#           'controller': 35,
#           'credit': 113,
#           'clients': 100,
#           'data': 77,
#           'collection': 26,
#           'delivery': 23,
#           'documentation': 106,
#           'email': 31,
#           'finance': 157,
#           'reporting': 220,
#           'statements': 232,
#           'fixed': 119,
#           'assets': 107,
#           'ledger': 259,
#           'inventory': 134,
#           'job': 31,
#           'costing': 23,
#           'legal': 32,
#           'materials': 44,
#           'meetings': 24,
#           'microsoft': 212,
#           'access': 76,
#           'excel': 188,
#           'word': 117,
#           'negotiating': 6,
#           'dba': 2,
#           'payables': 45,
#           'payroll': 243,
#           'peachtree': 38,
#           'processes': 132,
#           'coding': 47,
#           'purchasing': 28,
#           'express': 8,
#           'quick': 17,
#           'books': 17,
#           'quickbooks': 136,
#           'research': 80,
#           'sage': 40,
#           'sales': 214,
#           'spreadsheet': 36,
#           'tax': 351,
#           'software': 141,
#           'support': 62,
#           'valuation': 9,
#           'yearend': 62,
#           'activities': 42,
#           'alpha': 15,
#           'sigma': 9,
#           'phi': 12,
#           'officer': 20,
#           'chair': 12,
#           'positions': 9,
#           'january': 49,
#           '2006': 32,
#           '2010': 35,
#           'vice': 7,
#           'president': 14,
#           'social': 5,
#           'greek': 3,
#           'week': 5,
#           'delegate': 3,
#           'livestrong': 3,
#           'foundation': 5,
#           'bikeathon': 3,
#           'bachelor': 111,
#           'science': 104,
#           'university': 206,
#           'north': 11,
#           'carolina': 10,
#           'ï¼': 199,
#           'administration': 144,
#           'experience': 69,
#           '2014': 29,
#           'october': 4,
#           'company': 322,
#           'name': 242,
#           'performed': 62,
#           'month': 76,
#           'end': 96,
#           'functions': 52,
#           'produce': 2,
#           'include': 31,
#           'reconciliation': 141,
#           'operating': 26,
#           'recorded': 36,
#           'journals': 3,
#           'accrued': 3,
#           'submitted': 8,
#           'nc': 3,
#           'department': 70,
#           'revenue': 41,
#           'adjustments': 19,
#           'entries': 100,
#           'entered': 12,
#           'receivables': 35,
#           '7': 9,
#           'franchise': 3,
#           'locations': 7,
#           'worked': 34,
#           'vendors': 34,
#           'resolve': 30,
#           'situations': 1,
#           'arose': 3,
#           'reviewed': 31,
#           'maintained': 65,
#           'needed': 46,
#           'document': 11,
#           'file': 15,
#           'date': 21,
#           'directly': 10,
#           'review': 66,
#           'assembled': 5,
#           'requested': 7,
#           'put': 1,
#           'presentable': 1,
#           'formats': 6,
#           'weekly': 45,
#           'collected': 5,
#           'royalties': 2,
#           'fees': 11,
#           'used': 16,
#           'audit': 83,
#           'managed': 56,
#           'owned': 2,
#           'rented': 1,
#           '12': 13,
#           'commercial': 15,
#           'properties': 7,
#           'shopping': 1,
#           'center': 17,
#           'approved': 13,
#           'businesses': 7,
#           'responsible': 92,
#           'rent': 8,
#           'rates': 3,
#           'new': 78,
#           'renewing': 1,
#           'tenants': 2,
#           'writing': 13,
#           'leases': 4,
#           'collecting': 6,
#           'resolving': 12,
#           'tenant': 3,
#           'complaints': 12,
#           'inquires': 1,
#           'small': 9,
#           'farming': 2,
#           'entity': 7,
#           'maintaining': 19,
#           'setting': 10,
#           'employed': 1,
#           'labor': 6,
#           'work': 89,
#           'filed': 13,
#           'annual': 69,
#           'report': 46,
#           'companies': 22,
#           'cary': 1,
#           'keisler': 1,
#           'inc': 4,
#           'verified': 22,
#           'current': 59,
#           'filings': 13,
#           'march': 6,
#           '2013': 35,
#           'collect': 6,
#           'daily': 86,
#           'deposits': 36,
#           'newly': 1,
#           'sos': 1,
#           'well': 31,
#           'completed': 31,
#           'status': 43,
#           'ran': 4,
#           'interact': 7,
#           'customers': 52,
#           'outstanding': 25,
#           'balances': 17,
#           'due': 15,
#           'po': 3,
#           'non': 2,
#           'entrycoding': 1,
#           'discrepancy': 4,
#           'pull': 1,
#           'weeklyunpaid': 1,
#           'bills': 11,
#           'reports': 278,
#           'complete': 29,
#           'check': 26,
#           'run': 6,
#           'reconcile': 42,
#           'monthly': 194,
#           'card': 17,
#           'ranges': 1,
#           '6000000': 1,
#           '10000000': 1,
#           'helped': 8,
#           'facilitate': 6,
#           'roll': 8,
#           'turnover': 2,
#           'period': 12,
#           'september': 10,
#           'december': 11,
#           'ordering': 12,
#           'materialssupplies': 1,
#           'factory': 1,
#           'production': 16,
#           'floor': 2,
#           'vp': 2,
#           'members': 23,
#           'develop': 15,
#           'unit': 8,
#           'combined': 1,
#           'continued': 7,
#           'future': 6,
#           'april': 12,
#           '2012': 31,
#           'lead': 16,
#           'ensure': 60,
#           'transaction': 10,
#           'deviating': 1,
#           'ordinary': 1,
#           'operations': 71,
#           'project': 54,
#           'cost': 66,
#           'billable': 2,
#           'expenses': 34,
#           'posted': 11,
#           'ensures': 1,
#           'enries': 1,
#           'correct': 12,
#           'account': 198,
#           'provides': 3,
#           'bottom': 1,
#           'line': 6,
#           'design': 20,
#           'prepaid': 16,
#           'employee': 32,
#           'eom': 1,
#           'purposes': 7,
#           'sdi': 2,
#           'battleware': 2,
#           '10': 6,
#           'entry': 40,
#           'custodial': 1,
#           'sdis': 2,
#           'depreciation': 24,
#           'interest': 16,
#           'sweep': 1,
#           'accurate': 49,
#           'items': 24,
#           'prepare': 115,
#           'use': 27,
#           'partner': 9,
#           'july': 5,
#           'august': 14,
#           '2011': 38,
#           'identified': 12,
#           'reported': 13,
#           'tracked': 13,
#           'resolved': 38,
#           'subsidiary': 8,
#           'discrepancies': 46,
#           'phases': 2,
#           'revenues': 5,
#           'provide': 30,
#           'statement': 65,
#           'assurance': 17,
#           'presentation': 20,
#           'aiding': 1,
#           'completing': 9,
#           'tasks': 12,
#           'areas': 14,
#           'performing': 24,
#           'applying': 4,
#           'required': 33,
#           'regulations': 8,
#           'preparing': 43,
#           'provided': 34,
#           'employees': 35,
#           'via': 10,
#           'implementations': 3,
#           'issues': 55,
#           'aspects': 11,
#           'daytoday': 3,
#           'trained': 18,
#           'functionality': 1,
#           'demonstration': 1,
#           'assist': 47,
#           'proficient': 19,
#           'transitioning': 2,
#           'ie': 2,
#           'able': 6,
#           'perform': 41,
#           'duties': 35,
#           'departments': 32,
#           'including': 114,
#           'coordination': 18,
#           'transactional': 1,
#           'coordinate': 6,
#           'lien': 4,
#           'foreclosure': 3,
#           'preparations': 6,
#           'ownership': 2,
#           'histories': 4,
#           'order': 24,
#           'accurately': 15,
#           'claims': 5,
#           'behalf': 2,
#           'cliental': 1,
#           'constant': 1,
#           'analysis': 212,
#           'interim': 4,
#           'comparative': 2,
#           'verify': 13,
#           'validity': 8,
#           'monitor': 15,
#           'inconsistency': 1,
#           'variance': 30,
#           'explanations': 3,
#           'quickly': 8,
#           'summarize': 2,
#           'increased': 12,
#           'variances': 28,
#           'fund': 25,
#           'board': 19,
#           'audits': 46,
#           'returns': 85,
#           'cycles': 1,
#           'adjusting': 9,
#           'transactions': 75,
#           'gl': 52,
#           'posting': 18,
#           'errors': 18,
#           'administrative': 79,
#           'trial': 20,
#           'banking': 56,
#           'bi': 18,
#           'closing': 132,
#           'computer': 53,
#           'applications': 34,
#           'customer': 146,
#           'service': 102,
#           'driving': 16,
#           'insurance': 63,
#           'outlook': 83,
#           'powerpoint': 72,
#           'mortgage': 7,
#           'loan': 20,
#           'enterprise': 19,
#           'policies': 95,
#           'telecommunications': 3,
#           'phone': 29,
#           'workflow': 4,
#           'written': 36,
#           'senior': 67,
#           'budgets': 42,
#           'client': 59,
#           'derivatives': 6,
#           'drafting': 8,
#           'equity': 16,
#           'funds': 64,
#           'government': 49,
#           'technology': 17,
#           'investments': 4,
#           'natural': 4,
#           'page': 6,
#           'programming': 9,
#           'real': 29,
#           'estate': 29,
#           'scheme': 2,
#           'telephone': 23,
#           'awards': 8,
#           'fulton': 6,
#           'county': 17,
#           'casa': 6,
#           'directors': 13,
#           'member': 33,
#           'treasurer': 7,
#           'plan': 19,
#           'raisers': 4,
#           'supervise': 8,
#           'notforprofit': 4,
#           'organization': 31,
#           'trains': 4,
#           'volunteers': 6,
#           'mentor': 3,
#           'children': 3,
#           'pulled': 3,
#           'homes': 5,
#           'court': 5,
#           'system': 145,
#           'abuse': 3,
#           'neglect': 3,
#           'cpa': 50,
#           'hold': 7,
#           'active': 11,
#           'georgia': 3,
#           'license': 19,
#           'scored': 5,
#           '87': 3,
#           '93': 3,
#           'possible': 4,
#           '99': 3,
#           'four': 6,
#           'sections': 4,
#           'exam': 5,
#           'cfe': 3,
#           'fraud': 12,
#           'examiner': 5,
#           'requires': 3,
#           'passing': 2,
#           'exams': 2,
#           'two': 11,
#           'years': 16,
#           'preventing': 3,
#           'detecting': 2,
#           'recipient': 7,
#           '2007': 16,
#           'john': 2,
#           'r': 3,
#           'jones': 2,
#           'award': 15,
#           'given': 2,
#           'annually': 10,
#           'vote': 2,
#           'emory': 7,
#           'professors': 4,
#           'recognize': 4,
#           'top': 7,
#           'year': 41,
#           'student': 28,
#           'academia': 2,
#           'involvement': 4,
#           'character': 2,
#           'ben': 2,
#           'pius': 2,
#           'awarded': 12,
#           'exceptional': 6,
#           'achievements': 2,
#           'highest': 4,
#           'junior': 4,
#           'goizueta': 1,
#           '5': 17,
#           '36340': 2,
#           '37740': 2,
#           'aderantcms': 2,
#           'pro': 16,
#           'sql': 9,
#           'accessâ': 1,
#           'hyperion': 28,
#           'us': 38,
#           'gaap': 25,
#           'principles': 18,
#           'ifrs': 1,
#           'bookkeeping': 51,
#           'individual': 23,
#           'essbase': 11,
#           'history': 21,
#           'mar': 4,
#           'various': 80,
#           'limited': 8,
#           'liability': 5,
#           'purpose': 3,
#           'accuracy': 45,
#           'accordance': 21,
#           'international': 46,
#           'legislative': 1,
#           'basis': 54,
#           'primary': 5,
#           'liaison': 8,
#           'function': 6,
#           'deloitteâ': 1,
#           'assigned': 18,
#           'schedules': 28,
#           'auditsâ': 1,
#           'auditors': 28,
#           'understanding': 14,
#           'firms': 2,
#           'internal': 52,
#           'controls': 26,
#           'expenditure': 5,
#           'cycle': 17,
#           'â': 174,
#           'analyze': 37,
#           'journal': 82,
#           'original': 2,
#           'source': 3,
#           'found': 5,
#           'initiate': 2,
#           'discussions': 1,
#           'specialists': 1,
#           'payrolls': 2,
#           'inâ': 1,
#           'aspect': 1,
#           'income': 35,
#           'local': 28,
#           'consumption': 1,
#           'fringe': 3,
#           'benefit': 15,
#           'deductions': 3,
#           'seoul': 4,
#           'shanghai': 2,
#           'tokyo': 3,
#           'office': 277,
#           'upload': 2,
#           'reconcileâ': 1,
#           'value': 6,
#           'added': 4,
#           'vienna': 2,
#           'currency': 5,
#           'fluctuation': 1,
#           'record': 47,
#           'gainslosses': 3,
#           'related': 36,
#           'exchange': 10,
#           'offices': 6,
#           'firm': 12,
#           'using': 29,
#           'mode': 1,
#           'expatriate': 3,
#           'expenditures': 16,
#           'w2': 4,
#           'form': 4,
#           'initial': 2,
#           'k1': 2,
#           'monthend': 32,
#           'accrual': 21,
#           'base': 4,
#           'wage': 3,
#           'bonus': 1,
#           'occupancy': 1,
#           'property': 37,
#           'catering': 1,
#           'accruals': 49,
#           'expense': 49,
#           'allocations': 5,
#           'intercompany': 10,
#           'shared': 4,
#           'partners': 6,
#           'translation': 1,
#           'asset': 54,
#           'invoices': 54,
#           'asian': 1,
#           'travel': 20,
#           'notable': 1,
#           'accomplishments': 18,
#           'material': 14,
#           'misstatement': 1,
#           'first': 13,
#           '08': 2,
#           'made': 13,
#           'prospective': 3,
#           'clarity': 1,
#           'japanese': 1,
#           'systems': 85,
#           'associated': 7,
#           'health': 23,
#           'welfare': 1,
#           'childcare': 1,
#           'allowance': 5,
#           'jan': 26,
#           'maintain': 45,
#           'records': 48,
#           'parent': 1,
#           'investors': 4,
#           'semiannual': 3,
#           'bs': 12,
#           'flows': 8,
#           'warehouse': 7,
#           'shipping': 9,
#           'communicate': 5,
#           'outside': 8,
#           'companys': 16,
#           'designated': 1,
#           'cpas': 6,
#           'arise': 2,
#           'establish': 6,
#           'master': 40,
#           'receive': 6,
#           'compute': 1,
#           'make': 21,
#           '401k': 7,
#           'thru': 1,
#           'paychex': 3,
#           'factoring': 1,
#           'arrangements': 8,
#           'schedule': 14,
#           'guidance': 5,
#           'site': 4,
#           'personnel': 47,
#           'analyst': 20,
#           'aug': 10,
#           '2002': 15,
#           'manage': 33,
#           'forecast': 19,
#           'palm': 1,
#           'desert': 1,
#           'national': 23,
#           'sponsored': 1,
#           '350': 2,
#           'atm': 10,
#           'terminals': 1,
#           'averaging': 1,
#           '25': 5,
#           'million': 15,
#           'settle': 2,
#           'act': 13,
#           'innobeta': 1,
#           'affiliate': 2,
#           'money': 15,
#           'marketing': 37,
#           'profit': 29,
#           'loss': 14,
#           'surcharge': 1,
#           'interchange': 1,
#           'communication': 68,
#           'armor': 1,
#           'carrier': 1,
#           'temporary': 5,
#           'team': 74,
#           'diligence': 7,
#           'procedure': 6,
#           'world': 6,
#           'corp': 3,
#           'processing': 63,
#           'costs': 26,
#           'network': 4,
#           'terms': 6,
#           'efts': 2,
#           'papers': 7,
#           'confirmations': 1,
#           'efficient': 15,
#           'connection': 1,
#           'prepared': 96,
#           'closings': 7,
#           'preparation': 124,
#           'full': 26,
#           'footnotes': 1,
#           'lenders': 1,
#           'assure': 7,
#           'certain': 2,
#           'procedures': 108,
#           'routinely': 2,
#           'according': 5,
#           'translate': 1,
#           'documents': 26,
#           'pertaining': 5,
#           'defective': 1,
#           'parts': 3,
#           'comnet': 2,
#           'series': 3,
#           'distributed': 5,
#           'nextran': 1,
#           'industries': 2,
#           'chungho': 1,
#           'co': 4,
#           'ltd': 1,
#           'consult': 1,
#           'private': 5,
#           'services': 40,
#           'education': 55,
#           'temple': 5,
#           'identifying': 3,
#           'potential': 8,
#           'risks': 9,
#           'would': 11,
#           'impact': 7,
#           'xerox': 8,
#           'select': 7,
#           'courses': 16,
#           'advance': 11,
#           'taxation': 28,
#           'travelphotographygolfsoccermoviefashion': 2,
#           'public': 50,
#           'york': 9,
#           'issued': 8,
#           '03042015': 2,
#           'number': 14,
#           '117205': 2,
#           'aps': 2,
#           '2001': 8,
#           'investment': 26,
#           'internet': 10,
#           'ms': 82,
#           'power': 28,
#           'point': 29,
#           'pivot': 27,
#           'tables': 38,
#           'spreadsheets': 38,
#           'macros': 12,
#           'objects': 12,
#           'lombardi': 4,
#           'eagle': 5,
#           'pega': 4,
#           'dras': 3,
#           'workbench': 4,
#           'detailoriented': 6,
#           'analytical': 32,
#           'expert': 13,
#           'suite': 19,
#           'effective': 15,
#           'time': 43,
#           'complex': 23,
#           'problem': 30,
#           'solving': 21,
#           'superior': 18,
#           'multiple': 25,
#           'performanceformally': 1,
#           'recognized': 7,
#           'excellence': 7,
#           'achieved': 4,
#           'budgeting': 53,
#           'forecastingincreased': 1,
#           'efficiency': 16,
#           'investigations': 11,
#           'designing': 3,
#           'cashforecasting': 1,
#           '102012': 1,
#           '112015': 1,
#           'reconciled': 52,
#           'mutual': 1,
#           'custody': 3,
#           'differences': 4,
#           'iax': 1,
#           'communicated': 11,
#           'collaborated': 3,
#           'custodians': 2,
#           'impacted': 1,
#           'conducted': 20,
#           'special': 30,
#           'projects': 26,
#           'oversee': 10,
#           'assisted': 62,
#           'offshore': 1,
#           'pune': 2,
#           'india': 19,
#           'acted': 2,
#           'tests': 12,
#           'vs': 2,
#           'platform': 1,
#           'migration': 5,
#           'meet': 19,
#           'goals': 15,
#           'accountants': 17,
#           'database': 56,
#           'received': 21,
#           'achievement': 17,
#           'bny': 2,
#           'mellon': 2,
#           'servicing': 1,
#           'dec': 12,
#           'servcing': 1,
#           'aml': 1,
#           'compliance': 77,
#           '112011': 1,
#           '032012': 2,
#           'audited': 12,
#           'quality': 36,
#           'reviews': 14,
#           'results': 10,
#           'background': 4,
#           'search': 4,
#           'tools': 15,
#           'google': 1,
#           'ud': 1,
#           '1': 26,
#           'group': 7,
#           'simulation': 1,
#           'philosophy': 1,
#           'strategy': 16,
#           'drive': 4,
#           'simulated': 1,
#           '1000000': 1,
#           'stocktrack': 1,
#           'invested': 3,
#           '50': 3,
#           'moderate': 4,
#           'highrisk': 1,
#           'achieve': 11,
#           'capital': 20,
#           'appreciation': 1,
#           'low': 3,
#           'risk': 19,
#           'preserve': 1,
#           'rest': 1,
#           'index': 1,
#           'market': 15,
#           'determine': 20,
#           'allocation': 8,
#           'stocks': 5,
#           'minimizing': 3,
#           'cv': 1,
#           'graphed': 1,
#           'regression': 2,
#           'analyzed': 38,
#           'statistics': 11,
#           'groups': 10,
#           'portfolio': 9,
#           'case': 9,
#           'price': 7,
#           'momentum': 4,
#           'model': 5,
#           'test': 7,
#           'whether': 1,
#           'stock': 5,
#           'canadian': 1,
#           'weighted': 1,
#           'created': 23,
#           'worst': 1,
#           'best': 21,
#           'selected': 3,
#           'eight': 1,
#           'create': 5,
#           'compared': 3,
#           'pricing': 24,
#           'calculated': 4,
#           'average': 3,
#           'return': 14,
#           'rebalanced': 1,
#           'sp': 1,
#           '500': 4,
#           'within': 31,
#           'medical': 33,
#           'technologist': 1,
#           '072008': 1,
#           'clinical': 3,
#           'microbiology': 1,
#           'highlights': 6,
#           'plating': 1,
#           'culturing': 1,
#           'patients': 10,
#           'specimens': 1,
#           'rapid': 4,
#           'flu': 1,
#           'cdiff': 1,
#           'many': 4,
#           'confirmatory': 1,
#           'identify': 16,
#           'organism': 1,
#           'reading': 10,
#           'gram': 1,
#           'stain': 1,
#           'slides': 1,
#           'maintenance': 27,
#           'running': 3,
#           'control': 36,
#           'instruments': 5,
#           'delaware': 4,
#           '2008': 24,
#           'course': 17,
#           'corporate': 78,
#           'governance': 3,
#           'engineering': 3,
#           'languages': 27,
#           'english': 30,
#           'marathi': 2,
#           'hindi': 8,
#           'gujarati': 2,
#           'personal': 37,
#           'excellent': 34,
#           'multitasking': 10,
#           'thinking': 12,
#           'negotiation': 6,
#           'vlook': 3,
#           'platforms': 3,
#           '3d': 2,
#           'adobe': 17,
#           'illustrator': 3,
#           'photoshop': 3,
#           'pagemaker': 2,
#           'audio': 2,
#           'editing': 13,
#           'contracts': 71,
#           'debit': 18,
#           'dos': 4,
#           'hr': 23,
#           'inspection': 4,
#           'macro': 2,
#           'media': 9,
#           'director': 26,
#           '2k': 2,
#           'windows': 30,
#           '9x': 2,
#           'works': 14,
#           'mis': 9,
#           'modeling': 9,
#           'developer': 6,
#           '2000': 24,
#           'oracle': 38,
#           '8i': 2,
#           'video': 4,
#           'affiliations': 24,
#           'enter': 3,
#           'organizations': 6,
#           'involved': 4,
#           'see': 2,
#           'examples': 2,
#           'vidyasagar': 1,
#           'mba': 19,
#           'mohan': 1,
#           'lal': 1,
#           'sukhadia': 1,
#           'strayer': 5,
#           'attention': 19,
#           'detail': 19,
#           'invoice': 28,
#           'familiarity': 8,
#           'selfmotivated': 9,
#           'strong': 45,
#           'trending': 1,
#           'knowledge': 27,
#           'advanced': 30,
#           ...}),
#  'ADVOCATE': Counter({'child': 67,
#           'family': 45,
#           'advocate': 158,
#           'scheduling': 58,
#           'appointments': 37,
#           '400': 3,
#           'budgets': 17,
#           'call': 51,
#           'center': 68,
#           'customer': 378,
#           'service': 306,
#           'financial': 122,
#           'funds': 8,
#           'labor': 13,
#           'relations': 59,
#           'leadership': 87,
#           'sales': 235,
#           'l': 6,
#           'coursework': 13,
#           'organizational': 56,
#           'behavior': 35,
#           'compensation': 14,
#           'recruitment': 15,
#           'continuing': 8,
#           'education': 100,
#           'human': 116,
#           'services': 151,
#           'greenville': 1,
#           'college': 142,
#           'desktop': 2,
#           'publishing': 1,
#           'workshop': 3,
#           'ï¼': 269,
#           'city': 624,
#           'state': 676,
#           'skills': 321,
#           'summary': 7,
#           'army': 5,
#           'benefits': 55,
#           'billing': 85,
#           'blueprints': 2,
#           'catalogs': 2,
#           'coaching': 42,
#           'hand': 8,
#           'tools': 14,
#           'inspect': 2,
#           'logistics': 10,
#           'mechanical': 4,
#           'mail': 30,
#           'power': 29,
#           'quality': 113,
#           'read': 3,
#           'recording': 14,
#           'research': 78,
#           'safety': 53,
#           'soldering': 2,
#           'solder': 2,
#           'supply': 7,
#           'chain': 3,
#           'management': 382,
#           'phone': 72,
#           'troubleshooting': 33,
#           'typing': 19,
#           'wiring': 4,
#           'post': 6,
#           'secondary': 1,
#           'training': 191,
#           'certificate': 53,
#           '2011': 33,
#           'florida': 3,
#           'jacksonville': 6,
#           'diploma': 44,
#           '2003': 10,
#           'concorde': 1,
#           'career': 14,
#           'institution': 5,
#           'military': 16,
#           '84': 1,
#           '92': 1,
#           'united': 23,
#           'states': 26,
#           'communications': 25,
#           'specialist': 32,
#           'received': 29,
#           'honorable': 3,
#           'discharge': 9,
#           'substitute': 2,
#           'teacher': 13,
#           'adaptive': 4,
#           'equipment': 41,
#           'administrative': 84,
#           'duties': 45,
#           'appointment': 11,
#           'setting': 26,
#           'agency': 40,
#           'blood': 22,
#           'pressure': 16,
#           'cna': 8,
#           'consultant': 25,
#           'cpr': 35,
#           'certified': 44,
#           'first': 31,
#           'aid': 20,
#           'home': 43,
#           'care': 235,
#           'team': 182,
#           'building': 39,
#           'meal': 3,
#           'prep': 5,
#           'medical': 160,
#           'terminology': 15,
#           'medication': 23,
#           'meetings': 83,
#           'bathing': 4,
#           'policies': 98,
#           'record': 37,
#           'keeping': 14,
#           'inventory': 58,
#           'teaching': 18,
#           'phones': 27,
#           'therapy': 15,
#           'vision': 10,
#           'wounds': 2,
#           'written': 42,
#           'communication': 84,
#           'bachelor': 77,
#           'arts': 39,
#           'psychology': 49,
#           'minor': 11,
#           'social': 78,
#           'work': 156,
#           '2012': 61,
#           'governor': 1,
#           'university': 196,
#           'associate': 46,
#           'science': 110,
#           '2004': 24,
#           'south': 14,
#           'suburban': 2,
#           'express': 5,
#           'scripts': 10,
#           'cash': 78,
#           'handling': 27,
#           'excellent': 68,
#           'interpersonal': 47,
#           'detailoriented': 15,
#           'merchandising': 11,
#           'selfmotivated': 14,
#           '70': 3,
#           'wpm': 11,
#           'high': 112,
#           'school': 121,
#           'business': 200,
#           'computers': 7,
#           'camden': 1,
#           'county': 12,
#           'rn': 21,
#           'asst': 3,
#           'head': 11,
#           'nurse': 54,
#           'practice': 20,
#           'leader': 21,
#           'planning': 61,
#           'case': 71,
#           'health': 183,
#           'hospice': 1,
#           'infection': 2,
#           'control': 37,
#           'injections': 11,
#           'manager': 84,
#           'oncology': 10,
#           'staff': 161,
#           'development': 113,
#           'trauma': 16,
#           'triage': 7,
#           'tutoring': 4,
#           'urology': 5,
#           'experience': 98,
#           '092010': 1,
#           '122011': 3,
#           'company': 381,
#           'name': 348,
#           'hired': 4,
#           'adon': 1,
#           'assistant': 60,
#           'director': 57,
#           'nursing': 94,
#           '85': 2,
#           '90': 3,
#           'bed': 4,
#           'long': 8,
#           'term': 12,
#           'mentally': 3,
#           'physically': 1,
#           'disabled': 5,
#           'children': 69,
#           '2': 17,
#           'years': 38,
#           'upper': 5,
#           '20s': 1,
#           'older': 1,
#           'individuals': 20,
#           'job': 21,
#           'included': 17,
#           'staffing': 25,
#           'nurses': 8,
#           'monthly': 50,
#           'transportation': 15,
#           'outside': 12,
#           'md': 5,
#           'office': 183,
#           'visits': 15,
#           'residents': 14,
#           'monitoring': 36,
#           '3': 4,
#           'units': 6,
#           'day': 29,
#           'documentation': 72,
#           'taking': 16,
#           'needed': 47,
#           'twice': 3,
#           'month': 7,
#           'mod': 1,
#           'entire': 1,
#           'conducted': 32,
#           'inservices': 2,
#           'answered': 13,
#           'pages': 2,
#           'questions': 31,
#           'oversee': 5,
#           'critical': 29,
#           'changes': 40,
#           'helped': 23,
#           'decisions': 7,
#           'transfer': 5,
#           'hospital': 45,
#           'speaking': 25,
#           'mdhelped': 1,
#           'secured': 8,
#           'position': 14,
#           'rescare': 1,
#           'located': 8,
#           'oak': 3,
#           'park': 9,
#           'illinois': 34,
#           '2015': 45,
#           'made': 22,
#           'overseeing': 4,
#           'clients': 178,
#           'overall': 7,
#           'basic': 27,
#           'assessments': 26,
#           'listened': 2,
#           'new': 149,
#           'complaints': 22,
#           'change': 23,
#           'status': 39,
#           'would': 11,
#           'doctor': 6,
#           'inform': 5,
#           'gave': 3,
#           'infusions': 1,
#           'participated': 22,
#           'one': 21,
#           'clinical': 66,
#           'trial': 2,
#           'aspects': 14,
#           'visit': 6,
#           'timed': 1,
#           'documented': 13,
#           'per': 28,
#           'protocal': 1,
#           'still': 4,
#           'registered': 13,
#           'need': 21,
#           'part': 21,
#           'time': 78,
#           'july': 16,
#           '2016': 31,
#           'best': 32,
#           'jobs': 10,
#           'available': 21,
#           'minimal': 2,
#           'took': 17,
#           'roster': 3,
#           'fall': 4,
#           'worked': 53,
#           'maxim': 1,
#           'asking': 1,
#           'infusion': 3,
#           'cases': 21,
#           'promised': 1,
#           'ones': 1,
#           '40': 16,
#           'miles': 4,
#           'away': 2,
#           'didnt': 2,
#           'cover': 4,
#           'milage': 1,
#           'rarely': 1,
#           'called': 8,
#           'currently': 10,
#           'looking': 4,
#           'line': 8,
#           'going': 5,
#           'facility': 20,
#           '30': 27,
#           'minute': 4,
#           'drive': 7,
#           'online': 26,
#           'willing': 5,
#           'learn': 13,
#           'pt': 2,
#           'oncologyhospice': 1,
#           'additional': 50,
#           'professional': 103,
#           'activities': 57,
#           'ocn': 2,
#           'past': 13,
#           'med': 9,
#           'surg': 4,
#           'plan': 65,
#           'recertify': 1,
#           'future': 11,
#           'north': 9,
#           'shore': 1,
#           'youth': 14,
#           'baseball': 2,
#           'league': 5,
#           '4': 22,
#           'references': 1,
#           'dr': 4,
#           'emil': 1,
#           'totonchi': 1,
#           'masonic': 11,
#           'michael': 1,
#           'friedman': 1,
#           'beverly': 1,
#           'bohus': 1,
#           'lorel': 1,
#           'hedges': 1,
#           'practioner': 1,
#           'works': 14,
#           'tennessee': 4,
#           'uma': 1,
#           'kelkar': 1,
#           'rehab': 3,
#           'manor': 5,
#           'northbrook': 3,
#           'jean': 1,
#           'gavina': 1,
#           'mds': 14,
#           'elma': 1,
#           'ramos': 1,
#           'evening': 1,
#           'supervisor': 49,
#           'contact': 24,
#           'information': 169,
#           'upon': 10,
#           'request': 13,
#           '062009': 5,
#           '072010': 11,
#           'started': 3,
#           'promoted': 10,
#           'dcd': 1,
#           'delivery': 33,
#           'managing': 45,
#           'locked': 1,
#           'dementia': 2,
#           'unit': 51,
#           'later': 3,
#           '60': 4,
#           'recently': 1,
#           'back': 11,
#           'along': 8,
#           'leading': 11,
#           'priorities': 7,
#           'upholding': 1,
#           'corporate': 16,
#           'standards': 14,
#           'communicating': 7,
#           'existing': 26,
#           'systems': 79,
#           'material': 6,
#           'qa': 1,
#           'understanding': 23,
#           'issues': 103,
#           'valuing': 1,
#           'every': 9,
#           'employee': 58,
#           'supporting': 4,
#           'attending': 12,
#           'interdisciplinary': 9,
#           'daily': 64,
#           'weekly': 22,
#           'medicare': 14,
#           'investigation': 5,
#           'falls': 5,
#           'skin': 4,
#           'injuries': 6,
#           'admissions': 10,
#           'assists': 2,
#           'hiring': 22,
#           'disciplinary': 4,
#           'actions': 5,
#           'resigned': 1,
#           '2010': 34,
#           'want': 2,
#           'take': 13,
#           'vacation': 4,
#           'find': 6,
#           'somewhat': 1,
#           'closer': 2,
#           '011977': 2,
#           '012009': 12,
#           'responsible': 64,
#           '24': 7,
#           'hr': 18,
#           'basis': 24,
#           'including': 86,
#           'payroll': 42,
#           'monitor': 11,
#           'rns': 7,
#           'ncts': 1,
#           'clerks': 1,
#           'assignments': 8,
#           'learning': 37,
#           'needs': 113,
#           'occasionally': 1,
#           'fill': 13,
#           'voids': 1,
#           'reported': 9,
#           'tasks': 25,
#           'keep': 10,
#           'current': 76,
#           'problems': 31,
#           'interview': 5,
#           'process': 71,
#           'activity': 10,
#           'terminations': 3,
#           'sought': 2,
#           'scheduled': 11,
#           'sure': 8,
#           'attended': 16,
#           'required': 29,
#           'mandatories': 1,
#           'yearly': 6,
#           'general': 38,
#           'recruited': 2,
#           'chairman': 1,
#           'open': 11,
#           '1st': 7,
#           'inpatient': 7,
#           'also': 30,
#           'next': 2,
#           '20': 13,
#           'earned': 5,
#           'instruct': 1,
#           'become': 3,
#           'mix': 1,
#           'chemo': 1,
#           'drugs': 6,
#           'via': 29,
#           'laminar': 1,
#           'flow': 14,
#           'hood': 1,
#           'administer': 2,
#           'safely': 2,
#           'side': 14,
#           'effects': 11,
#           'manage': 41,
#           'symptoms': 6,
#           'beside': 1,
#           'patient': 162,
#           'load': 6,
#           'many': 25,
#           'days': 8,
#           'week': 15,
#           '1999': 7,
#           'changed': 2,
#           'surgical': 14,
#           '23hr': 1,
#           'observation': 2,
#           'approximately': 9,
#           'leaderequal': 1,
#           'expanded': 2,
#           'installed': 13,
#           'computer': 66,
#           'profiency': 1,
#           'classes': 7,
#           'progress': 43,
#           'charting': 3,
#           'patients': 150,
#           'workshops': 13,
#           'seminar': 6,
#           'picc': 5,
#           'insertion': 7,
#           'point': 33,
#           'headed': 1,
#           'program': 97,
#           'kept': 15,
#           'records': 47,
#           'piccs': 1,
#           'placed': 1,
#           'complications': 4,
#           'became': 7,
#           'nationally': 5,
#           'exam': 5,
#           'passing': 1,
#           'types': 9,
#           'seen': 2,
#           'thisunit': 1,
#           'include': 23,
#           'gyne': 1,
#           'sicu': 1,
#           'neck': 2,
#           'ent': 1,
#           'fetal': 1,
#           'demises': 1,
#           'less': 1,
#           'weeks': 2,
#           'due': 12,
#           'number': 5,
#           'private': 6,
#           'rooms': 8,
#           'isolation': 2,
#           'ro': 1,
#           'tb': 2,
#           'negative': 6,
#           'air': 1,
#           'room': 7,
#           'short': 1,
#           'stay': 5,
#           'anywhere': 5,
#           'overnight': 4,
#           '23': 3,
#           'overflow': 1,
#           'medicals': 1,
#           'extensive': 12,
#           '45': 5,
#           'result': 4,
#           'fast': 20,
#           'paced': 6,
#           'half': 2,
#           'discharged': 1,
#           'within': 48,
#           '12': 5,
#           'shifts': 4,
#           'beds': 1,
#           'filled': 2,
#           'main': 1,
#           'placing': 3,
#           'correctly': 7,
#           'assignment': 1,
#           'competent': 3,
#           'coming': 4,
#           'frequent': 1,
#           'rounds': 5,
#           'assure': 4,
#           'satisfaction': 56,
#           'quickly': 16,
#           'preventing': 2,
#           'escalating': 2,
#           'try': 3,
#           'set': 21,
#           'review': 51,
#           'based': 53,
#           'inservice': 3,
#           'send': 8,
#           'seminars': 16,
#           'budget': 44,
#           'allowed': 1,
#           'checking': 4,
#           'printed': 1,
#           'areas': 24,
#           'missing': 8,
#           'incorrect': 5,
#           'make': 18,
#           'aware': 1,
#           'correct': 23,
#           'help': 49,
#           'correction': 1,
#           'last': 3,
#           'done': 3,
#           'two': 18,
#           'adequate': 2,
#           '1976': 6,
#           '1974': 2,
#           'northeastern': 2,
#           '1973': 2,
#           'western': 8,
#           'awards': 19,
#           'dorothy': 2,
#           'rome': 2,
#           'nominee': 2,
#           'highest': 4,
#           'award': 51,
#           'experienced': 15,
#           'awarded': 12,
#           'applause': 2,
#           'awardsâ': 2,
#           'nominated': 2,
#           'excellence': 8,
#           'asked': 5,
#           'turned': 2,
#           'interventional': 3,
#           'radiology': 3,
#           'travel': 12,
#           'booking': 1,
#           'thinking': 17,
#           'creative': 19,
#           'problem': 80,
#           'solving': 39,
#           'cellular': 3,
#           'expert': 13,
#           'smartphones': 1,
#           'network': 50,
#           'connections': 4,
#           'internet': 20,
#           'wifi': 1,
#           'core': 2,
#           'accomplishments': 14,
#           'calendaring': 1,
#           'â': 348,
#           'planned': 10,
#           'ceo': 4,
#           'improvement': 16,
#           'oversaw': 14,
#           'implementation': 21,
#           'system': 100,
#           'resulted': 9,
#           'costeffective': 1,
#           'investigated': 4,
#           'analyzed': 15,
#           'client': 142,
#           'identify': 28,
#           'resolve': 29,
#           'multitasking': 18,
#           'demonstrated': 11,
#           'proficiencies': 1,
#           'telephone': 37,
#           'email': 23,
#           'fax': 4,
#           'frontdesk': 1,
#           'reception': 2,
#           'highvolume': 3,
#           'environment': 50,
#           'handled': 16,
#           'customers': 103,
#           'effectively': 28,
#           'identifying': 11,
#           'gaining': 3,
#           'trust': 9,
#           'approaching': 1,
#           'complex': 21,
#           'situations': 20,
#           'resolving': 15,
#           'maximize': 7,
#           'efficiency': 20,
#           'assistance': 52,
#           'assisted': 41,
#           'preparation': 10,
#           'entered': 8,
#           'data': 138,
#           'cumulative': 3,
#           'document': 15,
#           'september': 19,
#           '2007': 30,
#           'march': 21,
#           'volume': 34,
#           'incoming': 16,
#           'calls': 57,
#           'national': 43,
#           'prospective': 17,
#           'well': 62,
#           'associates': 16,
#           'actively': 4,
#           'ensure': 43,
#           'complete': 18,
#           'concerns': 24,
#           'provided': 94,
#           'innovative': 6,
#           'individualized': 4,
#           'solutions': 34,
#           'obtained': 9,
#           'resolution': 60,
#           'reassurance': 1,
#           'positive': 24,
#           'end': 8,
#           'accessed': 3,
#           'account': 41,
#           'database': 75,
#           'retrieve': 1,
#           'update': 11,
#           'maintaining': 21,
#           'personable': 1,
#           'conversations': 4,
#           'flexibly': 1,
#           'adjusted': 2,
#           'styles': 1,
#           'caller': 2,
#           'particularly': 1,
#           'terms': 7,
#           'level': 36,
#           'familiarity': 2,
#           'technology': 45,
#           'structures': 1,
#           'understood': 1,
#           'instructions': 2,
#           'procedures': 47,
#           'administered': 19,
#           'devicerelated': 1,
#           'interactions': 10,
#           'transactions': 24,
#           'details': 13,
#           'inquiries': 36,
#           'comments': 2,
#           'taken': 3,
#           'maintained': 56,
#           'uptodate': 6,
#           'knowledge': 68,
#           'constantly': 1,
#           'changing': 4,
#           'products': 50,
#           'order': 48,
#           'provide': 86,
#           'accurate': 43,
#           'legal': 50,
#           'secretary': 14,
#           'january': 46,
#           '2006': 21,
#           'may': 49,
#           'prepared': 25,
#           'court': 28,
#           'documents': 39,
#           'deeds': 1,
#           'real': 9,
#           'estate': 5,
#           'statements': 9,
#           'purchase': 10,
#           'agreements': 5,
#           'contracts': 30,
#           'attorney': 4,
#           'wills': 1,
#           'routine': 10,
#           'correspondence': 13,
#           'performed': 43,
#           'accounting': 40,
#           'accounts': 90,
#           'receivable': 11,
#           'payable': 17,
#           'entry': 61,
#           'slips': 1,
#           'taxes': 4,
#           'balancing': 3,
#           'estates': 1,
#           'greeted': 5,
#           'offered': 5,
#           'seats': 1,
#           'waited': 1,
#           'updating': 3,
#           'administering': 3,
#           'reminders': 1,
#           'lawyers': 6,
#           'ensured': 20,
#           'wellstocked': 1,
#           'supplies': 19,
#           'organized': 40,
#           'maximum': 3,
#           'assistantcustomer': 1,
#           'rep': 4,
#           'august': 17,
#           '2005': 28,
#           'directly': 7,
#           'president': 25,
#           'doane': 13,
#           'chief': 8,
#           'officer': 21,
#           'schedule': 22,
#           'events': 29,
#           'put': 1,
#           'together': 1,
#           'materials': 36,
#           'board': 24,
#           'meeting': 11,
#           'minutes': 5,
#           'member': 101,
#           'booked': 1,
#           'arrangements': 4,
#           'created': 46,
#           'itinerary': 1,
#           'trips': 1,
#           'retail': 19,
#           'banking': 11,
#           'representative': 34,
#           'ii': 16,
#           'june': 16,
#           '2002': 14,
#           'assisting': 25,
#           'person': 8,
#           'opened': 6,
#           'solved': 5,
#           'crosssold': 1,
#           'scanned': 2,
#           'checks': 13,
#           'drawer': 3,
#           'atm': 3,
#           'vault': 4,
#           'total': 7,
#           'branch': 1,
#           'majors': 2,
#           'fine': 3,
#           'art': 12,
#           'biology': 3,
#           '1985': 12,
#           'presidents': 10,
#           'scholarship': 17,
#           'outstanding': 11,
#           'achievement': 24,
#           'pallet': 2,
#           'scholar': 3,
#           'american': 33,
#           'legion': 2,
#           'loup': 2,
#           'ne': 2,
#           '1981': 3,
#           'special': 31,
#           'recognition': 14,
#           'yearbook': 4,
#           'editor': 7,
#           'mary': 2,
#           'chapin': 2,
#           'senior': 40,
#           'cohead': 2,
#           'photographer': 2,
#           '1984': 4,
#           'delta': 8,
#           'chi': 3,
#           'upsilon': 2,
#           'sorority': 3,
#           'xanadu': 2,
#           'literary': 2,
#           'magazine': 7,
#           'alpha': 11,
#           'lambda': 5,
#           'cardinal': 2,
#           'key': 25,
#           'honor': 24,
#           'societies': 3,
#           'gpa': 74,
#           '344': 2,
#           'executive': 31,
#           'personal': 47,
#           'banker': 8,
#           'major': 9,
#           'wireless': 11,
#           'device': 5,
#           'benefit': 11,
#           'cisco': 8,
#           'coach': 27,
#           'com': 3,
#           'counseling': 40,
#           'direction': 18,
#           'insurance': 96,
#           'kronos': 4,
#           'law': 52,
#           'letters': 27,
#           'mentoring': 20,
#           'excel': 98,
#           'ms': 53,
#           'sharepoint': 11,
#           'windows': 39,
#           'analysis': 63,
#           'enterprise': 6,
#           'newsletter': 4,
#           'organizing': 13,
#           'peak': 3,
#           'performance': 56,
#           'reviews': 14,
#           'pivot': 3,
#           'tables': 6,
#           'improve': 23,
#           'processes': 73,
#           'project': 58,
#           'assurance': 17,
#           'selling': 19,
#           'support': 106,
#           'supervising': 14,
#           'technical': 28,
#           'underwriter': 5,
#           'underwriting': 8,
#           'articles': 2,
#           'councilor': 1,
#           'life': 24,
#           'commercial': 23,
#           'property': 12,
#           'goal': 13,
#           'lines': 15,
#           'casualty': 2,
#           'year': 21,
#           'earn': 1,
#           'cic': 1,
#           'designation': 1,
#           'artifacts': 1,
#           'strategic': 44,
#           'player': 18,
#           'workflow': 25,
#           'product': 53,
#           'launches': 4,
#           'brand': 10,
#           'sql': 13,
#           'databases': 25,
#           'risk': 27,
#           'mitigation': 2,
#           'mapping': 1,
#           'serviceoriented': 2,
#           'architecture': 5,
#           'release': 2,
#           'collaboration': 10,
#           'test': 24,
#           'scenarios': 3,
#           'requirements': 33,
#           'gathering': 2,
#           'gap': 3,
#           '122002': 2,
#           '122017': 8,
#           'suppcraig': 1,
#           'gabron': 2,
#           'craig': 1,
#           'orted': 1,
#           'bluecross': 3,
#           'blueshield': 1,
#           'carolinas': 1,
#           'tricare': 4,
#           'functioning': 1,
#           'analyst': 11,
#           'role': 13,
#           'ability': 34,
#           'matrix': 2,
#           'across': 16,
#           'crossfunctional': 1,
#           'teams': 14,
#           'produce': 1,
#           'results': 21,
#           'highly': 12,
#           'dynamic': 3,
#           'formative': 1,
# ...
#           'established': 50,
#           'safe': 35,
#           'play': 36,
#           'childrendistributed': 4,
#           'quarterly': 16,
#           'assessments': 28,
#           'similar': 7,
#           'cards': 9,
#           'parentdeveloped': 2,
#           'professional': 88,
#           'directors': 10,
#           'therapistsobserved': 3,
#           'signs': 23,
#           'illness': 7,
#           'injury': 6,
#           'emotional': 48,
#           'disturbance': 7,
#           'disorders': 12,
#           'speech': 13,
#           'problemsmaintained': 2,
#           'aide': 10,
#           '1999': 15,
#           'mar': 7,
#           '2001': 19,
#           'zoos': 5,
#           'assisted': 56,
#           'periodsencouraged': 2,
#           'dynamicshelped': 2,
#           'participation': 16,
#           'groupcommunicated': 2,
#           'studentsmaintained': 2,
#           'napsestablished': 3,
#           'childrencreated': 2,
#           'developmentallyappropriate': 5,
#           'addressed': 14,
#           'stylesdistributed': 2,
#           'parentmaintained': 2,
#           'childfriendly': 8,
#           'access': 19,
#           'outdoor': 22,
#           'activitiescompleted': 3,
#           'required': 29,
#           'national': 52,
#           'head': 22,
#           'start': 11,
#           'program': 103,
#           'extracurricular': 5,
#           'ran': 7,
#           'nursery': 3,
#           'church': 18,
#           'yea': 2,
#           'taught': 83,
#           'sunday': 7,
#           'older': 2,
#           'kids': 12,
#           'another': 7,
#           'two': 18,
#           'years': 48,
#           'also': 27,
#           'helped': 29,
#           'run': 7,
#           'get': 6,
#           'homework': 32,
#           'done': 6,
#           'started': 5,
#           'didnt': 2,
#           'help': 43,
#           'home': 14,
#           'could': 17,
#           'come': 6,
#           'us': 34,
#           'younger': 5,
#           'enroll': 3,
#           'would': 22,
#           'summary': 6,
#           'talented': 2,
#           'diverse': 19,
#           'planning': 97,
#           'implementing': 24,
#           'promoting': 19,
#           'physical': 46,
#           'social': 119,
#           'intellectual': 4,
#           'growth': 24,
#           'programs': 67,
#           'strong': 22,
#           'communicator': 2,
#           'toddler': 9,
#           'preschool': 30,
#           'curricula': 13,
#           'academic': 96,
#           'autism': 17,
#           'book': 11,
#           'clients': 52,
#           'customer': 85,
#           'service': 106,
#           'internet': 26,
#           'explorer': 6,
#           'windows': 11,
#           'microsoft': 87,
#           'purchasing': 23,
#           'quick': 4,
#           'read': 22,
#           'sabre': 2,
#           'staffing': 2,
#           'inspect': 5,
#           'vehicles': 5,
#           'additional': 39,
#           'information': 101,
#           'willing': 9,
#           'relocate': 5,
#           'anywhere': 5,
#           'authorized': 7,
#           'employer': 6,
#           'liberal': 17,
#           'thomas': 4,
#           'jefferson': 1,
#           'guest': 9,
#           'branding': 3,
#           'case': 15,
#           'interpersonal': 24,
#           'oral': 13,
#           'critical': 31,
#           'thinking': 25,
#           'functional': 12,
#           'meetings': 88,
#           'office': 119,
#           'relationship': 9,
#           'building': 21,
#           'seminars': 14,
#           'written': 27,
#           'communication': 85,
#           'mba': 5,
#           '2006': 37,
#           'nevada': 3,
#           'jan': 11,
#           '2015': 30,
#           'responsibilities': 23,
#           'continuity': 1,
#           'process': 29,
#           'incorporated': 16,
#           'cooperative': 3,
#           'role': 13,
#           'playing': 7,
#           'course': 46,
#           'material': 25,
#           'life': 10,
#           'experiences': 6,
#           'use': 34,
#           'challenging': 17,
#           'debate': 1,
#           'account': 9,
#           '2014': 36,
#           'develop': 36,
#           'deeper': 1,
#           'hq': 1,
#           'regional': 7,
#           'grow': 4,
#           'gaming': 4,
#           'lodging': 5,
#           'channel': 1,
#           'starbucks': 4,
#           'coffee': 4,
#           'mgm': 1,
#           'international': 24,
#           'caesars': 3,
#           'entertainment': 1,
#           'stationâ': 1,
#           'casinos': 2,
#           'intercontinental': 3,
#           'hotels': 5,
#           'hilton': 2,
#           'credited': 1,
#           'store': 19,
#           'along': 2,
#           'las': 16,
#           'vegas': 16,
#           'strip': 2,
#           'zero': 2,
#           'base': 8,
#           'present': 24,
#           '105mm': 1,
#           'revenue': 11,
#           'built': 7,
#           'strategic': 8,
#           'alliances': 1,
#           'internal': 17,
#           'external': 10,
#           'teams': 15,
#           'resulted': 6,
#           'sustained': 1,
#           '14': 3,
#           'yrs': 1,
#           'feb': 1,
#           'led': 14,
#           'crossfunctional': 5,
#           'ensure': 25,
#           'franchise': 3,
#           'openings': 2,
#           'execution': 5,
#           'foodservice': 1,
#           'agreements': 3,
#           'california': 20,
#           'arizona': 6,
#           'viable': 2,
#           'segment': 3,
#           'accomplishments': 44,
#           'leveraged': 3,
#           'corporate': 14,
#           'executive': 22,
#           'launch': 3,
#           'customized': 3,
#           'stores': 5,
#           'profile': 2,
#           'partners': 4,
#           'expand': 4,
#           'product': 24,
#           'beyond': 2,
#           'franchised': 1,
#           'locations': 6,
#           'eventually': 3,
#           'secure': 4,
#           'distribution': 11,
#           'mandates': 1,
#           'resulting': 6,
#           'excess': 1,
#           '105': 1,
#           'million': 1,
#           'ongoing': 4,
#           'revenues': 4,
#           'increase': 19,
#           'number': 20,
#           'license': 12,
#           '1': 22,
#           '51': 1,
#           'volume': 2,
#           'presented': 10,
#           'comprehensive': 6,
#           'instructional': 57,
#           'topics': 9,
#           'included': 19,
#           'site': 18,
#           'placement': 5,
#           'perspective': 1,
#           'show': 5,
#           'roi': 1,
#           'contract': 4,
#           'compliance': 18,
#           'identifying': 5,
#           'publications': 5,
#           'history': 45,
#           'wwwlawrencelibksusoralhistorynetherhtml': 1,
#           'â': 262,
#           'presentations': 24,
#           'culture': 5,
#           'httpswwwyoutubecomwatchvtath6y7ebdo': 1,
#           'membershipsscholarly': 1,
#           'societies': 1,
#           'fraternity': 5,
#           'wwwlasvegasnupescomcurtisnetherhtml': 1,
#           'modern': 4,
#           'technology': 64,
#           'conflict': 13,
#           'resolution': 14,
#           'iep': 29,
#           'familiarity': 4,
#           'organizationplanning': 1,
#           'bls': 1,
#           'cpr': 46,
#           'studentcentered': 4,
#           'grading': 7,
#           'integration': 6,
#           'punctual': 2,
#           'inquirybased': 3,
#           'proctoring': 3,
#           '082014': 12,
#           '062017': 4,
#           'performed': 24,
#           'aspects': 3,
#           'managementâ': 2,
#           'instructed': 31,
#           'provided': 65,
#           'support': 101,
#           'needed': 31,
#           'documented': 8,
#           'attendance': 24,
#           'assignments': 39,
#           'grades': 30,
#           'planned': 33,
#           'cover': 1,
#           'collaborated': 18,
#           'administrators': 41,
#           'counselors': 6,
#           'improvement': 7,
#           'struggling': 5,
#           'developed': 61,
#           'integrated': 7,
#           'diversify': 6,
#           'met': 32,
#           'resolve': 10,
#           'conflicting': 2,
#           'priorities': 7,
#           'issues': 51,
#           'created': 61,
#           '081998': 4,
#           'administered': 23,
#           'quizzes': 17,
#           'assess': 10,
#           'fostered': 18,
#           'meaningful': 1,
#           'among': 7,
#           'fieldtrip': 1,
#           'retreats': 1,
#           'teamwork': 7,
#           'projects': 50,
#           'served': 25,
#           'affiliation': 1,
#           'board': 45,
#           'revised': 4,
#           'institutes': 1,
#           'policies': 50,
#           'rules': 25,
#           'assistant': 74,
#           '081989': 1,
#           '061998': 1,
#           'safety': 47,
#           'outside': 6,
#           'environments': 1,
#           'interventions': 10,
#           'team': 124,
#           'professionals': 4,
#           'different': 10,
#           'disciplines': 3,
#           'implement': 24,
#           'action': 9,
#           'plan': 50,
#           'worked': 62,
#           'personalized': 11,
#           'behavioral': 30,
#           'assistance': 19,
#           'including': 64,
#           'clerical': 6,
#           'document': 11,
#           'coordination': 8,
#           'relevant': 4,
#           'books': 17,
#           'poems': 1,
#           'movies': 1,
#           'themes': 5,
#           'promote': 37,
#           'interest': 23,
#           'interests': 28,
#           'educationparenting': 2,
#           'activitiesâ': 1,
#           'south': 10,
#           'carolina': 4,
#           'association': 22,
#           '4h': 7,
#           'memberteacher': 2,
#           'environmental': 9,
#           'club': 27,
#           'advisor': 19,
#           'prom': 9,
#           'coordinator': 28,
#           'junior': 9,
#           'sponsorâ': 2,
#           'volunteer': 33,
#           'boys': 13,
#           'girls': 7,
#           'rock': 7,
#           'hillâ': 2,
#           'detention': 6,
#           'hall': 5,
#           'teacherâ': 4,
#           'progressive': 5,
#           'committeeâ': 2,
#           'member': 76,
#           'responder': 6,
#           'masters': 16,
#           'studies': 44,
#           '2018': 6,
#           'winthrop': 2,
#           'gpa': 33,
#           '38': 5,
#           'sociology': 12,
#           'june': 41,
#           '1998': 22,
#           'coker': 2,
#           '30': 11,
#           'april': 12,
#           'hill': 5,
#           'northwestern': 2,
#           'staff': 120,
#           'supervising': 22,
#           'supervision': 20,
#           'tutoring': 17,
#           '8th': 6,
#           '9th': 7,
#           '11th': 7,
#           'anchor': 4,
#           'faculty': 13,
#           'juniorsenior': 2,
#           'sponsor': 6,
#           'bishopville': 4,
#           'primary': 8,
#           '1989': 6,
#           '603': 2,
#           'north': 6,
#           'dennis': 2,
#           'avenue': 6,
#           'sc': 4,
#           '29010': 2,
#           'adult': 8,
#           'committee': 21,
#           'specialists': 13,
#           'workers': 14,
#           'discuss': 36,
#           'designed': 24,
#           'educationalsocial': 2,
#           'targeted': 3,
#           'guardians': 16,
#           'determine': 5,
#           'resource': 30,
#           'mentor': 31,
#           'volunteered': 7,
#           'temporary': 4,
#           'guidance': 9,
#           'counselor': 12,
#           'mathematics': 57,
#           'art': 39,
#           'pupils': 2,
#           'study': 26,
#           'adopted': 7,
#           'certifications': 36,
#           'certified': 41,
#           'scst': 2,
#           'succeed': 2,
#           'certification': 30,
#           'monitoring': 9,
#           'evernote': 3,
#           'slack': 3,
#           'adobe': 9,
#           'photoshop': 11,
#           'scheduling': 34,
#           'financial': 22,
#           'analysis': 19,
#           'security': 15,
#           'trading': 3,
#           'portfolio': 8,
#           'managament': 3,
#           'liability': 3,
#           'structuring': 5,
#           'teaches': 3,
#           'classes': 18,
#           'accordance': 21,
#           'requirements': 25,
#           'approved': 14,
#           'courses': 28,
#           'expected': 3,
#           'expectations': 14,
#           'uses': 7,
#           'strengths': 5,
#           'designs': 9,
#           'engage': 16,
#           'cognitively': 3,
#           'aligned': 4,
#           'standards': 42,
#           'resources': 20,
#           'levels': 27,
#           'engagement': 12,
#           'closely': 23,
#           'monitors': 11,
#           'order': 41,
#           'understand': 5,
#           'progressing': 3,
#           'toward': 8,
#           'provides': 9,
#           'instructive': 3,
#           'moves': 3,
#           'forward': 5,
#           'establishes': 3,
#           'supportive': 9,
#           'risktaking': 3,
#           'feel': 5,
#           'free': 6,
#           'contribute': 4,
#           'ideas': 12,
#           'interactions': 3,
#           'respectful': 3,
#           'polite': 3,
#           'initiates': 2,
#           'participates': 3,
#           'individualized': 16,
#           'parties': 3,
#           'involved': 7,
#           'eligible': 4,
#           'utilizes': 4,
#           'district': 39,
#           'modification': 10,
#           'goals': 30,
#           'continually': 15,
#           'goal': 23,
#           'achievement': 11,
#           'maintains': 10,
#           'incidents': 6,
#           'eg': 5,
#           'substance': 6,
#           'harassment': 4,
#           'violence': 4,
#           'communicates': 5,
#           'families': 18,
#           'create': 34,
#           'partnerships': 4,
#           'around': 12,
#           'providing': 28,
#           'programing': 4,
#           'collaboration': 16,
#           'ela': 15,
#           'evaluates': 4,
#           'performance': 55,
#           'subordinate': 4,
#           'personnel': 29,
#           'robotics': 11,
#           'instructor': 8,
#           '082012': 10,
#           '092014': 5,
#           'clear': 19,
#           'informative': 7,
#           'lectures': 21,
#           'working': 26,
#           'kits': 4,
#           'programming': 11,
#           'theory': 4,
#           'increased': 14,
#           'expertise': 12,
#           'knowledge': 53,
#           'participating': 11,
#           'instructororiented': 4,
#           'modified': 13,
#           'accommodate': 13,
#           'learners': 18,
#           'using': 56,
#           'peerassisted': 4,
#           '082015': 6,
#           'realizing': 4,
#           '2025': 4,
#           'annually': 5,
#           '5': 20,
#           'year': 79,
#           'period': 16,
#           'analytics': 4,
#           'relocation': 4,
#           'services': 41,
#           'take': 22,
#           'though': 4,
#           'time': 90,
#           'asset': 4,
#           'restructuring': 4,
#           'system': 44,
#           'antifragile': 4,
#           'contingency': 4,
#           'recovery': 5,
#           'black': 6,
#           'swan': 4,
#           'events': 42,
#           'launched': 6,
#           'boosted': 6,
#           '15': 11,
#           'improvements': 5,
#           'automate': 4,
#           'record': 19,
#           'tracking': 15,
#           'mobile': 4,
#           'apps': 4,
#           'improved': 15,
#           'efficiency': 6,
#           'managing': 33,
#           'communications': 14,
#           'correspondence': 16,
#           'structure': 5,
#           'drafting': 10,
#           'contracts': 18,
#           'ed': 6,
#           'los': 20,
#           'angeles': 18,
#           'degree': 19,
#           'elementary': 34,
#           'psychology': 44,
#           '2003': 25,
#           'mexico': 4,
#           'studio': 2,
#           'santa': 3,
#           'monica': 2,
#           'agency': 2,
#           'budgeting': 8,
#           'budgets': 11,
#           'strategy': 2,
#           'closing': 5,
#           'cold': 3,
#           'calling': 2,
#           'excellent': 44,
#           'client': 16,
#           'relations': 22,
#           'databases': 8,
#           'fluent': 4,
#           'ftp': 2,
#           'hr': 2,
#           'insurance': 32,
#           'leadership': 57,
#           'legal': 11,
#           'marketing': 39,
#           'mergers': 2,
#           'acquisitions': 2,
#           'works': 10,
#           'organizational': 28,
#           'problem': 46,
#           'solver': 8,
#           'proposals': 12,
#           'quality': 28,
#           'assurance': 5,
#           'recruitment': 6,
#           'spanish': 35,
#           'vendor': 8,
#           'website': 8,
#           'eagle': 3,
#           'pass': 5,
#           'medical': 37,
#           ...})}

# %% [markdown]
# ### Lemmatization: Reducing words to their base form.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize NLTK's stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Function to lemmatize text
def lemmatize_text(text):
    words = nltk.word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# Iterate through the dataframes dictionary and apply lemmatization
for subfolder, df in dataframes.items():
    # Tokenize, remove stop words, and lemmatize the "Details" column
    df["Details"] = df["Details"].apply(lambda text: ' '.join([lemmatizer.lemmatize(word) for word in text.split() if word.lower() not in stop_words]))
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vinith
# [nltk_data]     MH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Vinith
# [nltk_data]     MH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Vinith
# [nltk_data]     MH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dataframes['ACCOUNTANT']
# Out:
#     PDF File Name                                            Details
# 0    10554236.pdf  accountant accounting general accounting accou...
# 1    10674770.pdf  staff accountant accounting account payable ac...
# 2    11163645.pdf  accountant account payable account receivables...
# 3    11759079.pdf  senior accountant accounting balance sheet bud...
# 4    12065211.pdf  senior accountant aderantcms excel quickbooks ...
# ..            ...                                                ...
# 113  78403342.pdf  accountant accounting balance budget business ...
# 114  80053367.pdf  general accountant healthcare â sound ethical ...
# 115  82649935.pdf  senior accountant bachelor art economics city ...
# 116  87635012.pdf  principal accountant microsoft excel peachtree...
# 117  98559931.pdf  payroll accountant accounting ap attention det...
#
# [118 rows x 2 columns]

# %% [markdown]
# ### Utilizing the DistilBERT model and tokenizer to extract embeddings from the "job_description" column in a DataFrame and replaces the text with these embeddings in a single line.

# %%
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel

# Initialize DistilBERT model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')

# Function to extract DistilBERT embeddings
def extract_distilbert_embeddings(text):
    # Tokenize text
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    
    # Generate embeddings
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract embeddings for the [CLS] token (you can adjust this depending on your needs)
    cls_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().tolist()
    
    return cls_embedding

# Iterate through the dataframes dictionary and apply DistilBERT embedding extraction
for subfolder, df in dataframes.items():
    # Apply DistilBERT embedding extraction to the 'Details' column and store in the same column
    df['Details'] = df['Details'].apply(extract_distilbert_embeddings)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 1f8e1cb8-c7c5-47b0-84a3-b1c6596ce6d4)')' thrown while requesting HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt

# %%
dataframes
# Out:
# {'ACCOUNTANT':     PDF File Name                                            Details
#  0    10554236.pdf  [-0.1271236687898636, 0.44556787610054016, 0.2...
#  1    10674770.pdf  [-0.07137733697891235, 0.39897966384887695, 0....
#  2    11163645.pdf  [-0.22557547688484192, 0.47983312606811523, 0....
#  3    11759079.pdf  [-0.1911216825246811, 0.4082939624786377, 0.23...
#  4    12065211.pdf  [-0.11686299741268158, 0.34147530794143677, 0....
#  ..            ...                                                ...
#  113  78403342.pdf  [-0.20568658411502838, 0.49587711691856384, 0....
#  114  80053367.pdf  [-0.1782316267490387, 0.3512096703052521, 0.38...
#  115  82649935.pdf  [-0.15202154219150543, 0.26726406812667847, -0...
#  116  87635012.pdf  [-0.2352742701768875, 0.23847785592079163, 0.0...
#  117  98559931.pdf  [-0.41110071539878845, 0.5781598687171936, 0.2...
#
#  [118 rows x 2 columns],
#  'ADVOCATE':     PDF File Name                                            Details
#  0    10186968.pdf  [-0.11402559280395508, 0.1983242630958557, 0.2...
#  1    10344379.pdf  [0.10981613397598267, 0.38595134019851685, 0.1...
#  2    10659182.pdf  [-0.12246859818696976, 0.34607207775115967, 0....
#  3    10818478.pdf  [-0.2429881989955902, 0.2855006754398346, 0.16...
#  4    11174187.pdf  [-0.24635791778564453, 0.2696900963783264, 0.4...
#  ..            ...                                                ...
#  113  91051945.pdf  [-0.22197303175926208, 0.31614071130752563, 0....
#  114  93512385.pdf  [-0.4880501329898834, 0.22778502106666565, 0.1...
#  115  95714702.pdf  [-0.14394763112068176, 0.24375499784946442, 0....
#  116  95970987.pdf  [-0.12132525444030762, 0.1641966551542282, 0.3...
#  117  97405769.pdf  [-0.07658639550209045, 0.2719295620918274, 0.4...
#
#  [118 rows x 2 columns],
#  'AGRICULTURE':    PDF File Name                                            Details
#  0   10953078.pdf  [-0.2275734543800354, 0.3619348406791687, 0.35...
#  1   11197262.pdf  [-0.12369748950004578, 0.3034871816635132, 0.0...
#  2   11676151.pdf  [-0.15041890740394592, 0.508169949054718, 0.30...
#  3   11813872.pdf  [-0.3248782157897949, 0.2613883912563324, 0.40...
#  4   12341902.pdf  [-0.2867022752761841, 0.3479079008102417, 0.36...
#  ..           ...                                                ...
#  58  69859102.pdf  [-0.035017937421798706, 0.2528972327709198, 0....
#  59  79536879.pdf  [-0.314310759305954, 0.44640859961509705, 0.18...
#  60  81042872.pdf  [-0.26992732286453247, 0.28090569376945496, 0....
#  61  84512719.pdf  [-0.11434520781040192, 0.26390305161476135, 0....
#  62  89740812.pdf  [-0.22322441637516022, 0.5216892957687378, 0.2...
#
#  [63 rows x 2 columns],
#  'APPAREL':    PDF File Name                                            Details
#  0   10182582.pdf  [-0.2621350586414337, 0.1993207037448883, 0.31...
#  1   10562768.pdf  [-0.12637153267860413, 0.18800213932991028, 0....
#  2   10738095.pdf  [-0.22713744640350342, 0.3975273370742798, 0.2...
#  3   10876132.pdf  [0.03462321683764458, 0.19376353919506073, 0.0...
#  4   11232471.pdf  [-0.18218497931957245, 0.18564027547836304, 0....
#  ..           ...                                                ...
#  92  78273826.pdf  [-0.17070071399211884, 0.34140655398368835, 0....
#  93  83566455.pdf  [-0.1514464020729065, 0.22533012926578522, 0.1...
#  94  91026230.pdf  [-0.34316200017929077, 0.2673405408859253, 0.2...
#  95  91533580.pdf  [-0.23139601945877075, 0.2467799335718155, 0.3...
#  96  99806115.pdf  [0.03493881598114967, 0.2882067561149597, 0.49...
#
#  [97 rows x 2 columns],
#  'ARTS':     PDF File Name                                            Details
#  0    10830646.pdf  [-0.20658786594867706, 0.19704800844192505, 0....
#  1    11187796.pdf  [-0.14980542659759521, 0.23014239966869354, 0....
#  2    11360471.pdf  [0.007283545099198818, 0.13678330183029175, 0....
#  3    11555549.pdf  [-0.22426541149616241, 0.3334943950176239, 0.2...
#  4    11995013.pdf  [0.04282117262482643, 0.3275969326496124, 0.34...
#  ..            ...                                                ...
#  98   83338413.pdf  [-0.08827629685401917, 0.23176679015159607, 0....
#  99   93576192.pdf  [-0.11286129057407379, 0.2129756212234497, 0.2...
#  100  94230796.pdf  [0.01581285521388054, 0.1192835196852684, 0.25...
#  101  99033098.pdf  [-0.20551574230194092, 0.4243885576725006, 0.3...
#  102  99561379.pdf  [-0.1064382866024971, 0.33640649914741516, 0.3...
#
#  [103 rows x 2 columns],
#  'AUTOMOBILE':    PDF File Name                                            Details
#  0   11152490.pdf  [-0.08977709710597992, 0.24647006392478943, 0....
#  1   11257723.pdf  [-0.014548608101904392, 0.3708456754684448, 0....
#  2   11797122.pdf  [0.06952033191919327, 0.36802324652671814, 0.4...
#  3   11887930.pdf  [-0.20271362364292145, 0.35304510593414307, 0....
#  4   14455622.pdf  [-0.41712433099746704, 0.3689365088939667, 0.1...
#  5   14508237.pdf  [-0.19779294729232788, 0.3583623170852661, 0.4...
#  6   15100547.pdf  [0.06843740493059158, 0.49099957942962646, 0.3...
#  7   15210069.pdf  [-0.05053031072020531, 0.5082237124443054, 0.2...
#  8   15484011.pdf  [-0.05671801418066025, 0.28042474389076233, 0....
#  9   15790602.pdf  [-0.05580820515751839, 0.39017921686172485, 0....
#  10  16332293.pdf  [0.007467571645975113, 0.3074245750904083, 0.3...
#  11  17510973.pdf  [-0.2995645999908447, 0.3429139256477356, 0.43...
#  12  17571262.pdf  [-0.3005669414997101, 0.39318186044692993, 0.2...
#  13  18448085.pdf  [-0.43046310544013977, 0.3662448525428772, 0.2...
#  14  18932512.pdf  [0.03824368119239807, 0.23335319757461548, 0.2...
#  15  22452756.pdf  [-0.12367545813322067, 0.22604425251483917, 0....
#  16  22732234.pdf  [-0.23251521587371826, 0.22238197922706604, 0....
#  17  22946204.pdf  [-0.30307334661483765, 0.14406028389930725, 0....
#  18  23009962.pdf  [-0.34060055017471313, 0.30195704102516174, 0....
#  19  23522150.pdf  [-0.2621464431285858, 0.32022571563720703, 0.2...
#  20  24592627.pdf  [-0.08536864817142487, 0.23350052535533905, 0....
#  21  24703983.pdf  [-0.0858081579208374, 0.4281092584133148, 0.28...
#  22  25047127.pdf  [-0.2912214696407318, 0.3276492953300476, 0.40...
#  23  26341645.pdf  [-0.32263603806495667, 0.3636021018028259, 0.4...
#  24  28790806.pdf  [-0.07627492398023605, 0.18639720976352692, 0....
#  25  32069695.pdf  [-0.15935659408569336, 0.45945391058921814, 0....
#  26  32109048.pdf  [-0.08097153156995773, 0.259566068649292, 0.46...
#  27  47487091.pdf  [-0.3586066961288452, 0.33889126777648926, 0.2...
#  28  51508889.pdf  [-0.33939221501350403, 0.3834612965583801, 0.3...
#  29  63989974.pdf  [-0.13551601767539978, 0.3838965594768524, 0.4...
#  30  78357954.pdf  [-0.1297745704650879, 0.23717352747917175, 0.3...
#  31  82140102.pdf  [-0.010573274455964565, 0.3004041314125061, 0....
#  32  84295343.pdf  [-0.19826513528823853, 0.34081709384918213, 0....
#  33  91515108.pdf  [-0.17662003636360168, 0.2360316663980484, 0.4...
#  34  97449528.pdf  [-0.06373468041419983, 0.3479330539703369, 0.1...
#  35  99680385.pdf  [-0.1607663482427597, 0.44166845083236694, 0.1...,
#  'AVIATION':     PDF File Name                                            Details
#  0    10176815.pdf  [-0.1351582556962967, 0.4548815190792084, 0.21...
#  1    10189110.pdf  [-0.09532678127288818, 0.26458045840263367, 0....
#  2    10395944.pdf  [-0.08900795876979828, 0.2982308864593506, 0.3...
#  3    10567764.pdf  [0.07803915441036224, 0.2944349944591522, 0.36...
#  4    10945968.pdf  [-0.26920995116233826, 0.22007478773593903, 0....
#  ..            ...                                                ...
#  112  92283635.pdf  [-0.2123071700334549, 0.2843429744243622, 0.15...
#  113  94137171.pdf  [-0.19627660512924194, 0.5040252804756165, 0.3...
#  114  96457008.pdf  [0.10673823207616806, 0.12506085634231567, 0.2...
#  115  98389424.pdf  [-0.2190711796283722, 0.3344869017601013, 0.25...
#  116  99416532.pdf  [-0.36225566267967224, 0.3083690404891968, 0.3...
#
#  [117 rows x 2 columns],
#  'BANKING':     PDF File Name                                            Details
#  0    10329506.pdf  [-0.10894499719142914, 0.32357966899871826, 0....
#  1    10909673.pdf  [-0.3636385202407837, 0.24726754426956177, 0.2...
#  2    11065180.pdf  [-0.25911039113998413, 0.3843219578266144, 0.3...
#  3    11262933.pdf  [-0.17449963092803955, 0.3896968960762024, 0.3...
#  4    11266906.pdf  [-0.2018350064754486, 0.3461865782737732, 0.54...
#  ..            ...                                                ...
#  110  89049979.pdf  [-0.11510524153709412, 0.2418307363986969, 0.2...
#  111  96493528.pdf  [-0.15519556403160095, 0.21698632836341858, 0....
#  112  98348532.pdf  [-0.1892303079366684, 0.2825693190097809, 0.32...
#  113  98965485.pdf  [-0.19662822782993317, 0.3395282030105591, 0.1...
#  114  99124477.pdf  [-0.21185582876205444, 0.24858546257019043, 0....
#
#  [115 rows x 2 columns],
#  'BPO':    PDF File Name                                            Details
#  0   11183737.pdf  [-0.26668164134025574, 0.4044814109802246, 0.3...
#  1   13964744.pdf  [-0.19771689176559448, 0.1733788251876831, 0.3...
#  2   15145575.pdf  [-0.09904687106609344, 0.35433775186538696, 0....
#  3   15573418.pdf  [-0.3535022437572479, 0.3896748721599579, 0.35...
#  4   16492045.pdf  [-0.24199222028255463, 0.5275778770446777, 0.2...
#  5   18589927.pdf  [-0.2164427936077118, 0.3425789475440979, 0.23...
#  6   19362586.pdf  [0.11510655283927917, 0.11618263274431229, 0.1...
#  7   23933031.pdf  [-0.2334708869457245, 0.3848423659801483, 0.26...
#  8   24727739.pdf  [-0.1372964084148407, 0.4669717848300934, 0.33...
#  9   26829350.pdf  [-0.35742032527923584, 0.19471564888954163, 0....
#  10  27710853.pdf  [-0.1920514851808548, 0.20682691037654877, 0.2...
#  11  30709029.pdf  [-0.11679325252771378, 0.2978229224681854, 0.2...
#  12  31064969.pdf  [-0.3997194766998291, 0.3350342810153961, 0.25...
#  13  38707449.pdf  [-0.2806069850921631, 0.3203951418399811, 0.29...
#  14  41152404.pdf  [-0.08527743816375732, 0.3283524215221405, 0.3...
#  15  45077654.pdf  [-0.07465937733650208, 0.2318735271692276, 0.5...
#  16  57706851.pdf  [-0.16065341234207153, 0.3490239977836609, 0.3...
#  17  63158213.pdf  [-0.18354281783103943, 0.11562855541706085, 0....
#  18  69097572.pdf  [-0.20525063574314117, 0.4407861530780792, 0.1...
#  19  79261033.pdf  [-0.2551286816596985, 0.2934264838695526, 0.21...
#  20  89512321.pdf  [-0.23290199041366577, 0.35701340436935425, 0....
#  21  95625660.pdf  [-0.22814089059829712, 0.23176448047161102, 0....,
#  'BUSINESS-DEVELOPMENT':     PDF File Name                                            Details
#  0    10228751.pdf  [-0.0689103752374649, 0.41736745834350586, 0.3...
#  1    10235211.pdf  [-0.30760762095451355, 0.3431038558483124, 0.3...
#  2    10289113.pdf  [-0.40289628505706787, 0.31345176696777344, 0....
#  3    10501991.pdf  [-0.1651369333267212, 0.1431487798690796, 0.43...
#  4    10541358.pdf  [-0.2376287281513214, 0.3978337049484253, 0.35...
#  ..            ...                                                ...
#  115  89197180.pdf  [-0.19580097496509552, 0.3750242590904236, 0.2...
#  116  90629382.pdf  [-0.06336157768964767, 0.40307536721229553, 0....
#  117  91467795.pdf  [-0.22341126203536987, 0.27240484952926636, 0....
#  118  95382114.pdf  [-0.42849215865135193, 0.26163095235824585, 0....
#  119  98379112.pdf  [-0.023273637518286705, 0.1752575933933258, 0....
#
#  [120 rows x 2 columns],
#  'CHEF':     PDF File Name                                            Details
#  0    10001727.pdf  [-0.07319480925798416, 0.4035181403160095, 0.2...
#  1    10276858.pdf  [0.03318537399172783, 0.47363656759262085, 0.2...
#  2    10333299.pdf  [0.09092176705598831, 0.42940983176231384, 0.2...
#  3    10588874.pdf  [-0.29740777611732483, 0.36053863167762756, 0....
#  4    10653119.pdf  [-0.13665397465229034, 0.3485043942928314, 0.2...
#  ..            ...                                                ...
#  113  91268638.pdf  [-0.06981172412633896, 0.23510073125362396, 0....
#  114  91591026.pdf  [-0.021032748743891716, 0.30550917983055115, 0...
#  115  92122785.pdf  [-0.19848084449768066, 0.27747491002082825, 0....
#  116  92985983.pdf  [-0.11071299016475677, 0.3648512065410614, 0.0...
#  117  94047639.pdf  [-0.07608196884393692, 0.43084508180618286, 0....
#
#  [118 rows x 2 columns],
#  'CONSTRUCTION':     PDF File Name                                            Details
#  0    10041713.pdf  [-0.12550115585327148, 0.20120789110660553, 0....
#  1    10100240.pdf  [0.04474570229649544, 0.4494065046310425, 0.30...
#  2    10149490.pdf  [-0.10747101157903671, 0.1701461374759674, 0.2...
#  3    10176013.pdf  [-0.05157526582479477, 0.25937485694885254, 0....
#  4    10281555.pdf  [-0.007788956165313721, 0.34018635749816895, 0...
#  ..            ...                                                ...
#  107  88859947.pdf  [-0.3377515375614166, 0.41059011220932007, 0.3...
#  108  90032884.pdf  [-0.2329089194536209, 0.2481626570224762, 0.23...
#  109  93436805.pdf  [-0.29776251316070557, 0.47297441959381104, 0....
#  110  94503308.pdf  [-0.22361163794994354, 0.43919113278388977, 0....
#  111  99433371.pdf  [-0.14625079929828644, 0.5232686996459961, 0.1...
#
#  [112 rows x 2 columns],
#  'CONSULTANT':     PDF File Name                                            Details
#  0    10332998.pdf  [0.015597045421600342, 0.25875934958457947, 0....
#  1    10984392.pdf  [-0.21565183997154236, 0.2090720683336258, 0.3...
#  2    11020140.pdf  [-0.21309813857078552, 0.5813082456588745, 0.3...
#  3    11333660.pdf  [-0.42488592863082886, 0.32733669877052307, 0....
#  4    11415967.pdf  [-0.1835731714963913, 0.408174991607666, 0.239...
#  ..            ...                                                ...
#  110  93459677.pdf  [-0.03548197075724602, 0.3239753842353821, 0.2...
#  111  95350373.pdf  [-0.21624623239040375, 0.5117892026901245, 0.3...
#  112  95429627.pdf  [-0.21905294060707092, 0.3968384265899658, 0.3...
#  113  95792386.pdf  [-0.1116221696138382, 0.3539741039276123, 0.38...
#  114  99714410.pdf  [-0.3343278169631958, 0.3875821530818939, 0.29...
#
#  [115 rows x 2 columns],
#  'DESIGNER':     PDF File Name                                            Details
#  0    10466583.pdf  [0.12992258369922638, 0.012067805975675583, -0...
#  1    10748989.pdf  [0.026039715856313705, 0.32168787717819214, 0....
#  2    10751444.pdf  [-0.04997851327061653, 0.12179665267467499, 0....
#  3    11155153.pdf  [-0.1595979779958725, 0.30017581582069397, 0.3...
#  4    11722421.pdf  [0.14859901368618011, 0.2641538679599762, 0.32...
#  ..            ...                                                ...
#  102  85101052.pdf  [-0.12415266782045364, 0.3150912821292877, 0.4...
#  103  90066849.pdf  [-0.008105679415166378, 0.23689036071300507, 0...
#  104  91153752.pdf  [-0.03811688721179962, -0.005250593181699514, ...
#  105  93301686.pdf  [-0.32325300574302673, 0.4128322899341583, 0.1...
#  106  94417768.pdf  [-0.024586502462625504, 0.2855825126171112, 0....
#
#  [107 rows x 2 columns],
#  'DIGITAL-MEDIA':    PDF File Name                                            Details
#  0   10005171.pdf  [-0.2591826021671295, 0.3788501024246216, 0.24...
#  1   10515955.pdf  [0.00824026856571436, 0.3473407030105591, 0.20...
#  2   11005406.pdf  [-0.2418726235628128, 0.18802420794963837, 0.4...
#  3   11270462.pdf  [-0.21047867834568024, 0.29541027545928955, 0....
#  4   11677012.pdf  [-0.20948489010334015, 0.2751372158527374, 0.2...
#  ..           ...                                                ...
#  91  82929064.pdf  [-0.21141986548900604, 0.30219322443008423, 0....
#  92  90685127.pdf  [-0.17010512948036194, 0.32148492336273193, 0....
#  93  91318828.pdf  [0.03720161318778992, 0.3416796326637268, 0.26...
#  94  91539554.pdf  [-0.35210150480270386, 0.23666301369667053, 0....
#  95  94492380.pdf  [0.16239306330680847, 0.24787932634353638, -0....
#
#  [96 rows x 2 columns],
#  'ENGINEERING':     PDF File Name                                            Details
#  0    10030015.pdf  [-0.05768565461039543, 0.2927562892436981, 0.1...
#  1    10219099.pdf  [0.09199395775794983, 0.33698970079421997, 0.3...
#  2    10624813.pdf  [-0.19232909381389618, 0.24767036736011505, 0....
#  3    10712803.pdf  [0.029341217130422592, 0.48189809918403625, 0....
#  4    10985403.pdf  [-0.1468985676765442, 0.2479335069656372, 0.27...
#  ..            ...                                                ...
#  113  82246962.pdf  [-0.045005254447460175, 0.28796711564064026, 0...
#  114  86209934.pdf  [-0.21924751996994019, 0.2769395411014557, 0.2...
#  115  86828820.pdf  [0.00892847590148449, 0.37851589918136597, 0.3...
#  116  90280583.pdf  [-0.23933212459087372, 0.23838657140731812, 0....
#  117  96029688.pdf  [-0.29562637209892273, 0.3034506142139435, 0.2...
#
#  [118 rows x 2 columns],
#  'FINANCE':     PDF File Name                                            Details
#  0    10549585.pdf  [-0.16498790681362152, 0.2588058114051819, 0.4...
#  1    11441764.pdf  [-0.1628837287425995, 0.410456120967865, 0.323...
#  2    11490673.pdf  [-0.25025326013565063, 0.3952958583831787, 0.2...
#  3    11877150.pdf  [-0.1979994773864746, 0.14638374745845795, 0.1...
#  4    12071138.pdf  [-0.19962042570114136, 0.41198617219924927, 0....
#  ..            ...                                                ...
#  113  91564103.pdf  [-0.11528870463371277, 0.48499608039855957, 0....
#  114  92524964.pdf  [-0.23663689196109772, 0.38048219680786133, 0....
#  115  93653247.pdf  [-0.5118926763534546, 0.42726659774780273, 0.0...
#  116  95519832.pdf  [-0.18700037896633148, 0.16991670429706573, 0....
#  117  98513424.pdf  [-0.35017985105514526, 0.45727959275245667, 0....
#
#  [118 rows x 2 columns],
#  'FITNESS':     PDF File Name                                            Details
#  0    10235429.pdf  [-0.05373026430606842, 0.16998659074306488, 0....
#  1    10268614.pdf  [-0.14310933649539948, 0.22825348377227783, 0....
#  2    10333051.pdf  [-0.18574592471122742, 0.24599266052246094, 0....
#  3    10428916.pdf  [-0.49793440103530884, 0.2224748283624649, 0.1...
#  4    10568350.pdf  [-0.12541252374649048, 0.06731235980987549, 0....
#  ..            ...                                                ...
#  112  90365216.pdf  [-0.20992356538772583, 0.26926669478416443, 0....
#  113  95085510.pdf  [-0.26309898495674133, 0.206825852394104, 0.35...
#  114  95769832.pdf  [-0.1106204092502594, 0.20090466737747192, 0.3...
#  115  96761538.pdf  [-0.08595350384712219, 0.26177096366882324, 0....
#  116  97123005.pdf  [-0.38613229990005493, 0.44797560572624207, 0....
#
#  [117 rows x 2 columns],
#  'HEALTHCARE':     PDF File Name                                            Details
#  0    10062724.pdf  [-0.17965348064899445, 0.2571483850479126, 0.3...
#  1    10076271.pdf  [-0.3100602626800537, 0.2830047309398651, 0.17...
#  2    10251432.pdf  [-0.07674577087163925, 0.3568004369735718, 0.3...
#  3    10466208.pdf  [-0.22084398567676544, 0.29421448707580566, 0....
#  4    10480456.pdf  [-0.24695512652397156, 0.3610166311264038, 0.3...
#  ..            ...                                                ...
#  110  95011061.pdf  [-0.09764301776885986, 0.323026567697525, 0.36...
#  111  96260484.pdf  [-0.16834260523319244, 0.41216421127319336, 0....
#  112  97169343.pdf  [-0.15684649348258972, 0.30255064368247986, 0....
#  113  98300955.pdf  [-0.1900363266468048, 0.5003692507743835, 0.41...
#  114  98309114.pdf  [-0.1840779185295105, 0.4659711718559265, 0.24...
#
#  [115 rows x 2 columns],
#  'HR':     PDF File Name                                            Details
#  0    10399912.pdf  [0.0049901604652404785, 0.4346908926963806, 0....
#  1    10694288.pdf  [-0.0659775584936142, 0.32898420095443726, 0.5...
#  2    11480899.pdf  [-0.20472978055477142, 0.3265697658061981, 0.2...
#  3    11592605.pdf  [-0.35912570357322693, 0.37432727217674255, 0....
#  4    11698189.pdf  [-0.42524057626724243, 0.30247190594673157, 0....
#  ..            ...                                                ...
#  105  86184722.pdf  [-0.19213631749153137, 0.3263232111930847, 0.3...
#  106  87968870.pdf  [-0.280945748090744, 0.4256397485733032, 0.260...
#  107  91930382.pdf  [-0.14044195413589478, 0.27967798709869385, 0....
#  108  93002334.pdf  [-0.36757493019104004, 0.21898050606250763, 0....
#  109  93112113.pdf  [-0.16676993668079376, 0.17977683246135712, 0....
#
#  [110 rows x 2 columns],
#  'INFORMATION-TECHNOLOGY':     PDF File Name                                            Details
#  0    10089434.pdf  [-0.16873712837696075, 0.3165063261985779, 0.4...
#  1    10247517.pdf  [-0.1415853202342987, 0.34162387251853943, 0.3...
#  2    10265057.pdf  [-0.2191089540719986, 0.3131057620048523, 0.14...
#  3    10553553.pdf  [-0.3224456012248993, 0.3317788243293762, 0.45...
#  4    10641230.pdf  [-0.14907081425189972, 0.4011663794517517, 0.3...
#  ..            ...                                                ...
#  115  90867631.pdf  [-0.2870796322822571, 0.3593895733356476, 0.44...
#  116  91121135.pdf  [-0.27261272072792053, 0.6035914421081543, 0.2...
#  117  91635250.pdf  [-0.15886452794075012, 0.3544774055480957, 0.3...
#  118  91697974.pdf  [-0.12174713611602783, 0.3032945990562439, 0.2...
#  119  92069209.pdf  [-0.30554622411727905, 0.14230838418006897, 0....
#
#  [120 rows x 2 columns],
#  'PUBLIC-RELATIONS':     PDF File Name                                            Details
#  0    10070224.pdf  [-0.1537504643201828, 0.49982520937919617, 0.2...
#  1    10554045.pdf  [-0.2148049920797348, 0.3532159924507141, 0.31...
#  2    10873344.pdf  [-0.27612218260765076, 0.38086259365081787, 0....
#  3    10926726.pdf  [-0.15571975708007812, 0.3735092282295227, 0.3...
#  4    11160414.pdf  [-0.06521893292665482, 0.4186139702796936, 0.2...
#  ..            ...                                                ...
#  106  85973397.pdf  [-0.1690758913755417, 0.3106862008571625, 0.30...
#  107  88651471.pdf  [-0.18559832870960236, 0.2784655690193176, 0.2...
#  108  91197243.pdf  [-0.3460977375507355, 0.3422044813632965, 0.23...
#  109  93828034.pdf  [-0.22802700102329254, 0.4197239577770233, 0.2...
#  110  98086373.pdf  [-0.11309510469436646, 0.4442279636859894, 0.2...
#
#  [111 rows x 2 columns],
#  'SALES':     PDF File Name                                            Details
#  0    10138632.pdf  [0.07597097754478455, 0.25158774852752686, 0.3...
#  1    10464113.pdf  [-0.08908763527870178, 0.29880452156066895, 0....
#  2    10603337.pdf  [-0.014670164324343204, 0.11107804626226425, -...
#  3    10724818.pdf  [-0.29497382044792175, 0.2334664911031723, 0.2...
#  4    10898339.pdf  [-0.1376258283853531, 0.3285447061061859, 0.23...
#  ..            ...                                                ...
#  111  87118391.pdf  [-0.1142469123005867, 0.34989893436431885, 0.1...
#  112  90682785.pdf  [-0.09522071480751038, 0.23649664223194122, 0....
#  113  92200491.pdf  [-0.019139688462018967, 0.3410235047340393, 0....
#  114  98108571.pdf  [0.24287398159503937, 0.4115515649318695, 0.07...
#  115  98509238.pdf  [-0.2860517203807831, 0.1833212822675705, 0.36...
#
#  [116 rows x 2 columns],
#  'TEACHER':     PDF File Name                                            Details
#  0    10504237.pdf  [-0.010038796812295914, 0.21340052783489227, 0...
#  1    10527994.pdf  [-0.006265724077820778, 0.33032622933387756, 0...
#  2    10909720.pdf  [-0.2946441173553467, 0.27775517106056213, 0.1...
#  3    11336022.pdf  [-0.21914109587669373, 0.37180957198143005, 0....
#  4    11616482.pdf  [-0.19739536941051483, 0.42904505133628845, 0....
#  ..            ...                                                ...
#  97   86322251.pdf  [-0.19638070464134216, 0.17027691006660461, 0....
#  98   86597425.pdf  [-0.07409564405679703, 0.3479766249656677, 0.2...
#  99   90363254.pdf  [-0.017275333404541016, 0.31826233863830566, -...
#  100  96547039.pdf  [-0.3203238546848297, 0.3744415044784546, 0.33...
#  101  99244405.pdf  [-0.2945340871810913, 0.21440333127975464, 0.2...
#
#  [102 rows x 2 columns]}

# %% [markdown]
# ### Calculating cosine similarities between job descriptions and CV embeddings, creating new DataFrames with PDF ranks and cosine similarities, and export these DataFrames to CSV files while also displaying their contents for each position title.

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Create a mapping between position titles and DataFrame names
position_title_mapping = dict(zip(sel_job_desp_df['position_title'], dataframes.keys()))

# Initialize a dictionary to store the dataframes with PDF ranks and cosine similarities
dataframes_with_ranks = {}

# Calculate cosine similarities and create dataframes
for position_title, job_description in zip(sel_job_desp_df['position_title'], sel_job_desp_df['job_description']):
    similarities = {}
    job_description = np.array(job_description).reshape(1, -1)  # Ensure job_description is a 2D array
    cv_df = dataframes[position_title_mapping[position_title]]  # Get the corresponding DataFrame
    cv_embeddings = np.array(list(cv_df['Details']))  # Assuming 'Details' column contains CV embeddings
    
    # Calculate cosine similarities within the corresponding DataFrame
    similarities = cosine_similarity(job_description, cv_embeddings)
    
    # Get the PDF file names and ranks based on similarity
    pdf_file_names = cv_df['PDF File Name']
    ranked_pdf_file_names = [pdf_file_names[i] for i in np.argsort(similarities[0])[::-1]]
    
    # Create a new DataFrame with PDF ranks and cosine similarities
    rank_df = pd.DataFrame({'PDF File Name': ranked_pdf_file_names,
                            'Cosine Similarity': similarities[0][np.argsort(similarities[0])[::-1]]})
    
    # Store the dataframe in the dictionary
    dataframes_with_ranks[position_title] = rank_df

# Export dataframes to CSV files and/or access them as needed
for position_title, rank_df in dataframes_with_ranks.items():
    # Export the dataframe to a CSV file
    rank_df.to_csv(f'{position_title}_ranked.csv', index=False)
    
    # You can also access the dataframe as needed
    print(f"DataFrame for {position_title}:\n")
    print(rank_df)
    print("\n")
# Out:
# DataFrame for Accountant:
#
#     PDF File Name  Cosine Similarity
# 0    12442909.pdf           0.510607
# 1    15592167.pdf           0.458605
# 2    18365791.pdf           0.445075
# 3    10554236.pdf           0.439047
# 4    36024962.pdf           0.439034
# ..            ...                ...
# 113  25867805.pdf           0.363885
# 114  21763056.pdf           0.360377
# 115  29821051.pdf           0.358728
# 116  24799301.pdf           0.346606
# 117  24817041.pdf           0.340470
#
# [118 rows x 2 columns]
#
#
# DataFrame for Part-time   Patient Advocate:
#
#     PDF File Name  Cosine Similarity
# 0    10186968.pdf           0.397712
# 1    29415426.pdf           0.392439
# 2    20324037.pdf           0.382327
# 3    73448369.pdf           0.377010
# 4    15337481.pdf           0.374494
# ..            ...                ...
# 113  26071861.pdf           0.305230
# 114  27182111.pdf           0.305018
# 115  14176254.pdf           0.305013
# 116  10344379.pdf           0.298493
# 117  13967854.pdf           0.276442
#
# [118 rows x 2 columns]
#
#
# DataFrame for Account Executive, Urology - Ohio and parts of W.PA, W.VA:
#
#    PDF File Name  Cosine Similarity
# 0   27689009.pdf           0.439290
# 1   56068028.pdf           0.426366
# 2   19851252.pdf           0.415215
# 3   27888251.pdf           0.414899
# 4   84512719.pdf           0.412397
# ..           ...                ...
# 58  15546686.pdf           0.338967
# 59  55500538.pdf           0.329358
# 60  14140903.pdf           0.328782
# 61  40882926.pdf           0.326405
# 62  24068423.pdf           0.320430
#
# [63 rows x 2 columns]
#
#
# DataFrame for Business Banking Relationship Manager:
#
#    PDF File Name  Cosine Similarity
# 0   12668625.pdf           0.396841
# 1   13858219.pdf           0.374683
# 2   31225895.pdf           0.372499
# 3   25543217.pdf           0.360019
# 4   11232471.pdf           0.358736
# ..           ...                ...
# 92  25142074.pdf           0.298556
# 93  12669075.pdf           0.293717
# 94  13807808.pdf           0.291919
# 95  14413257.pdf           0.289273
# 96  56025640.pdf           0.289199
#
# [97 rows x 2 columns]
#
#
# DataFrame for  Construction Project Manager:
#
#     PDF File Name  Cosine Similarity
# 0    39064638.pdf           0.418526
# 1    11187796.pdf           0.398370
# 2    94230796.pdf           0.395847
# 3    99561379.pdf           0.394884
# 4    11360471.pdf           0.392397
# ..            ...                ...
# 98   24983760.pdf           0.310740
# 99   16962067.pdf           0.308942
# 100  19724031.pdf           0.307323
# 101  78107631.pdf           0.305355
# 102  18029935.pdf           0.294868
#
# [103 rows x 2 columns]
#
#
# DataFrame for Ecommerce Consultant:
#
#    PDF File Name  Cosine Similarity
# 0   22732234.pdf           0.389953
# 1   26341645.pdf           0.385072
# 2   84295343.pdf           0.384703
# 3   11152490.pdf           0.384411
# 4   22946204.pdf           0.383546
# 5   14508237.pdf           0.382784
# 6   97449528.pdf           0.381452
# 7   82140102.pdf           0.381003
# 8   11887930.pdf           0.376542
# 9   16332293.pdf           0.376366
# 10  15484011.pdf           0.373047
# 11  11257723.pdf           0.372547
# 12  91515108.pdf           0.371066
# 13  99680385.pdf           0.368327
# 14  18932512.pdf           0.361549
# 15  23009962.pdf           0.359296
# 16  32109048.pdf           0.358883
# 17  23522150.pdf           0.357066
# 18  15790602.pdf           0.356421
# 19  25047127.pdf           0.356407
# 20  24703983.pdf           0.355562
# 21  24592627.pdf           0.353678
# 22  28790806.pdf           0.350554
# 23  15100547.pdf           0.349515
# 24  32069695.pdf           0.347881
# 25  11797122.pdf           0.347482
# 26  78357954.pdf           0.345744
# 27  15210069.pdf           0.345147
# 28  18448085.pdf           0.338307
# 29  22452756.pdf           0.333679
# 30  17571262.pdf           0.332438
# 31  14455622.pdf           0.330805
# 32  17510973.pdf           0.326710
# 33  47487091.pdf           0.325026
# 34  51508889.pdf           0.315356
# 35  63989974.pdf           0.310533
#
#
# DataFrame for SR. Web Designer:
#
#     PDF File Name  Cosine Similarity
# 0    67631413.pdf           0.384308
# 1    65219288.pdf           0.382319
# 2    17686472.pdf           0.380003
# 3    49646155.pdf           0.378090
# 4    24773845.pdf           0.375777
# ..            ...                ...
# 112  61315605.pdf           0.303535
# 113  21190805.pdf           0.301725
# 114  22168194.pdf           0.300286
# 115  10395944.pdf           0.297624
# 116  90318913.pdf           0.294927
#
# [117 rows x 2 columns]
#
#
# DataFrame for Software Engineering:
#
#     PDF File Name  Cosine Similarity
# 0    60489316.pdf           0.427417
# 1    11065180.pdf           0.420714
# 2    35483925.pdf           0.418829
# 3    17276884.pdf           0.415398
# 4    89049979.pdf           0.415213
# ..            ...                ...
# 110  36302399.pdf           0.343631
# 111  31025785.pdf           0.342162
# 112  65864767.pdf           0.341815
# 113  10909673.pdf           0.337106
# 114  12021752.pdf           0.332505
#
# [115 rows x 2 columns]
#
#
# DataFrame for Director of Finance:
#
#    PDF File Name  Cosine Similarity
# 0   16492045.pdf           0.414900
# 1   27710853.pdf           0.409149
# 2   89512321.pdf           0.404725
# 3   18589927.pdf           0.404498
# 4   13964744.pdf           0.401462
# 5   30709029.pdf           0.398695
# 6   45077654.pdf           0.397248
# 7   31064969.pdf           0.395974
# 8   24727739.pdf           0.395766
# 9   11183737.pdf           0.391463
# 10  38707449.pdf           0.390920
# 11  26829350.pdf           0.388196
# 12  41152404.pdf           0.382310
# 13  79261033.pdf           0.376684
# 14  69097572.pdf           0.370978
# 15  19362586.pdf           0.365935
# 16  23933031.pdf           0.362790
# 17  63158213.pdf           0.361221
# 18  95625660.pdf           0.355815
# 19  15573418.pdf           0.350257
# 20  15145575.pdf           0.348425
# 21  57706851.pdf           0.342400
#
#
# DataFrame for Fitness Coach:
#
#     PDF File Name  Cosine Similarity
# 0    12632728.pdf           0.412603
# 1    14241621.pdf           0.397718
# 2    28337049.pdf           0.395556
# 3    30938994.pdf           0.389582
# 4    33424600.pdf           0.382513
# ..            ...                ...
# 115  32385553.pdf           0.284494
# 116  14726000.pdf           0.281591
# 117  18236085.pdf           0.279725
# 118  10235211.pdf           0.276788
# 119  24412546.pdf           0.260070
#
# [120 rows x 2 columns]
#
#
# DataFrame for VP, Healthcare Services:
#
#     PDF File Name  Cosine Similarity
# 0    26718039.pdf           0.484522
# 1    19007667.pdf           0.484522
# 2    28230807.pdf           0.454351
# 3    10333299.pdf           0.449384
# 4    23398733.pdf           0.447439
# ..            ...                ...
# 113  12717345.pdf           0.353360
# 114  10889157.pdf           0.351638
# 115  21904897.pdf           0.347238
# 116  35468363.pdf           0.344232
# 117  24673903.pdf           0.327627
#
# [118 rows x 2 columns]
#
#
# DataFrame for HR Generalist:
#
#     PDF File Name  Cosine Similarity
# 0    16378091.pdf           0.453074
# 1    22983516.pdf           0.428404
# 2    21586858.pdf           0.426808
# 3    18882984.pdf           0.422796
# 4    22546476.pdf           0.422111
# ..            ...                ...
# 107  61065616.pdf           0.341516
# 108  10100240.pdf           0.341403
# 109  28803888.pdf           0.339657
# 110  15564893.pdf           0.338772
# 111  25098739.pdf           0.321325
#
# [112 rows x 2 columns]
#
#
# DataFrame for Sales Associate:
#
#     PDF File Name  Cosine Similarity
# 0    48533663.pdf           0.422525
# 1    13215696.pdf           0.419388
# 2    10984392.pdf           0.418545
# 3    29297393.pdf           0.416083
# 4    95792386.pdf           0.414764
# ..            ...                ...
# 110  91116867.pdf           0.330218
# 111  26291616.pdf           0.327285
# 112  79570655.pdf           0.326697
# 113  14346702.pdf           0.314444
# 114  29076405.pdf           0.130350
#
# [115 rows x 2 columns]
#
#
# DataFrame for Teachers at Alpha Park KinderCare:
#
#     PDF File Name  Cosine Similarity
# 0    36269672.pdf           0.510200
# 1    90066849.pdf           0.453567
# 2    23951429.pdf           0.439079
# 3    12674307.pdf           0.419471
# 4    16288901.pdf           0.415771
# ..            ...                ...
# 102  24655918.pdf           0.306516
# 103  39434376.pdf           0.302378
# 104  34511655.pdf           0.301025
# 105  42384185.pdf           0.300130
# 106  14724186.pdf           0.279092
#
# [107 rows x 2 columns]

# %% [markdown]
# ### Calculating cosine similarities between job descriptions and CV embeddings to find and display the top 5 PDF files for each position title, along with their similarity scores.

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Create a mapping between position titles and DataFrame names
position_title_mapping = dict(zip(sel_job_desp_df['position_title'], dataframes.keys()))

# Initialize a dictionary to store the top 5 CVs for each position title
top_5_cvs = {}

# Calculate cosine similarities and find the top 5 CVs for each position title
for position_title, job_description in zip(sel_job_desp_df['position_title'], sel_job_desp_df['job_description']):
    similarities = {}
    job_description = np.array(job_description).reshape(1, -1)  # Ensure job_description is a 2D array
    cv_df = dataframes[position_title_mapping[position_title]]  # Get the corresponding DataFrame
    cv_embeddings = np.array(list(cv_df['Details']))  # Assuming 'Details' column contains CV embeddings
    
    # Calculate cosine similarities within the corresponding DataFrame
    similarities = cosine_similarity(job_description, cv_embeddings)
    
    # Get the PDF file names and ranks based on similarity
    pdf_file_names = cv_df['PDF File Name']
    ranked_pdf_file_names = [(pdf_file_names[i], similarities[0][i]) for i in np.argsort(similarities[0])[-1:-6:-1]]
    
    # Store the ranked PDF file names along with similarity
    top_5_cvs[position_title] = ranked_pdf_file_names

# Display results
for position_title, top_pdf_similarities in top_5_cvs.items():
    print(f"Top 5 PDF Files for {position_title}:")
    for rank, (pdf_file, similarity) in enumerate(top_pdf_similarities, start=1):
        print(f"Rank {rank}: PDF File: {pdf_file}, Similarity: {similarity:.4f}")
    print("\n")
# Out:
# Top 5 PDF Files for Accountant:
# Rank 1: PDF File: 12442909.pdf, Similarity: 0.5106
# Rank 2: PDF File: 15592167.pdf, Similarity: 0.4586
# Rank 3: PDF File: 18365791.pdf, Similarity: 0.4451
# Rank 4: PDF File: 10554236.pdf, Similarity: 0.4390
# Rank 5: PDF File: 36024962.pdf, Similarity: 0.4390
#
#
# Top 5 PDF Files for Part-time   Patient Advocate:
# Rank 1: PDF File: 10186968.pdf, Similarity: 0.3977
# Rank 2: PDF File: 29415426.pdf, Similarity: 0.3924
# Rank 3: PDF File: 20324037.pdf, Similarity: 0.3823
# Rank 4: PDF File: 73448369.pdf, Similarity: 0.3770
# Rank 5: PDF File: 15337481.pdf, Similarity: 0.3745
#
#
# Top 5 PDF Files for Account Executive, Urology - Ohio and parts of W.PA, W.VA:
# Rank 1: PDF File: 27689009.pdf, Similarity: 0.4393
# Rank 2: PDF File: 56068028.pdf, Similarity: 0.4264
# Rank 3: PDF File: 19851252.pdf, Similarity: 0.4152
# Rank 4: PDF File: 27888251.pdf, Similarity: 0.4149
# Rank 5: PDF File: 84512719.pdf, Similarity: 0.4124
#
#
# Top 5 PDF Files for Business Banking Relationship Manager:
# Rank 1: PDF File: 12668625.pdf, Similarity: 0.3968
# Rank 2: PDF File: 13858219.pdf, Similarity: 0.3747
# Rank 3: PDF File: 31225895.pdf, Similarity: 0.3725
# Rank 4: PDF File: 25543217.pdf, Similarity: 0.3600
# Rank 5: PDF File: 11232471.pdf, Similarity: 0.3587
#
#
# Top 5 PDF Files for  Construction Project Manager:
# Rank 1: PDF File: 39064638.pdf, Similarity: 0.4185
# Rank 2: PDF File: 11187796.pdf, Similarity: 0.3984
# Rank 3: PDF File: 94230796.pdf, Similarity: 0.3958
# Rank 4: PDF File: 99561379.pdf, Similarity: 0.3949
# Rank 5: PDF File: 11360471.pdf, Similarity: 0.3924
#
#
# Top 5 PDF Files for Ecommerce Consultant:
# Rank 1: PDF File: 22732234.pdf, Similarity: 0.3900
# Rank 2: PDF File: 26341645.pdf, Similarity: 0.3851
# Rank 3: PDF File: 84295343.pdf, Similarity: 0.3847
# Rank 4: PDF File: 11152490.pdf, Similarity: 0.3844
# Rank 5: PDF File: 22946204.pdf, Similarity: 0.3835
#
#
# Top 5 PDF Files for SR. Web Designer:
# Rank 1: PDF File: 67631413.pdf, Similarity: 0.3843
# Rank 2: PDF File: 65219288.pdf, Similarity: 0.3823
# Rank 3: PDF File: 17686472.pdf, Similarity: 0.3800
# Rank 4: PDF File: 49646155.pdf, Similarity: 0.3781
# Rank 5: PDF File: 24773845.pdf, Similarity: 0.3758
#
#
# Top 5 PDF Files for Software Engineering:
# Rank 1: PDF File: 60489316.pdf, Similarity: 0.4274
# Rank 2: PDF File: 11065180.pdf, Similarity: 0.4207
# Rank 3: PDF File: 35483925.pdf, Similarity: 0.4188
# Rank 4: PDF File: 17276884.pdf, Similarity: 0.4154
# Rank 5: PDF File: 89049979.pdf, Similarity: 0.4152
#
#
# Top 5 PDF Files for Director of Finance:
# Rank 1: PDF File: 16492045.pdf, Similarity: 0.4149
# Rank 2: PDF File: 27710853.pdf, Similarity: 0.4091
# Rank 3: PDF File: 89512321.pdf, Similarity: 0.4047
# Rank 4: PDF File: 18589927.pdf, Similarity: 0.4045
# Rank 5: PDF File: 13964744.pdf, Similarity: 0.4015
#
#
# Top 5 PDF Files for Fitness Coach:
# Rank 1: PDF File: 12632728.pdf, Similarity: 0.4126
# Rank 2: PDF File: 14241621.pdf, Similarity: 0.3977
# Rank 3: PDF File: 28337049.pdf, Similarity: 0.3956
# Rank 4: PDF File: 30938994.pdf, Similarity: 0.3896
# Rank 5: PDF File: 33424600.pdf, Similarity: 0.3825
#
#
# Top 5 PDF Files for VP, Healthcare Services:
# Rank 1: PDF File: 26718039.pdf, Similarity: 0.4845
# Rank 2: PDF File: 19007667.pdf, Similarity: 0.4845
# Rank 3: PDF File: 28230807.pdf, Similarity: 0.4544
# Rank 4: PDF File: 10333299.pdf, Similarity: 0.4494
# Rank 5: PDF File: 23398733.pdf, Similarity: 0.4474
#
#
# Top 5 PDF Files for HR Generalist:
# Rank 1: PDF File: 16378091.pdf, Similarity: 0.4531
# Rank 2: PDF File: 22983516.pdf, Similarity: 0.4284
# Rank 3: PDF File: 21586858.pdf, Similarity: 0.4268
# Rank 4: PDF File: 18882984.pdf, Similarity: 0.4228
# Rank 5: PDF File: 22546476.pdf, Similarity: 0.4221
#
#
# Top 5 PDF Files for Sales Associate:
# Rank 1: PDF File: 48533663.pdf, Similarity: 0.4225
# Rank 2: PDF File: 13215696.pdf, Similarity: 0.4194
# Rank 3: PDF File: 10984392.pdf, Similarity: 0.4185
# Rank 4: PDF File: 29297393.pdf, Similarity: 0.4161
# Rank 5: PDF File: 95792386.pdf, Similarity: 0.4148
#
#
# Top 5 PDF Files for Teachers at Alpha Park KinderCare:
# Rank 1: PDF File: 36269672.pdf, Similarity: 0.5102
# Rank 2: PDF File: 90066849.pdf, Similarity: 0.4536
# Rank 3: PDF File: 23951429.pdf, Similarity: 0.4391
# Rank 4: PDF File: 12674307.pdf, Similarity: 0.4195
# Rank 5: PDF File: 16288901.pdf, Similarity: 0.4158
